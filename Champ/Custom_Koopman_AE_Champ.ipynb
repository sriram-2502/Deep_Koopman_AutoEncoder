# %% [markdown]
# # Implement a custom Autoencoder with Koopman layer

# %% [markdown]
# ## Version Control

# %% [markdown]
# To Do:
# 1) Account for trailing batch - Make robust (fixed issue by reshaping input data)
# 2) Address Sp issue for loss function
# 3) Try different L_inf norm hyperparameter
# 4) Add regularization parameters

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras

import  numpy as np
import pandas as pd

import matplotlib.colors as mcol
import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.animation as animation

import seaborn as sns

import time 
import os

import glob
import csv

# %%
plt.rcParams['figure.figsize'] = [9, 6]
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.style.use('default')

# %%
#from google.colab import drive
#drive.mount('/gdrive')

# %% [markdown]
# Comment out if don't need

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data

# %% [markdown]
# ### Read Sim Data Functions

# %%
def preprocessSimData(df, desiredStates:list, initialIndex:int=300, finalIndex:int=812):
    '''
    Preprocess text file (fixing formatting issue in data as well) while returning a dataframe object with the desired states selected

    Parameters:
    -----------
    df: dataFrame
        Panda dataframe that is read from one of the recorded simulation .txt files
    desiredStates: list
        List of desired states to return as a panda dataframe object in sequential order

    Return:
    ----------
    stateMatrix: dataFrame
        State matrix with desired states
    '''



    # Fix formatting Variables
    falseList = ['time_lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort', 'nan']
    df.columns = falseList
    df['time_lf_hip_joint_position'] = df.time_lf_hip_joint_position.str[0:8] + ' ' + df.time_lf_hip_joint_position.str[8:]


    # Data and State Name List
    data = df.values # np array of data values
    namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

    dictStates = {}
    staticCounter = 0 # Variable to account for formatting issue
    for index in range(len(namesList)-1):
        if index == 0 and staticCounter == 0: # Condition for formatting issue of collected data
            for j in range(len(data[:,index])): # Looping through all elements in column 0 and converting to float
                if j == 0: # Initialize array
                    array1 = float(data[j,index][0:8])
                    #print(array1)
                    array2 = float(data[j,index][8:])
                    #print(array2)
                else:
                    array1 = np.vstack((array1,float(data[j,index][0:8])))
                    array2 = np.vstack((array2,float(data[j,index][8:])))
            dictStates[namesList[index]] = np.squeeze(array1[initialIndex:finalIndex])
            dictStates[namesList[index+1]] = np.squeeze(array2[initialIndex:finalIndex])        
        else:
            dictStates[namesList[index+1]] = data[initialIndex:finalIndex,index]
    for counter, names in enumerate(desiredStates):
        if counter == 0:
            stateMatrix = np.reshape(dictStates[names], (-1,1))
        else:
            stateMatrix = np.hstack((stateMatrix, np.reshape(dictStates[names], (-1,1))))
    return pd.DataFrame(stateMatrix, columns = desiredStates)



def preprocessFile(fileNames:list, initialIndex:int, finalIndex:int, desiredStates:list):
    '''
    Given fileNames to read, reads the file(s) and returns all data concatenated in a panda dataframe framework

    Paramaters:
    -----------
    fileNamess:list
        List of filenames to read and concatenate data together
    intialIndex: int
        Index to start reading each file's data from
    finalIndex: int
        Index to stop reading each file's data from
    desiredStates:list
        List of states to read
    
    Return:
    ----------
    totalData: dataFrame
        Returns data of all filenames with given states in one panda dataframe
    '''

    filePaths = []
    for i in fileNames:
        filePaths.append(glob.glob(i))
    #print(filePaths)


    dataFrameList = []
    for i in filePaths:
        for j in i:
            df = pd.read_csv(j, sep= " ", header=None)
            dataFrameList.append(preprocessSimData(df, desiredStates, initialIndex=initialIndex, finalIndex=finalIndex)) # 712-200 = 512 --> 512-1 is 512 indices (i.e. [0, 511])

    totalData = pd.concat(dataFrameList)
    return totalData

# %% [markdown]
# ### Read full data

# %%
# List of states
namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

# %%
desiredStates = ['lf_hip_joint_position', 'lf_hip_joint_vel', 'lf_lower_leg_joint_position', 
                'lf_lower_leg_joint_vel', 'lf_hip_joint_effort', 'lf_lower_leg_joint_effort']

input_dim = len(desiredStates)
output_dim = input_dim

trajLength = 2**6 # Length of each trajectory in the dataset

filePath = "simData"
fileNames = [filePath + '/empty_world_ground_2/joint_state_test_emptyWorld_forward_0.5*']
#fileNames = [filePath + '/noContact/joint_state_test_emptyWorld_forward_0.5*']

numTraj = 256 # Total number of trajectories in the dataset (train)
numTraj_val = 32
numTraj_test = 32
batch_size = int(2**8) # Number of snapshots in each batch
numTraj_batch = int(batch_size/trajLength)
numTraj_batch = int(batch_size/trajLength)

initialIndex, finalIndex= 400, 400+trajLength*(numTraj+numTraj_val+numTraj_test)

num_batches_train = int(trajLength*numTraj/batch_size) ## num_batches = trajLength*numTraj/batch_size 
num_batches_val = int(trajLength*numTraj_val/batch_size)

# %%
doggoFrame = preprocessFile(fileNames,initialIndex,finalIndex, desiredStates)
doggoFrame.head(5)
# Out:
#   lf_hip_joint_position lf_hip_joint_vel lf_lower_leg_joint_position  \
# 0                0.0013           3.6865                     -1.4667
# 1               -0.0027          -3.9149                     -1.5198
# 2                0.0009           3.4271                     -1.5245
# 3               -0.0012          -2.4308                     -1.5679
# 4                0.0009           1.4415                      -1.584
#
#   lf_lower_leg_joint_vel lf_hip_joint_effort lf_lower_leg_joint_effort
# 0                19.5187              4.1101                      25.0
# 1               -30.1504             -3.6843                  -24.6202
# 2                15.1851              3.5978                   21.3211
# 3                -19.652             -2.8346                  -15.4825
# 4                 2.1823               1.589                    8.4289

# %%
plt.figure(figsize=(16,4))
plt.plot(doggoFrame.values[0:5000,2])
plt.title("Graph of data")
# Out:
# Text(0.5, 1.0, 'Graph of data')

# %%
plt.figure(figsize=(9,6))
plt.plot(doggoFrame.values[0:,0], doggoFrame.values[0:,1],lw=1)
plt.title("Phase Portrait")
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\dot\theta$")
plt.tight_layout()

# %%
print("Datapoints: ", len(doggoFrame.index))
# Out:
# Datapoints:  20480

# %%
doggo_train = doggoFrame.values[:numTraj*trajLength,:]
doggo_validation = doggoFrame.values[numTraj*trajLength:(numTraj+numTraj_val)*trajLength,:]
doggo_test = doggoFrame.values[(numTraj+numTraj_val)*trajLength:(numTraj+numTraj_val+numTraj_test)*trajLength,:]

doggo_train = np.asarray(doggo_train).astype('float32')
doggo_test = np.asarray(doggo_test).astype('float32')
doggo_validation = np.asarray(doggo_validation).astype('float32')

# %%
print("Size of doggo_train:", len(doggo_train))
print("Size of doggo_validation:", len(doggo_validation))
print("Size of doggo_test:", len(doggo_test))
# Out:
# Size of doggo_train: 16384
# Size of doggo_validation: 2048
# Size of doggo_test: 2048

# %% [markdown]
# ### Make into dataset

# %%
# Normalize the data
min_val = tf.reduce_min(doggo_train)
max_val = tf.reduce_max(doggo_train)

#doggo_train = (doggo_train - min_val) / (max_val - min_val)
#doggo_validation = (doggo_validation - min_val) / (max_val - min_val)
#doggo_test = (doggo_test - min_val) / (max_val - min_val)

train_data = tf.cast(doggo_train[0:batch_size*num_batches_train], tf.float32)
validation_data = tf.cast(doggo_validation[0:batch_size*num_batches_val], tf.float32)
validation_data = tf.data.Dataset.from_tensor_slices((validation_data, validation_data)).batch(batch_size)
test_data = tf.cast(doggo_test, tf.float32)

# %%
x_train = train_data
y_train = train_data

# %% [markdown]
# # Custom Model definition

# %% [markdown]
# ## Encoder

# %%
class EncoderLayer(keras.layers.Layer):
    """
    Custom class to create a encoder layer
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * x + b: tensor
        linear combination of weights times input + bias for the layer
    """
    
    def __init__(self, units=32, name=None):
        super(EncoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Encoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, inputs):
        #print("Encoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(inputs, self.w) + self.b

# %%
class EncoderModel(keras.Model):
    """
    Custom Model to create an encoder with one input
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    """
    
    def __init__(self, name=None):
        super(EncoderModel, self).__init__(name=name)
        self.enc1 = EncoderLayer(256)
        self.enc2 = EncoderLayer(256)
        self.enc3 = EncoderLayer(256)
        self.enc4 = EncoderLayer(256)
        self.enc5 = EncoderLayer(256)
        self.enc6 = EncoderLayer(256)
        self.enc7 = EncoderLayer(256)

    def call(self, input):
        x = input
        x = self.enc1(x)
        x = tf.nn.tanh(x)
        x = self.enc2(x)
        x = tf.nn.tanh(x)

        # Encoder output layer
        x = self.enc3(x)
        x = tf.nn.tanh(x)
        x = self.enc4(x)
        x = tf.nn.tanh(x)
        x = self.enc5(x)
        x = tf.nn.tanh(x)
        x = self.enc6(x)
        x = tf.nn.tanh(x)
        x = self.enc7(x)
        z = tf.nn.tanh(x)
        return z

# %% [markdown]
# ## Koopman

# %%
class KoopmanLayer(keras.layers.Layer):
    """
    Custom class to calculate the Koopman operator K on latent variables
    Adds a linear loss as mse(Z2-Z2_tilde)
    
    Parameters
    ----------
    Z: tensor 
        inputs are the latent variabes (output from encoder)
        input dimension is (m, 128)
        m is the number of time snapshots for each input dimension of X
        128 is the number of latent varibales (observables)

    Return
    ----------
    Z: tensor
        return the original input Z 

    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    Z2_tilde: tensor
        return the prediction by linearity from K (z2_tilde = K^m * z(1,:))
    """

    def __init__(self, trajLength, numTraj_batch):
        super(KoopmanLayer, self).__init__()
        self.trajLength = trajLength
        self.numTraj_batch = numTraj_batch

    def build(self, Z):
        # Initialize K as a weight
            self.K =  self.add_weight(
                name = 'Koopman_weight',
                shape=(Z[-1], Z[-1]),
                initializer="random_normal",
                trainable=True,
            )

    def timeShift(self,Z,latent_dim):
        '''
        Shifts trajectories one time step
        Parameters:
        -----------
            Z: tensor
                Batch data of latent variables (in the lifted space)
                
            latent_dim: tensor shape
                Dimension of the lifted space (columns of Z)
        '''
        Z1 = []
        z1 = []
        Z2 = []

        for i in range(self.numTraj_batch):
            Z1.append(Z[i*self.trajLength:(i+1)*self.trajLength-1,:])
            Z2.append(Z[i*self.trajLength+1:(i+1)*self.trajLength,:])
            z1.append(Z[i*self.trajLength,:])
        return tf.reshape(Z1, [-1, latent_dim]), tf.reshape(Z2, [-1, latent_dim]), tf.reshape(z1, [-1, latent_dim])       

    def call(self, Z):
        latent_dim = tf.shape(Z)[1]
        shift_len = (self.trajLength-1)*self.numTraj_batch # length of rows for forward time shifted Z
        Z1, Z2, z1 = self.timeShift(Z,latent_dim)

        # Find Z2_tilde
        Z2_tilde = tf.zeros([shift_len, latent_dim], dtype=tf.float32)
        for traj in range(self.numTraj_batch): # loop over numnber of traj
            for m in range(self.trajLength-1): #loop over snapshots in each traj
                 #K = tf.zeros([latent_dim, latent_dim], dtype=tf.float32)
                 
                 indices = tf.constant([[traj*(self.trajLength-1)+m]])
                 if m == 0:
                    K = self.K 
                    # Matrix matvec works out to get Kz' and returns as row vector
                    updates = [tf.linalg.matvec(K, z1[traj,:])] #updates the row tensor at index = indices 
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                 else:
                    K = tf.matmul(K,self.K)
                    updates = [tf.linalg.matvec(K, z1[traj,:])]
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
           
        # Find linear loss
        Linear_loss = tf.reduce_mean(tf.square(tf.subtract(Z2,Z2_tilde)))
        self.add_loss(Linear_loss)
        
        # prints for debugging dimensions
        #print("Koopman layer, K",tf.shape(K))
        #print("Koopman layer, m",tf.shape(m))
        #print("Koopman layer, Z",tf.shape(Z))
        #print("Koopman layer, z1",tf.shape(z1))
        #print("Koopman layer, Z2 ",tf.shape(Z2))
        #print("Koopman layer, Z2_tilde",tf.shape(Z2_tilde))
        
        return Z, tf.matmul(Z1,self.K), Z2_tilde,

# %%
class Koopman_Model(keras.Model):
    """
    Custom Model to create an encoder with koopman layer
    
    Parameters
    ----------
    input: tensor 
        z - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    
    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    z2_tilde: tensor
        Latent variables of prediction obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    """
    
    def __init__(self, trajLength, numTraj_batch, name=None):
        super(Koopman_Model, self).__init__(name=name)
        self.koopman = KoopmanLayer(trajLength,numTraj_batch)


    def call(self, input):
        z = input
        z, Z2_hat, z2_tilde = self.koopman(z)
        return z, Z2_hat, z2_tilde

# %% [markdown]
# ## Decoder

# %%
class DecoderLayer(keras.layers.Layer):
    """
    Custom class to create a decoder layer with two inputs
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * input1 + b: tensor
        linear combination of weights times input1 + bias for the layer
        
    W.T * input2 + b: tensor
        linear combination of weights times input2 + bias for the layer

    W.T * input3 + b: tensor
        linear combination of weights times input3 + bias for the layer
    """

    def __init__(self, units=32, name=None):
        super(DecoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Decoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, input1, input2, input3):
        #print("Decoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(input1, self.w) + self.b, tf.matmul(input2, self.w) + self.b, tf.matmul(input3, self.w) + self.b

# %%
class DecoderModel(keras.Model):
    """
    Custom Model to create a decoder with two inputs
    
    Parameters
    ----------
    input 1: tensor 
        z - the lifted output of the koopman layer (encoder output)
    
    input 2: tensor 
        z2_tilde - obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Prediction of the original state inputs x (label values are forward time shifted x)

    x2_tilde: tensor
        Prediction obtained by linearity from K 
    
    """
    
    def __init__(self, outputDim, name=None):
        super(DecoderModel, self).__init__(name=name)
        self.dec1 = DecoderLayer(256)
        self.dec2 = DecoderLayer(256)
        self.dec3 = DecoderLayer(256)
        self.dec4 = DecoderLayer(256)
        self.outputLayer = DecoderLayer(outputDim)

    def call(self, input1, input2, input3):
        z = input1
        z2_hat = input2
        z2_tilde = input3

        z, z2_hat, z2_tilde = self.dec1(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec2(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec3(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec4(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        # Decoder output layer
        x_hat, x2_hat, x2_tilde = self.outputLayer(z, z2_hat, z2_tilde)
        #x_hat = tf.nn.elu(x_hat)
        #x2_hat = tf.nn.elu(x2_hat)
        #x2_tilde = tf.nn.elu(x2_tilde)

        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# ## Koopman Autoencoder

# %%
class Koopman_AE_Model(keras.Model):
    """
    Custom Model to create a Koopman Autoencoder
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    
    x2_tilde: tensor
        Prediction obtained by linearity from K 
    """
    
    def __init__(self, inputDim, outputDim, trajLength, numTraj, name=None):
        super(Koopman_AE_Model, self).__init__(name=name)
        self.enc = EncoderModel()
        self.koopman = Koopman_Model(trajLength, numTraj)
        self.dec = DecoderModel(outputDim)

    def call(self, input):
        x = input
        z = self.enc(x)
        z, z2_hat, z2_tilde = self.koopman(z)
        x_hat, x2_hat, x2_tilde = self.dec(z, z2_hat, z2_tilde)
        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# # Custom Training Loop

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.batch(batch_size)

# %%
class MyStaticModel():
    def __init__(self, input_dim, batch_size, trajLength, num_batches_train, num_batches_val, epochNum, lr):
        # Initialize constants
        self.batch_size = batch_size
        self.trajLength = int(trajLength) #should be int
        self.numtraj_batch = int(self.batch_size/self.trajLength) # should be int
        self.num_batches_train = num_batches_train
        self.num_batches_val = num_batches_val

        self.epochNum = epochNum
        self.lr = lr

        self.inputs = tf.keras.layers.Input(shape=(input_dim,))
        self.graphCounter = 0 

    ######################################  LOSS FUNCTIONS  ###################################################
    def tot_loss(self, model, x, x_hat, x2_hat, x2_tilde):
        """Calculates total loss as sum of recon_loss + predict_loss + Koopman_loss"""
        #alpha1 = 0.1, alpha2 = 1e-7, alpha3 = 1e-15
        alpha1 = 0.1
        alpha2 = 1e-7
        alpha3 = 1e-15

        x2 = []
        x2_SP = []
        x2_tilde_SP = []
        for i in range(self.numtraj_batch):
            predict_length = self.trajLength-1
            x2.append(x[i*self.trajLength+1:(i+1)*self.trajLength]) # forward time shift x to get x2
            x2_SP.append(x[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # forward time shift x to get x2 for Sp timesteps
            #x2_tilde_SP.append(x2_tilde[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # get Sp timesteps from x2_tilde
            # Shape currently goes from 31 to 27.. but somehow indexing does not work
            x2_tilde_SP = x2_tilde

        #print("In loss function x2", tf.shape(x2))
        #print("In loss function x2_SP", tf.shape(x2_SP))
        #print("In loss function x2_tilde_SP", tf.shape(x2_tilde_SP))

        x2 = tf.reshape(x2, [-1, x.shape[-1]])
        x2_SP = tf.reshape(x2_SP, [-1, x.shape[-1]])
        x2_tilde_SP = tf.reshape(x2_tilde_SP, [-1, x.shape[-1]])

        recon_loss = tf.reduce_mean(tf.square(tf.subtract(x,x_hat)))
        predict_loss =tf.reduce_mean(tf.square(tf.subtract(x2_SP,x2_tilde_SP)))

        weights  = model.trainable_variables
        lossL2 = tf.add_n([tf.nn.l2_loss(w) for w in weights if 'bias' not in w.name])

        Linf_loss = tf.add(tf.norm(tf.subtract(x,x_hat), ord=np.inf), tf.norm(tf.subtract(x2,x2_hat), ord=np.inf))
        '''
        print("-------------------------------")
        print("L_inf loss: ", alpha2*Linf_loss)
        print("recon_loss + predict_loss: ", alpha1*(recon_loss+predict_loss))
        print("L2 Loss: ", alpha3*lossL2)
        print("Lifted Loss: ", sum(model.losses))
        '''
        return alpha1*(recon_loss+predict_loss) + alpha2*Linf_loss + alpha3*lossL2 + sum(model.losses)

    ###############################################  GRAPH FUNCTIONS     #########################################################

    def graphPlot(self, error, error_min, error_max, error_val, error_min_val, error_max_val):
        '''
        Graph plots for loss over all epochs
        Parameters:
        error: list
            Training Loss Error for all epochs
        error_val: list
            Validation Loss Error for all epochs
        '''
        saveFiles = True
        imgPath = 'graphs/'
        csvPath = 'csvFiles/'

        csvFileName = 'epochLosses.csv'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making graph folder. Folder already exists...")

            try:
                os.mkdir(csvPath)
            except:
                print("Tried making csv folder. Folder already exists...")
        
        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Training Loss")
        plt.plot(error_val, label = "Validation Loss")
        textTitle = "All Epoch Loss %d" % self.graphCounter
        self.graphCounter += 1
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight') 
        plt.close()

        # Save data into csv file
        csvDict = {'Epoch Training Loss': error, 'Epoch Training Min Loss': error_min, 'Epoch Training Max Loss': error_max,
                    'Epoch Validation Loss': error_val, 'Epoch Validation Min Loss' : error_min_val, 
                    'Epoch Validation Max Loss': error_max_val}
        df = pd.DataFrame(csvDict)
        df.to_csv(csvPath+csvFileName)
            

    
    def graphBatchLossPlot(self, epochNum, error, error_val):
        '''
        Graphs the loss of each batch
        
        Parameter:
        ----------
        epochNum: int
            Current epoch number
        error: list
            Training error for batch
        error_val: list
            Validation error for batch

        Return:
        -------
        None
        '''
        saveFiles = True
        imgPath = 'graphs/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Batch Training Loss")
        plt.plot(error_val, label="Batch Validation Loss")
        textTitle = "BatchLoss_Epoch_%d" % (epochNum)
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
        plt.close() 

    
    def graphEigenfunctions(self, model, K):
        '''
        Graphs the eigenfunction given K and the model (used sample from hypercube)
        Parameter:
        ----------
        model: keras model
            Koopman autoencoder model
        K:
            Koopman operator
        
        Return:
        ----------
        None
        '''
        saveFiles = True
        imgPath = 'graphs/eigenfunctions/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        x1 = tf.linspace(-1,1,256)
        x2 = tf.linspace(-1,1,256)
        x1, x2 = tf.meshgrid(x1, x2)
        X = tf.reshape([[x1],[x2]], [-1, 2])

        Z = model.enc(X)
        complex_Z = tf.complex(Z, tf.zeros(tf.shape(Z))) # make Z complex with zero complex part

        eig_values, right_eig_vectors = tf.linalg.eig(tf.squeeze(K))
        W = tf.transpose(tf.linalg.inv(right_eig_vectors))
        Psi = tf.matmul(complex_Z,W)

        eig_dominant = tf.abs(eig_values)
        counter = 0
        for eig in eig_values:
            cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["b","w","r"])
            #normalize = mpl.colors.Normalize(vmin=np.min(Psi[:,counter]), vmax=np.max(Psi[:,counter]))
            plt.figure(counter)
            fig, axs = plt.subplots(2)
            
            p1 = axs[0].scatter(x1, x2, c=tf.abs(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p1, ax=axs[0])
            fig_title1 = "|Psi| %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig)) 
            axs[0].set_title(fig_title1)
            
            p2 = axs[1].scatter(x1, x2, c=tf.math.angle(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p2, ax=axs[1])
            fig_title2 = "angle(Psi) %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig))  
            axs[1].set_title(fig_title2)

            fig.tight_layout()
            textTitle = "Psi_%0.04f_epoch%d"%(eig, counter)
            counter += 1
            if saveFiles:
                plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
            plt.close('all') 

    ###############################################     FIT FUNCTION        #########################################################

    def fit(self, model, x, y, validation_data, batch_size):
        '''
        Given a tensorflow model, training data (x,y), validation data, and the batch size, trains the model over specified datapoints
        Parameter:
        ----------
        model: Tensorflow model
        x:
            Training data 
        y:
            Training data for evaluation (for AE, same as x)
        validation_data: tensorflow batch?
            Data in a batch (See tensorflow tutorial)
        batch_size: int
            The batch size for training
        Return:
        ---------
        None
        '''
        # Preprocess data
        train_ds = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)

        # Define the optimizer
        optimizer = tf.keras.optimizers.Adam(self.lr)

        epochs = self.epochNum     
        
        # Initialize variables for csv file
        epoch_train_loss = [] # total loss for each epoch
        epoch_train_min_loss = []
        epoch_train_max_loss = []
        
        epoch_validation_loss = []
        epoch_validation_min_loss = []
        epoch_validation_max_loss = []



        start_time_total = time.time()
        for epoch in range(epochs):

            print("\nStart of epoch %d" % (epoch))
            start_time = time.time()

            batch_train_loss_list = [] # total loss for each batch 
            batch_validation_loss_list = []


            ###############################################     Training loop     ###################################################
            # Iterate over the train batches of the dataset.
            for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
                with tf.GradientTape() as tape:
                    reconstruction, prediction, linearity = model(x_batch_train)

                    # total avg loss for each batch
                    batch_train_loss = self.tot_loss(model, y_batch_train, reconstruction, prediction, linearity)
                    batch_train_loss_list.append(batch_train_loss)

                grads = tape.gradient(batch_train_loss, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
                              
            # outside batch loop
            avg_train_loss = np.sum(batch_train_loss_list)/self.num_batches_train
            min_train_loss = np.amin(batch_train_loss_list)
            max_train_loss = np.amax(batch_train_loss_list)
            epoch_train_loss.append(avg_train_loss)
            epoch_train_min_loss.append(min_train_loss)
            epoch_train_max_loss.append(max_train_loss)


            print("Average training loss at epoch %d: %.7f"% (epoch, float(avg_train_loss)))


            ###############################################   Validaiton  loop     ###################################################
            for step, (x_batch_val, y_batch_val) in enumerate(validation_data):
                reconstruction_val, pred_val, linearity_val = model(x_batch_val)

                batch_validation_loss = self.tot_loss(model, y_batch_val, reconstruction_val, pred_val, linearity_val)
                batch_validation_loss_list.append(batch_validation_loss)

            # outside batch loop
            epoch_validation_loss.append(np.sum(batch_validation_loss_list)/self.num_batches_val)
            epoch_validation_min_loss.append(np.amin(batch_validation_loss_list))
            epoch_validation_max_loss.append(np.amax(batch_validation_loss_list))

            print(f"Epoch val loss: {np.sum(batch_validation_loss_list)/num_batches_val}")
            print("Time taken: %.2fs" % (time.time()- start_time_total))
            #self.graphBatchLossPlot(epoch, batch_train_loss_list, batch_validation_loss_list)
            #K = model.koopman.get_weights()
            #self.graphEigenfunctions(model, K)

        self.graphPlot(epoch_train_loss, epoch_train_min_loss, epoch_train_max_loss, epoch_validation_loss, 
                        epoch_validation_min_loss, epoch_validation_max_loss)
        print("Total time taken: %.2fs" % (time.time() - start_time_total))

# %%
epochNum = 250
lr = 1e-4

Training_class = MyStaticModel(input_dim, batch_size, trajLength, num_batches_train, num_batches_val, epochNum = epochNum, lr=lr)
koopmanAEModel = Koopman_AE_Model(input_dim, output_dim, trajLength, numTraj_batch, name="Koopman_AE_Model")
Training_class.fit(koopmanAEModel,x=train_data, y=train_data, validation_data=validation_data, batch_size=batch_size)
# Out:
# Start of epoch 0
# Average training loss at epoch 0: 6.8982363
# Epoch val loss: 5.148484230041504
# Time taken: 59.01s
#
# Start of epoch 1
# Average training loss at epoch 1: 5.4282398
# Epoch val loss: 4.705935955047607
# Time taken: 92.66s
#
# Start of epoch 2
# Average training loss at epoch 2: 5.0911903
# Epoch val loss: 4.492130756378174
# Time taken: 126.05s
#
# Start of epoch 3
# Average training loss at epoch 3: 4.8820257
# Epoch val loss: 4.339707851409912
# Time taken: 159.63s
#
# Start of epoch 4
# Average training loss at epoch 4: 4.7259326
# Epoch val loss: 4.223111629486084
# Time taken: 192.96s
#
# Start of epoch 5
# Average training loss at epoch 5: 4.5983992
# Epoch val loss: 4.136612892150879
# Time taken: 226.80s
#
# Start of epoch 6
# Average training loss at epoch 6: 4.5073376
# Epoch val loss: 4.068760871887207
# Time taken: 260.02s
#
# Start of epoch 7
# Average training loss at epoch 7: 4.4435873
# Epoch val loss: 4.025934219360352
# Time taken: 293.52s
#
# Start of epoch 8
# Average training loss at epoch 8: 4.3954787
# Epoch val loss: 3.9908552169799805
# Time taken: 327.88s
#
# Start of epoch 9
# Average training loss at epoch 9: 4.3565240
# Epoch val loss: 3.9656853675842285
# Time taken: 361.86s
#
# Start of epoch 10
# Average training loss at epoch 10: 4.3214374
# Epoch val loss: 3.9423046112060547
# Time taken: 395.13s
#
# Start of epoch 11
# Average training loss at epoch 11: 4.2931976
# Epoch val loss: 3.921290397644043
# Time taken: 429.35s
#
# Start of epoch 12
# Average training loss at epoch 12: 4.2718277
# Epoch val loss: 3.9042701721191406
# Time taken: 462.76s
#
# Start of epoch 13
# Average training loss at epoch 13: 4.2560291
# Epoch val loss: 3.893786668777466
# Time taken: 496.70s
#
# Start of epoch 14
# Average training loss at epoch 14: 4.2427235
# Epoch val loss: 3.882826328277588
# Time taken: 529.52s
#
# Start of epoch 15
# Average training loss at epoch 15: 4.2319765
# Epoch val loss: 3.874885082244873
# Time taken: 563.07s
#
# Start of epoch 16
# Average training loss at epoch 16: 4.2242517
# Epoch val loss: 3.873383045196533
# Time taken: 596.26s
#
# Start of epoch 17
# Average training loss at epoch 17: 4.2157869
# Epoch val loss: 3.8670475482940674
# Time taken: 629.70s
#
# Start of epoch 18
# Average training loss at epoch 18: 4.2092013
# Epoch val loss: 3.864834785461426
# Time taken: 662.71s
#
# Start of epoch 19
# Average training loss at epoch 19: 4.2037539
# Epoch val loss: 3.865497589111328
# Time taken: 695.94s
#
# Start of epoch 20
# Average training loss at epoch 20: 4.1979256
# Epoch val loss: 3.872300148010254
# Time taken: 728.94s
#
# Start of epoch 21
# Average training loss at epoch 21: 4.1946898
# Epoch val loss: 3.8702492713928223
# Time taken: 762.46s
#
# Start of epoch 22
# Average training loss at epoch 22: 4.1904106
# Epoch val loss: 3.8664486408233643
# Time taken: 795.56s
#
# Start of epoch 23
# Average training loss at epoch 23: 4.1873293
# Epoch val loss: 3.8719568252563477
# Time taken: 828.72s
#
# Start of epoch 24
# Average training loss at epoch 24: 4.1831965
# Epoch val loss: 3.8702993392944336
# Time taken: 861.97s
#
# Start of epoch 25
# Average training loss at epoch 25: 4.1823235
# Epoch val loss: 3.8711233139038086
# Time taken: 895.19s
#
# Start of epoch 26
# Average training loss at epoch 26: 4.1801229
# Epoch val loss: 3.8747453689575195
# Time taken: 928.70s
#
# Start of epoch 27
# Average training loss at epoch 27: 4.1766014
# Epoch val loss: 3.8812947273254395
# Time taken: 961.83s
#
# Start of epoch 28
# Average training loss at epoch 28: 4.1746845
# Epoch val loss: 3.875041961669922
# Time taken: 994.77s
#
# Start of epoch 29
# Average training loss at epoch 29: 4.1729832
# Epoch val loss: 3.8758859634399414
# Time taken: 1028.05s
#
# Start of epoch 30
# Average training loss at epoch 30: 4.1722212
# Epoch val loss: 3.869400978088379
# Time taken: 1061.21s
#
# Start of epoch 31
# Average training loss at epoch 31: 4.1687508
# Epoch val loss: 3.864720582962036
# Time taken: 1094.35s
#
# Start of epoch 32
# Average training loss at epoch 32: 4.1665158
# Epoch val loss: 3.8574047088623047
# Time taken: 1127.73s
#
# Start of epoch 33
# Average training loss at epoch 33: 4.1703873
# Epoch val loss: 3.8524670600891113
# Time taken: 1161.11s
#
# Start of epoch 34
# Average training loss at epoch 34: 4.1662664
# Epoch val loss: 3.8639509677886963
# Time taken: 1194.07s
#
# Start of epoch 35
# Average training loss at epoch 35: 4.1646709
# Epoch val loss: 3.877009391784668
# Time taken: 1227.18s
#
# Start of epoch 36
# Average training loss at epoch 36: 4.1661792
# Epoch val loss: 3.8531298637390137
# Time taken: 1260.31s
#
# Start of epoch 37
# Average training loss at epoch 37: 4.1607361
# Epoch val loss: 3.8605117797851562
# Time taken: 1293.80s
#
# Start of epoch 38
# Average training loss at epoch 38: 4.1543040
# Epoch val loss: 3.833554983139038
# Time taken: 1326.95s
#
# Start of epoch 39
# Average training loss at epoch 39: 4.1355801
# Epoch val loss: 3.8521957397460938
# Time taken: 1360.31s
#
# Start of epoch 40
# Average training loss at epoch 40: 4.1310883
# Epoch val loss: 3.867431163787842
# Time taken: 1393.34s
#
# Start of epoch 41
# Average training loss at epoch 41: 4.1394200
# Epoch val loss: 3.855875015258789
# Time taken: 1426.84s
#
# Start of epoch 42
# Average training loss at epoch 42: 4.1297140
# Epoch val loss: 3.86468768119812
# Time taken: 1460.06s
#
# Start of epoch 43
# Average training loss at epoch 43: 4.1271458
# Epoch val loss: 3.8276453018188477
# Time taken: 1493.45s
#
# Start of epoch 44
# Average training loss at epoch 44: 4.1253109
# Epoch val loss: 3.881946563720703
# Time taken: 1526.39s
#
# Start of epoch 45
# Average training loss at epoch 45: 4.1440854
# Epoch val loss: 3.8754992485046387
# Time taken: 1559.50s
#
# Start of epoch 46
# Average training loss at epoch 46: 4.1650486
# Epoch val loss: 3.8467371463775635
# Time taken: 1592.70s
#
# Start of epoch 47
# Average training loss at epoch 47: 4.1212602
# Epoch val loss: 3.8835935592651367
# Time taken: 1625.79s
#
# Start of epoch 48
# Average training loss at epoch 48: 4.1317739
# Epoch val loss: 3.867072582244873
# Time taken: 1659.08s
#
# Start of epoch 49
# Average training loss at epoch 49: 4.1379852
# Epoch val loss: 3.839691638946533
# Time taken: 1692.43s
#
# Start of epoch 50
# Average training loss at epoch 50: 4.1034279
# Epoch val loss: 3.8445088863372803
# Time taken: 1725.64s
#
# Start of epoch 51
# Average training loss at epoch 51: 4.1150870
# Epoch val loss: 3.84014892578125
# Time taken: 1759.08s
#
# Start of epoch 52
# Average training loss at epoch 52: 4.0908909
# Epoch val loss: 3.827704906463623
# Time taken: 1792.15s
#
# Start of epoch 53
# Average training loss at epoch 53: 4.1178122
# Epoch val loss: 3.8467040061950684
# Time taken: 1825.45s
#
# Start of epoch 54
# Average training loss at epoch 54: 4.0822601
# Epoch val loss: 3.8210432529449463
# Time taken: 1858.89s
#
# Start of epoch 55
# Average training loss at epoch 55: 4.1144238
# Epoch val loss: 3.8610925674438477
# Time taken: 1892.37s
#
# Start of epoch 56
# Average training loss at epoch 56: 4.0725651
# Epoch val loss: 3.8214340209960938
# Time taken: 1925.52s
#
# Start of epoch 57
# Average training loss at epoch 57: 4.0804100
# Epoch val loss: 3.838979482650757
# Time taken: 1958.63s
#
# Start of epoch 58
# Average training loss at epoch 58: 4.0643301
# Epoch val loss: 3.848400592803955
# Time taken: 1991.61s
#
# Start of epoch 59
# Average training loss at epoch 59: 4.0912762
# Epoch val loss: 3.8599190711975098
# Time taken: 2024.87s
#
# Start of epoch 60
# Average training loss at epoch 60: 4.0737658
# Epoch val loss: 3.8726725578308105
# Time taken: 2058.29s
#
# Start of epoch 61
# Average training loss at epoch 61: 4.0492182
# Epoch val loss: 3.8455686569213867
# Time taken: 2091.37s
#
# Start of epoch 62
# Average training loss at epoch 62: 4.0830078
# Epoch val loss: 3.8605451583862305
# Time taken: 2124.29s
#
# Start of epoch 63
# Average training loss at epoch 63: 4.0634851
# Epoch val loss: 3.877676248550415
# Time taken: 2157.96s
#
# Start of epoch 64
# Average training loss at epoch 64: 4.0603943
# Epoch val loss: 3.822549819946289
# Time taken: 2191.14s
#
# Start of epoch 65
# Average training loss at epoch 65: 4.0718884
# Epoch val loss: 3.8146767616271973
# Time taken: 2224.52s
#
# Start of epoch 66
# Average training loss at epoch 66: 4.0480700
# Epoch val loss: 3.7761054039001465
# Time taken: 2257.81s
#
# Start of epoch 67
# Average training loss at epoch 67: 4.0319934
# Epoch val loss: 3.8229660987854004
# Time taken: 2291.03s
#
# Start of epoch 68
# Average training loss at epoch 68: 4.0366125
# Epoch val loss: 3.836854934692383
# Time taken: 2324.26s
#
# Start of epoch 69
# Average training loss at epoch 69: 4.0397849
# Epoch val loss: 3.767791509628296
# Time taken: 2357.94s
#
# Start of epoch 70
# Average training loss at epoch 70: 4.0321474
# Epoch val loss: 3.734530448913574
# Time taken: 2391.10s
#
# Start of epoch 71
# Average training loss at epoch 71: 4.0355349
# Epoch val loss: 3.775146484375
# Time taken: 2424.25s
#
# Start of epoch 72
# Average training loss at epoch 72: 4.0648456
# Epoch val loss: 3.8939404487609863
# Time taken: 2457.42s
#
# Start of epoch 73
# Average training loss at epoch 73: 4.1013761
# Epoch val loss: 3.8567657470703125
# Time taken: 2490.76s
#
# Start of epoch 74
# Average training loss at epoch 74: 4.0858784
# Epoch val loss: 3.8023626804351807
# Time taken: 2524.34s
#
# Start of epoch 75
# Average training loss at epoch 75: 4.0550337
# Epoch val loss: 3.82395339012146
# Time taken: 2557.80s
#
# Start of epoch 76
# Average training loss at epoch 76: 4.0158739
# Epoch val loss: 3.824483633041382
# Time taken: 2591.33s
#
# Start of epoch 77
# Average training loss at epoch 77: 4.0608215
# Epoch val loss: 3.8444299697875977
# Time taken: 2624.37s
#
# Start of epoch 78
# Average training loss at epoch 78: 4.0272593
# Epoch val loss: 3.8024466037750244
# Time taken: 2657.49s
#
# Start of epoch 79
# Average training loss at epoch 79: 4.0351534
# Epoch val loss: 3.7910444736480713
# Time taken: 2690.67s
#
# Start of epoch 80
# Average training loss at epoch 80: 4.0162635
# Epoch val loss: 3.7982754707336426
# Time taken: 2723.77s
#
# Start of epoch 81
# Average training loss at epoch 81: 4.0140042
# Epoch val loss: 3.784426689147949
# Time taken: 2756.97s
#
# Start of epoch 82
# Average training loss at epoch 82: 4.0238132
# Epoch val loss: 3.857476234436035
# Time taken: 2790.12s
#
# Start of epoch 83
# Average training loss at epoch 83: 4.0172091
# Epoch val loss: 3.851595640182495
# Time taken: 2823.15s
#
# Start of epoch 84
# Average training loss at epoch 84: 4.0382938
# Epoch val loss: 3.812417507171631
# Time taken: 2856.37s
#
# Start of epoch 85
# Average training loss at epoch 85: 4.0436029
# Epoch val loss: 3.798550605773926
# Time taken: 2890.35s
#
# Start of epoch 86
# Average training loss at epoch 86: 4.0071468
# Epoch val loss: 3.7525553703308105
# Time taken: 2923.74s
#
# Start of epoch 87
# Average training loss at epoch 87: 3.9988594
# Epoch val loss: 3.7952523231506348
# Time taken: 2957.00s
#
# Start of epoch 88
# Average training loss at epoch 88: 3.9806445
# Epoch val loss: 3.849916934967041
# Time taken: 2990.55s
#
# Start of epoch 89
# Average training loss at epoch 89: 4.0461531
# Epoch val loss: 3.8498125076293945
# Time taken: 3024.01s
#
# Start of epoch 90
# Average training loss at epoch 90: 4.0284948
# Epoch val loss: 3.819343090057373
# Time taken: 3057.51s
#
# Start of epoch 91
# Average training loss at epoch 91: 4.0166116
# Epoch val loss: 3.7808477878570557
# Time taken: 3090.83s
#
# Start of epoch 92
# Average training loss at epoch 92: 3.9814558
# Epoch val loss: 3.758584499359131
# Time taken: 3124.49s
#
# Start of epoch 93
# Average training loss at epoch 93: 3.9936805
# Epoch val loss: 3.9385147094726562
# Time taken: 3157.64s
#
# Start of epoch 94
# Average training loss at epoch 94: 3.9862800
# Epoch val loss: 3.814898729324341
# Time taken: 3190.97s
#
# Start of epoch 95
# Average training loss at epoch 95: 4.0597334
# Epoch val loss: 3.820932149887085
# Time taken: 3224.27s
#
# Start of epoch 96
# Average training loss at epoch 96: 3.9750900
# Epoch val loss: 3.795085906982422
# Time taken: 3257.73s
#
# Start of epoch 97
# Average training loss at epoch 97: 3.9719868
# Epoch val loss: 3.8149306774139404
# Time taken: 3290.84s
#
# Start of epoch 98
# Average training loss at epoch 98: 4.0040913
# Epoch val loss: 3.966360569000244
# Time taken: 3324.71s
#
# Start of epoch 99
# Average training loss at epoch 99: 4.0525918
# Epoch val loss: 3.926976203918457
# Time taken: 3357.91s
#
# Start of epoch 100
# Average training loss at epoch 100: 4.0515018
# Epoch val loss: 3.978219509124756
# Time taken: 3391.65s
#
# Start of epoch 101
# Average training loss at epoch 101: 3.9726996
# Epoch val loss: 3.8338804244995117
# Time taken: 3424.83s
#
# Start of epoch 102
# Average training loss at epoch 102: 3.9747856
# Epoch val loss: 3.7930498123168945
# Time taken: 3458.33s
#
# Start of epoch 103
# Average training loss at epoch 103: 3.9916034
# Epoch val loss: 3.7925784587860107
# Time taken: 3491.66s
#
# Start of epoch 104
# Average training loss at epoch 104: 3.9671123
# Epoch val loss: 3.7759850025177
# Time taken: 3525.04s
#
# Start of epoch 105
# Average training loss at epoch 105: 3.9466143
# Epoch val loss: 3.8625338077545166
# Time taken: 3558.39s
#
# Start of epoch 106
# Average training loss at epoch 106: 3.9489288
# Epoch val loss: 3.7715530395507812
# Time taken: 3591.80s
#
# Start of epoch 107
# Average training loss at epoch 107: 3.9792163
# Epoch val loss: 3.8180081844329834
# Time taken: 3624.76s
#
# Start of epoch 108
# Average training loss at epoch 108: 3.9448552
# Epoch val loss: 3.819859504699707
# Time taken: 3658.18s
#
# Start of epoch 109
# Average training loss at epoch 109: 3.9080043
# Epoch val loss: 3.777981996536255
# Time taken: 3691.41s
#
# Start of epoch 110
# Average training loss at epoch 110: 3.9834714
# Epoch val loss: 3.858071804046631
# Time taken: 3724.43s
#
# Start of epoch 111
# Average training loss at epoch 111: 3.9450545
# Epoch val loss: 3.8091859817504883
# Time taken: 3757.80s
#
# Start of epoch 112
# Average training loss at epoch 112: 3.9209118
# Epoch val loss: 3.8688082695007324
# Time taken: 3791.08s
#
# Start of epoch 113
# Average training loss at epoch 113: 3.9353669
# Epoch val loss: 3.962552547454834
# Time taken: 3824.26s
#
# Start of epoch 114
# Average training loss at epoch 114: 3.9308393
# Epoch val loss: 3.8275818824768066
# Time taken: 3857.73s
#
# Start of epoch 115
# Average training loss at epoch 115: 3.9108329
# Epoch val loss: 3.7683444023132324
# Time taken: 3891.06s
#
# Start of epoch 116
# Average training loss at epoch 116: 3.9379909
# Epoch val loss: 3.8591203689575195
# Time taken: 3924.24s
#
# Start of epoch 117
# Average training loss at epoch 117: 3.9211655
# Epoch val loss: 3.7904298305511475
# Time taken: 3957.61s
#
# Start of epoch 118
# Average training loss at epoch 118: 3.9058819
# Epoch val loss: 3.8569884300231934
# Time taken: 3990.74s
#
# Start of epoch 119
# Average training loss at epoch 119: 3.8926368
# Epoch val loss: 3.8370800018310547
# Time taken: 4024.02s
#
# Start of epoch 120
# Average training loss at epoch 120: 3.8991740
# Epoch val loss: 3.8924736976623535
# Time taken: 4057.06s
#
# Start of epoch 121
# Average training loss at epoch 121: 3.9451528
# Epoch val loss: 3.948762893676758
# Time taken: 4090.12s
#
# Start of epoch 122
# Average training loss at epoch 122: 3.9123080
# Epoch val loss: 3.867183208465576
# Time taken: 4123.81s
#
# Start of epoch 123
# Average training loss at epoch 123: 3.8833418
# Epoch val loss: 3.9475913047790527
# Time taken: 4157.51s
#
# Start of epoch 124
# Average training loss at epoch 124: 3.8600521
# Epoch val loss: 3.9509551525115967
# Time taken: 4190.80s
#
# Start of epoch 125
# Average training loss at epoch 125: 3.8978570
# Epoch val loss: 3.975287437438965
# Time taken: 4224.10s
#
# Start of epoch 126
# Average training loss at epoch 126: 3.9136891
# Epoch val loss: 3.8150174617767334
# Time taken: 4257.15s
#
# Start of epoch 127
# Average training loss at epoch 127: 3.8984897
# Epoch val loss: 3.864279270172119
# Time taken: 4290.22s
#
# Start of epoch 128
# Average training loss at epoch 128: 3.8606544
# Epoch val loss: 3.858757257461548
# Time taken: 4323.49s
#
# Start of epoch 129
# Average training loss at epoch 129: 3.8693707
# Epoch val loss: 3.9084911346435547
# Time taken: 4356.83s
#
# Start of epoch 130
# Average training loss at epoch 130: 3.8838153
# Epoch val loss: 4.030856132507324
# Time taken: 4390.34s
#
# Start of epoch 131
# Average training loss at epoch 131: 3.8465364
# Epoch val loss: 3.9823665618896484
# Time taken: 4423.38s
#
# Start of epoch 132
# Average training loss at epoch 132: 3.9398711
# Epoch val loss: 4.061822891235352
# Time taken: 4456.71s
#
# Start of epoch 133
# Average training loss at epoch 133: 3.8367982
# Epoch val loss: 3.878506660461426
# Time taken: 4489.69s
#
# Start of epoch 134
# Average training loss at epoch 134: 3.8408594
# Epoch val loss: 3.8814659118652344
# Time taken: 4523.22s
#
# Start of epoch 135
# Average training loss at epoch 135: 3.8717723
# Epoch val loss: 4.100160598754883
# Time taken: 4556.34s
#
# Start of epoch 136
# Average training loss at epoch 136: 3.8230250
# Epoch val loss: 4.015591144561768
# Time taken: 4589.70s
#
# Start of epoch 137
# Average training loss at epoch 137: 3.8402612
# Epoch val loss: 4.032068252563477
# Time taken: 4623.26s
#
# Start of epoch 138
# Average training loss at epoch 138: 3.8994069
# Epoch val loss: 3.958682060241699
# Time taken: 4656.64s
#
# Start of epoch 139
# Average training loss at epoch 139: 3.8272853
# Epoch val loss: 3.973168134689331
# Time taken: 4689.56s
#
# Start of epoch 140
# Average training loss at epoch 140: 3.8143818
# Epoch val loss: 4.043384552001953
# Time taken: 4723.03s
#
# Start of epoch 141
# Average training loss at epoch 141: 3.8576894
# Epoch val loss: 4.158677101135254
# Time taken: 4756.29s
#
# Start of epoch 142
# Average training loss at epoch 142: 3.8374250
# Epoch val loss: 4.143728733062744
# Time taken: 4789.72s
#
# Start of epoch 143
# Average training loss at epoch 143: 3.8664775
# Epoch val loss: 4.213689804077148
# Time taken: 4822.87s
#
# Start of epoch 144
# Average training loss at epoch 144: 3.8707032
# Epoch val loss: 4.316852569580078
# Time taken: 4856.26s
#
# Start of epoch 145
# Average training loss at epoch 145: 3.8662453
# Epoch val loss: 4.156904220581055
# Time taken: 4889.10s
#
# Start of epoch 146
# Average training loss at epoch 146: 3.8300407
# Epoch val loss: 4.081398010253906
# Time taken: 4922.37s
#
# Start of epoch 147
# Average training loss at epoch 147: 3.7893050
# Epoch val loss: 4.075542449951172
# Time taken: 4955.46s
#
# Start of epoch 148
# Average training loss at epoch 148: 3.7740889
# Epoch val loss: 4.068209648132324
# Time taken: 4988.43s
#
# Start of epoch 149
# Average training loss at epoch 149: 3.7347686
# Epoch val loss: 3.956892251968384
# Time taken: 5021.35s
#
# Start of epoch 150
# Average training loss at epoch 150: 3.7966800
# Epoch val loss: 4.022008419036865
# Time taken: 5054.71s
#
# Start of epoch 151
# Average training loss at epoch 151: 3.7601252
# Epoch val loss: 4.131270408630371
# Time taken: 5087.90s
#
# Start of epoch 152
# Average training loss at epoch 152: 3.7650247
# Epoch val loss: 3.8982203006744385
# Time taken: 5121.38s
#
# Start of epoch 153
# Average training loss at epoch 153: 3.7382243
# Epoch val loss: 4.0962724685668945
# Time taken: 5154.45s
#
# Start of epoch 154
# Average training loss at epoch 154: 3.7914777
# Epoch val loss: 4.125767707824707
# Time taken: 5187.89s
#
# Start of epoch 155
# Average training loss at epoch 155: 3.7849300
# Epoch val loss: 4.123132705688477
# Time taken: 5220.94s
#
# Start of epoch 156
# Average training loss at epoch 156: 3.7291265
# Epoch val loss: 4.1856207847595215
# Time taken: 5254.24s
#
# Start of epoch 157
# Average training loss at epoch 157: 3.7330265
# Epoch val loss: 4.03084659576416
# Time taken: 5287.43s
#
# Start of epoch 158
# Average training loss at epoch 158: 3.7934861
# Epoch val loss: 4.15352725982666
# Time taken: 5320.55s
#
# Start of epoch 159
# Average training loss at epoch 159: 3.7338068
# Epoch val loss: 4.0595197677612305
# Time taken: 5353.44s
#
# Start of epoch 160
# Average training loss at epoch 160: 3.7163887
# Epoch val loss: 4.238358497619629
# Time taken: 5386.67s
#
# Start of epoch 161
# Average training loss at epoch 161: 3.7825022
# Epoch val loss: 4.158562660217285
# Time taken: 5419.90s
#
# Start of epoch 162
# Average training loss at epoch 162: 3.7316604
# Epoch val loss: 4.202455997467041
# Time taken: 5453.87s
#
# Start of epoch 163
# Average training loss at epoch 163: 3.7327147
# Epoch val loss: 3.91746187210083
# Time taken: 5487.28s
#
# Start of epoch 164
# Average training loss at epoch 164: 3.8288250
# Epoch val loss: 3.8177943229675293
# Time taken: 5520.33s
#
# Start of epoch 165
# Average training loss at epoch 165: 3.7925487
# Epoch val loss: 3.965717315673828
# Time taken: 5553.40s
#
# Start of epoch 166
# Average training loss at epoch 166: 3.7982309
# Epoch val loss: 4.0072221755981445
# Time taken: 5586.88s
#
# Start of epoch 167
# Average training loss at epoch 167: 3.6993327
# Epoch val loss: 3.8399674892425537
# Time taken: 5619.98s
#
# Start of epoch 168
# Average training loss at epoch 168: 3.7442708
# Epoch val loss: 3.9500484466552734
# Time taken: 5653.58s
#
# Start of epoch 169
# Average training loss at epoch 169: 3.6947384
# Epoch val loss: 4.005603790283203
# Time taken: 5686.41s
#
# Start of epoch 170
# Average training loss at epoch 170: 3.6635220
# Epoch val loss: 3.894434928894043
# Time taken: 5720.07s
#
# Start of epoch 171
# Average training loss at epoch 171: 3.7237883
# Epoch val loss: 3.982997417449951
# Time taken: 5753.13s
#
# Start of epoch 172
# Average training loss at epoch 172: 3.6742921
# Epoch val loss: 4.118675231933594
# Time taken: 5786.60s
#
# Start of epoch 173
# Average training loss at epoch 173: 3.6260519
# Epoch val loss: 4.186014175415039
# Time taken: 5819.40s
#
# Start of epoch 174
# Average training loss at epoch 174: 3.6751862
# Epoch val loss: 4.226189136505127
# Time taken: 5852.96s
#
# Start of epoch 175
# Average training loss at epoch 175: 3.7057753
# Epoch val loss: 4.1306657791137695
# Time taken: 5886.13s
#
# Start of epoch 176
# Average training loss at epoch 176: 3.6670358
# Epoch val loss: 4.274012565612793
# Time taken: 5919.75s
#
# Start of epoch 177
# Average training loss at epoch 177: 3.6659484
# Epoch val loss: 4.074573516845703
# Time taken: 5952.93s
#
# Start of epoch 178
# Average training loss at epoch 178: 3.6280601
# Epoch val loss: 4.049997329711914
# Time taken: 5986.15s
#
# Start of epoch 179
# Average training loss at epoch 179: 3.6575842
# Epoch val loss: 4.502409934997559
# Time taken: 6019.66s
#
# Start of epoch 180
# Average training loss at epoch 180: 3.6877384
# Epoch val loss: 3.9519202709198
# Time taken: 6053.09s
#
# Start of epoch 181
# Average training loss at epoch 181: 3.5914416
# Epoch val loss: 4.271989345550537
# Time taken: 6086.16s
#
# Start of epoch 182
# Average training loss at epoch 182: 3.5969996
# Epoch val loss: 4.069429397583008
# Time taken: 6119.53s
#
# Start of epoch 183
# Average training loss at epoch 183: 3.6647921
# Epoch val loss: 3.9547603130340576
# Time taken: 6152.47s
#
# Start of epoch 184
# Average training loss at epoch 184: 3.6085925
# Epoch val loss: 4.012959957122803
# Time taken: 6185.83s
#
# Start of epoch 185
# Average training loss at epoch 185: 3.5719719
# Epoch val loss: 4.125217437744141
# Time taken: 6219.07s
#
# Start of epoch 186
# Average training loss at epoch 186: 3.5334816
# Epoch val loss: 3.9741783142089844
# Time taken: 6252.15s
#
# Start of epoch 187
# Average training loss at epoch 187: 3.5124588
# Epoch val loss: 3.9607462882995605
# Time taken: 6285.31s
#
# Start of epoch 188
# Average training loss at epoch 188: 3.5496261
# Epoch val loss: 3.9369142055511475
# Time taken: 6318.76s
#
# Start of epoch 189
# Average training loss at epoch 189: 3.7300119
# Epoch val loss: 4.340014934539795
# Time taken: 6351.87s
#
# Start of epoch 190
# Average training loss at epoch 190: 3.6441865
# Epoch val loss: 4.60589599609375
# Time taken: 6385.35s
#
# Start of epoch 191
# Average training loss at epoch 191: 3.5662274
# Epoch val loss: 3.901871919631958
# Time taken: 6418.82s
#
# Start of epoch 192
# Average training loss at epoch 192: 3.5002446
# Epoch val loss: 4.073848724365234
# Time taken: 6452.16s
#
# Start of epoch 193
# Average training loss at epoch 193: 3.5053759
# Epoch val loss: 4.092223167419434
# Time taken: 6485.38s
#
# Start of epoch 194
# Average training loss at epoch 194: 3.5803070
# Epoch val loss: 4.29582405090332
# Time taken: 6518.79s
#
# Start of epoch 195
# Average training loss at epoch 195: 3.6278605
# Epoch val loss: 4.1982951164245605
# Time taken: 6552.12s
#
# Start of epoch 196
# Average training loss at epoch 196: 3.5590587
# Epoch val loss: 4.377066612243652
# Time taken: 6585.25s
#
# Start of epoch 197
# Average training loss at epoch 197: 3.4785056
# Epoch val loss: 4.000765800476074
# Time taken: 6619.02s
#
# Start of epoch 198
# Average training loss at epoch 198: 3.5368297
# Epoch val loss: 4.014471054077148
# Time taken: 6653.02s
#
# Start of epoch 199
# Average training loss at epoch 199: 3.5727434
# Epoch val loss: 4.197360992431641
# Time taken: 6686.41s
#
# Start of epoch 200
# Average training loss at epoch 200: 3.4371476
# Epoch val loss: 4.431204319000244
# Time taken: 6719.72s
#
# Start of epoch 201
# Average training loss at epoch 201: 3.4299421
# Epoch val loss: 4.499852657318115
# Time taken: 6753.17s
#
# Start of epoch 202
# Average training loss at epoch 202: 3.4344587
# Epoch val loss: 4.398522853851318
# Time taken: 6786.44s
#
# Start of epoch 203
# Average training loss at epoch 203: 3.4854722
# Epoch val loss: 4.009590148925781
# Time taken: 6819.70s
#
# Start of epoch 204
# Average training loss at epoch 204: 3.5526927
# Epoch val loss: 4.061643600463867
# Time taken: 6852.82s
#
# Start of epoch 205
# Average training loss at epoch 205: 3.6443419
# Epoch val loss: 3.91086745262146
# Time taken: 6885.95s
#
# Start of epoch 206
# Average training loss at epoch 206: 3.4328074
# Epoch val loss: 4.220062732696533
# Time taken: 6919.31s
#
# Start of epoch 207
# Average training loss at epoch 207: 3.4026599
# Epoch val loss: 4.0948591232299805
# Time taken: 6952.13s
#
# Start of epoch 208
# Average training loss at epoch 208: 3.4574804
# Epoch val loss: 4.018436431884766
# Time taken: 6985.99s
#
# Start of epoch 209
# Average training loss at epoch 209: 3.3861604
# Epoch val loss: 4.093872547149658
# Time taken: 7019.29s
#
# Start of epoch 210
# Average training loss at epoch 210: 3.5437472
# Epoch val loss: 4.252438545227051
# Time taken: 7052.57s
#
# Start of epoch 211
# Average training loss at epoch 211: 3.4503167
# Epoch val loss: 4.030878067016602
# Time taken: 7085.70s
#
# Start of epoch 212
# Average training loss at epoch 212: 3.4802992
# Epoch val loss: 3.901097297668457
# Time taken: 7118.92s
#
# Start of epoch 213
# Average training loss at epoch 213: 3.4894452
# Epoch val loss: 3.9759674072265625
# Time taken: 7152.43s
#
# Start of epoch 214
# Average training loss at epoch 214: 3.5202079
# Epoch val loss: 4.055577278137207
# Time taken: 7185.47s
#
# Start of epoch 215
# Average training loss at epoch 215: 3.4486785
# Epoch val loss: 4.298011779785156
# Time taken: 7218.37s
#
# Start of epoch 216
# Average training loss at epoch 216: 3.3471644
# Epoch val loss: 4.2049760818481445
# Time taken: 7251.32s
#
# Start of epoch 217
# Average training loss at epoch 217: 3.3352411
# Epoch val loss: 3.9160373210906982
# Time taken: 7284.31s
#
# Start of epoch 218
# Average training loss at epoch 218: 3.3585222
# Epoch val loss: 3.9763545989990234
# Time taken: 7317.46s
#
# Start of epoch 219
# Average training loss at epoch 219: 3.3634021
# Epoch val loss: 3.8487837314605713
# Time taken: 7350.69s
#
# Start of epoch 220
# Average training loss at epoch 220: 3.3499951
# Epoch val loss: 3.960078716278076
# Time taken: 7384.01s
#
# Start of epoch 221
# Average training loss at epoch 221: 3.2997124
# Epoch val loss: 4.088641166687012
# Time taken: 7417.58s
#
# Start of epoch 222
# Average training loss at epoch 222: 3.3275104
# Epoch val loss: 3.888362407684326
# Time taken: 7450.80s
#
# Start of epoch 223
# Average training loss at epoch 223: 3.2254047
# Epoch val loss: 3.865621566772461
# Time taken: 7484.27s
#
# Start of epoch 224
# Average training loss at epoch 224: 3.2626312
# Epoch val loss: 3.879887104034424
# Time taken: 7517.31s
#
# Start of epoch 225
# Average training loss at epoch 225: 3.4325359
# Epoch val loss: 4.213497161865234
# Time taken: 7550.84s
#
# Start of epoch 226
# Average training loss at epoch 226: 3.4239349
# Epoch val loss: 4.151756286621094
# Time taken: 7583.92s
#
# Start of epoch 227
# Average training loss at epoch 227: 3.1908410
# Epoch val loss: 3.7782087326049805
# Time taken: 7617.31s
#
# Start of epoch 228
# Average training loss at epoch 228: 3.3152194
# Epoch val loss: 4.0114240646362305
# Time taken: 7650.45s
#
# Start of epoch 229
# Average training loss at epoch 229: 3.4116740
# Epoch val loss: 3.966494560241699
# Time taken: 7683.78s
#
# Start of epoch 230
# Average training loss at epoch 230: 3.3243961
# Epoch val loss: 3.883000612258911
# Time taken: 7717.04s
#
# Start of epoch 231
# Average training loss at epoch 231: 3.2150185
# Epoch val loss: 3.80889892578125
# Time taken: 7750.19s
#
# Start of epoch 232
# Average training loss at epoch 232: 3.2505820
# Epoch val loss: 3.885547637939453
# Time taken: 7783.32s
#
# Start of epoch 233
# Average training loss at epoch 233: 3.3462384
# Epoch val loss: 3.8644020557403564
# Time taken: 7816.84s
#
# Start of epoch 234
# Average training loss at epoch 234: 3.3354955
# Epoch val loss: 3.9132399559020996
# Time taken: 7850.07s
#
# Start of epoch 235
# Average training loss at epoch 235: 3.2733870
# Epoch val loss: 3.966891288757324
# Time taken: 7883.35s
#
# Start of epoch 236
# Average training loss at epoch 236: 3.2384949
# Epoch val loss: 3.9662344455718994
# Time taken: 7916.38s
#
# Start of epoch 237
# Average training loss at epoch 237: 3.2956600
# Epoch val loss: 4.049219608306885
# Time taken: 7949.58s
#
# Start of epoch 238
# Average training loss at epoch 238: 3.2406979
# Epoch val loss: 3.979133129119873
# Time taken: 7982.71s
#
# Start of epoch 239
# Average training loss at epoch 239: 3.2228622
# Epoch val loss: 3.8001298904418945
# Time taken: 8016.21s
#
# Start of epoch 240
# Average training loss at epoch 240: 3.3379602
# Epoch val loss: 3.853466033935547
# Time taken: 8049.16s
#
# Start of epoch 241
# Average training loss at epoch 241: 3.1916771
# Epoch val loss: 3.8578498363494873
# Time taken: 8082.21s
#
# Start of epoch 242
# Average training loss at epoch 242: 3.2278132
# Epoch val loss: 3.90934419631958
# Time taken: 8115.25s
#
# Start of epoch 243
# Average training loss at epoch 243: 3.3486123
# Epoch val loss: 4.071102619171143
# Time taken: 8148.38s
#
# Start of epoch 244
# Average training loss at epoch 244: 3.1552668
# Epoch val loss: 4.119441509246826
# Time taken: 8181.52s
#
# Start of epoch 245
# Average training loss at epoch 245: 3.1674244
# Epoch val loss: 4.107471942901611
# Time taken: 8214.77s
#
# Start of epoch 246
# Average training loss at epoch 246: 3.1425350
# Epoch val loss: 3.95027756690979
# Time taken: 8248.14s
#
# Start of epoch 247
# Average training loss at epoch 247: 3.1571608
# Epoch val loss: 4.138387680053711
# Time taken: 8281.41s
#
# Start of epoch 248
# Average training loss at epoch 248: 3.0840163
# Epoch val loss: 4.015744209289551
# Time taken: 8314.37s
#
# Start of epoch 249
# Average training loss at epoch 249: 3.1097584
# Epoch val loss: 4.18032169342041
# Time taken: 8347.74s
# Tried making graph folder. Folder already exists...
# Tried making csv folder. Folder already exists...
# Total time taken: 8347.91s

# %% [markdown]
# # Plots on Train data

# %% [markdown]
# ### Reconstruction

# %%
#input = x_train[batch_size*10:batch_size*11]
input = x_train
print("Training shape: ", input.shape)
out1, out2, out3 = koopmanAEModel(input)
# Out:
# Training shape:  (16384, 6)

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %%
plt.rcParams['figure.figsize'] = [8, 4]
row,col = np.shape(input)

for i in range(col):
    plt.figure(i)
    plt.title("Batch Reconstruction")
    plt.plot(input[0:trajLength,i], label = "Ground Truth")
    plt.plot(out1[0:trajLength,i], '--', label="Reconstruction")
    plt.title("%dth State" % i)
    plt.legend()

# %%
plt.plot(out1[:,2], out1[:,3], label="Reconstruction")
plt.plot(input[:,2], input[:,3], '--', label="Ground Truth")
plt.legend()

# %% [markdown]
# ### Graphing Error Section

# %% [markdown]
# #### Average Error Function

# %%
def preProcessForAvg(input, numTraj_batch, trajLength, num_batches, desiredStates, model):
    '''
    Given input, the number of trajectory in each batch, and the trajectory length, outputs
    batch data concatenated vertically on top of one another by calling the Koopman AE class

    Parameters:
    -----------
    input: Tensor
        Input data to reshape into outputs
    numTraj_batch: int
        Number of trajectory per batch
    trajLength: int
        Number of snapshots in a trajectory
    desiredStates: list
        List of states
    model: Koopman AE keras model
        Koopman AE model to propagate data

    Return:
    ----------
    x1_all: tensor
        Copy of input (No need for change) (Ground Truth)
    x2_all: tensor
        Concatenated tensor of 1 time shifted data for all batches (Ground Truth)
    x3_all: tensor
        Concatenated tensor of 1 time step shifted data for all batches (x2_all=x3_all) (Ground Truth)
    out1_all: tensor
        Reconstruction of input (parameter) using the Koopman AE class
    out2_all: tensor
        Predicted output from Koopman model of concatenated tensors of 1 time shifted data for all batches
    out3_all: tensor
        Predicted n time step output from Koopman model of concatenated tensors data for all batches
    '''
    
    x2_all = []
    out1_all = []
    out2_all = []
    out3_all = []
    x = input


    # Loop through num of batches
    for i in range(num_batches):
        x2 = []
        # Within each batch, loop through trajectory number
        for j in range(numTraj_batch):
            x2.append(x[(i*numTraj_batch+j)*trajLength+1:(i*numTraj_batch+j+1)*trajLength])
        x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input for a batch
        x2_all.append(x2)
        
        x_input = x[i*numTraj_batch*trajLength:(i+1)*numTraj_batch*trajLength]
        out1, out2, out3 = model(x_input)
        out1_all.append(out1)
        out2_all.append(out2)
        out3_all.append(out3)
        
    x1_all = x
    x2_all = tf.reshape(x2_all,(-1,len(desiredStates)))
    x3_all = x2_all
    out1_all = tf.reshape(out1_all,(-1,len(desiredStates)))
    out2_all = tf.reshape(out2_all,(-1,len(desiredStates)))
    out3_all = tf.reshape(out3_all,(-1,len(desiredStates)))


    '''
    print(tf.shape(x2_all))
    print(tf.shape(out1_all))
    print(tf.shape(out2_all))
    print(tf.shape(out3_all))
    '''

    return x1_all, x2_all, x3_all, out1_all, out2_all, out3_all

# %%
def avgTrajError(gTruth, predicted, trajLength, numTraj):
    '''
    Get the average trajectory error

    Parameters:
    -----------
    gTruth: tensor or ndarray
        Ground Truth matrix
    predicted: tensor or ndarray
        Predicted matrix
    trajLength: int
        Length of trajectory
    numTraj: int
        Number of trajectory (total?)
    

    Return:
    ----------
    avgErrorList: list
        List of average errors of all trajectories (each index is the avg error of the states at a point of time along the trajectory)
    
    errorList: list
        List of error of all states and trajectory
    '''
    errorList = []
    avgErrorList = []
    numStates = len(gTruth[0,:])
    for i in range(numTraj):
        '''
        print("Gtruth")
        print(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:])
        print("Predicted")
        print(np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
        print("---Loop---")
        '''
        errorList.append(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:] - np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
    
    #print("Error List")
    #print(np.shape(errorList[0]))
    
    for j in range(trajLength):
        #print("Length of Traj %d"% j)
        for k in range(numTraj):
            #print("Traj: %d"% k)
            if k == 0:
                avgErrorList.append(errorList[k][j,:])
            else:
                #print(avgErrorList[j])
                avgErrorList[j] = (k*avgErrorList[j]+errorList[k][j,:])/(k+1) # Recursive average formula
    return avgErrorList, errorList

# %% [markdown]
# #### Preprocess Error Graph Data

# %%
saveErrorPath = 'errorGraph/'
try:
    os.mkdir(saveErrorPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
x1_all,x2_all,x3_all, out1_all,out2_all,out3_all = preProcessForAvg(x_train,numTraj_batch, trajLength, num_batches_train, desiredStates, koopmanAEModel)
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)

# %%
print(x2_all.shape)
# Out:
# (16128, 6)

# %% [markdown]
# #### Error Graphs

# %% [markdown]
# ##### Reconstruction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i],
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Reconstruction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'recon_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ##### Forward Time Shift Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i], 
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Forward Time Shift Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'ftimeShift_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ##### Linearity Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i], 
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Linear Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'linPred_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ### Reconstruction/Forward Time Shift Prediction/Linear Prediction Graph

# %%
saveOutputPath = 'outputGraph/'
try:
    os.mkdir(saveOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x1_all[:1000,i])
    plt.plot(out1_all[:1000,i],'--',label="")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.savefig(saveOutputPath+'recon_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x2_all[:1000,i])
    plt.plot(out2_all[:1000,i],'--',label="")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.savefig(saveOutputPath+'ftimeShiftPred_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x3_all[:1000,i])
    plt.plot(out3_all[:1000,i],'--',label="")
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.38,0.44))
    plt.savefig(saveOutputPath+'linPred_'+title+'.png', dpi=300)
    plt.close()

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %% [markdown]
# # Animate Graphs

# %% [markdown]
# ## Animate Setup

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
def animateStatesError(middleLine, boundLine, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifBoundLine=True, xlim=[0,128], ylim=[0,1]):
    '''
    Given the average trajectory error, standard deviation error, and desired states,
    animate the trajectory with given legend into a mp4 under the mp4 folder

    Parameters:
    -----------
    middleLine: ndarray
        Trajectory of the middle line (nxlen(desiredStates))
    boundLine: ndarray
        Trajectory of the bound for upper and lower bound (+/- stdDev)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line
    xlim: list
        Limit of plot axis in x direction
    ylim: list
        Limit of axis in y direction


    Return:
    ---------
    None
    '''
    for j in range(np.shape(middleLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        line, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " "))
        plt.style.use('default')
        plt.legend()
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])

            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(middleLine[0:i,j]))
            data = middleLine[0:i,j] #select data range
            line.set_data(x,data)
            line.set_color('#1f77b4')
        
            if ifBoundLine:
                p = plt.fill_between(range(len(boundLine[0:i,j])), middleLine[0:i,j]-boundLine[0:i,j], 
                                middleLine[0:i,j]+boundLine[0:i,j], facecolor='lightsteelblue')
                return line, p,
            else:
                return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=128,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %%
def animateStates(predictedLine, gTruthLine, label1, label2, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifGTruthLine=True, xlim=[0,128], ylim=[0,1]):
    '''
    Given the predicted and ground truth trajectory, as well as desired states,
    animate the trajectory with given legend into a mp4 under the mp4FilePath folder

    Parameters:
    -----------
    predictedLine: ndarray
        Trajectory of the predicted line (nxlen(desiredStates))
    gTruthLine: ndarray
        Trajectory of the ground truth line (+/- stdDev)
    label1: str
        Label for predicted line (suffix)
    label2: str
        Label for ground truth line (suffix)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line
    xlim: list
        Limit of plot axis in x direction
    ylim: list
        Limit of axis in y direction
        
    Return:
    ---------
    None
    '''
    for j in range(np.shape(predictedLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        line, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " ") + " " + label1)
        line.set_color('C1')
        plt.setp(line, linestyle='--')
        if ifGTruthLine:
            line2, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " ") + " " + label2)
            line2.set_color('C0')
            #plt.setp(line2, linestyle='--')
        
        plt.style.use('default')
        plt.legend(loc='upper left')
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])
            if ifGTruthLine:
                line2.set_data([],[])
            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(predictedLine[0:i,j]))
            data = predictedLine[0:i,j] #select data range
            line.set_data(x,data)
            if ifGTruthLine:
                line2.set_data(x, gTruthLine[0:i,j])
          
            return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=256,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %% [markdown]
# ## Animation Graphs

# %% [markdown]
# Trajectory

# %%
animateStates(x1_all, x1_all, 'State Trajectory', 'State Trajectory', desiredStates, 'trajectory', ifGTruthLine=False)

# %% [markdown]
# Error

# %%
# Reconstruction Error
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_recon_error')

# Forward Time Shift Prediction Error
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_fTimeShiftPred_error')

# Linear Prediction Error
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_linPred_error')

# %% [markdown]
# Trajectory

# %%
animateStates(out1_all,x1_all,'Reconstruction','Truth',  desiredStates, 'train_traj_recon')
animateStates(out2_all,x2_all,'Forward Time Shift','Truth', desiredStates, 'train_traj_FTimeShiftPred')
animateStates(out3_all,x3_all,'Lin Pred','Truth', desiredStates, 'train_traj_linPred')

# %% [markdown]
# # Save the Model

# %%
koopmanAEModel.save('checkpoints/champ_Trained_Model')
# Out:
# INFO:tensorflow:Assets written to: checkpoints/champ_Trained_Model\assets

# %% [markdown]
# # Load the Model

# %%
new_model = tf.keras.models.load_model('checkpoints/champ_Trained_Model', compile=False)
new_model.summary()
# Out:
# Model: "Koopman_AE_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_model (EncoderModel) multiple                  396544
# _________________________________________________________________
# koopman__model (Koopman_Mode multiple                  65536
# _________________________________________________________________
# decoder_model (DecoderModel) multiple                  264710
# =================================================================
# Total params: 726,790
# Trainable params: 726,790
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = x_train
new_out1, new_out2, new_out3 = new_model(input)

# %% [markdown]
# # Plots on Test Data

# %% [markdown]
# ## Test Graphs

# %%
saveTestOutputPath = 'testOutputGraph/'
try:
    os.mkdir(saveTestOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
input = doggo_test
new_out1, new_out2, new_out3 = new_model(input)

# %%
nx1_all,nx2_all,nx3_all,nout1_all,nout2_all,nout3_all = preProcessForAvg(input,numTraj_batch,trajLength,num_batches_val,desiredStates, new_model)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx1_all[:,i], label="Ground Truth")
    plt.plot(nout1_all[:,i],'--',label="Reconstruction")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_recon_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx2_all[:,i], label="Ground Truth")
    plt.plot(nout2_all[:,i],'--',label="Predicted")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.3, 0.6))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_fTimeShift_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx3_all[:,i], label="Ground Truth", linewidth=2)
    plt.plot(nout3_all[:,i],'--',label="Predicted", linewidth=2)
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.38,0.44))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_linPred_'+title+'.png', dpi=300)
    plt.close()

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %% [markdown]
# ## Error Graphs on Test

# %%
avgTrajErrorList, errorList = avgTrajError(nx1_all, nout1_all, trajLength, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Reconstruction Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.25,0.25))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_recon_error_'+title+'.png', dpi=300)
    plt.close()

# %%
avgTrajErrorList, errorList = avgTrajError(nx2_all, nout2_all, trajLength-1, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Forward Time Shift Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.003,0.003))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_FTimeShift_error_'+title+'.png', dpi=300)
    plt.close()

# %%
avgTrajErrorList, errorList = avgTrajError(nx3_all, nout3_all, trajLength-1, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Linear Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.003,0.003))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_LinPred_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ## Phase Portrait

# %%
plt.plot(nx1_all[:,0], nx1_all[:,1], label="Ground Truth")
plt.plot(nout1_all[:,0], nout1_all[:,1], linestyle='--',label="Reconstruction")
title = 'Phase Reconstruction'
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_' +title+'.png', dpi=300)
plt.close()


plt.plot(nx2_all[:,0], nx2_all[:,1], label="Ground Truth")
plt.plot(nout1_all[:,0], nout1_all[:,1], linestyle='--',label="Forward Time Shift")
title = "Forward Time Shift"
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()


plt.plot(nx3_all[:,0], nx3_all[:,1], label="Ground Truth")
plt.plot(nout3_all[:,0], nout3_all[:,1], linestyle='--',label="Linear Prediction")
title = "Linear Prediction"
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()

# %%
plt.plot(nx1_all[:,2], nx1_all[:,3], label="Ground Truth")
plt.plot(nout1_all[:,2], nout1_all[:,3], linestyle='--',label="Reconstruction")
title = 'Phase Reconstruction Lower Leg'
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_' +title+'.png', dpi=300)
plt.close()


plt.plot(nx2_all[:,2], nx2_all[:,3], label="Ground Truth")
plt.plot(nout1_all[:,2], nout1_all[:,3], linestyle='--',label="Forward Time Shift")
title = "Forward Time Shift Lower Leg"
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()


plt.plot(nx3_all[:,2], nx3_all[:,3], label="Ground Truth")
plt.plot(nout3_all[:,2], nout3_all[:,3], linestyle='--',label="Linear Prediction")
title = "Linear Prediction Lower Leg"
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()

# %% [markdown]
# ## Animation on Test

# %%
avgTrajErrorList, errorList = avgTrajError(nx1_all, nout1_all, trajLength, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_recon_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx2_all, nout2_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_fTimeShiftPred_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx3_all, nout3_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_linPred_error', mp4FilePath, ifBoundLine=False)

# %% [markdown]
# Trajectory

# %%
animateStates(nout1_all,nx1_all,'Reconstruction','Truth',  desiredStates, 'test_traj_recon',xlim=[0,256])
animateStates(nout2_all,nx2_all,'Forward Time Shift','Truth', desiredStates, 'test_traj_FTimeShiftPred',xlim=[0,256])
animateStates(nout3_all,nx3_all,'Lin Pred','Truth', desiredStates, 'test_traj_linPred', xlim=[0,256])

# %% [markdown]
# # Koopman Eigenvalues

# %%
w,v = np.linalg.eig(new_model.koopman.get_weights())
fig = plt.figure(figsize=(5.5,5))
ax = fig.add_subplot(1,1,1)
circ = plt.Circle((0, 0), radius=1, edgecolor='black', facecolor='None')
ax.add_patch(circ)
plt.scatter(w.real.squeeze(), w.imag.squeeze())
title = "Koopman Eigenvalues - Empty Ground"
plt.title(title)
plt.savefig(saveTestOutputPath+'test_'+title+'.png', dpi=300)
plt.close()
