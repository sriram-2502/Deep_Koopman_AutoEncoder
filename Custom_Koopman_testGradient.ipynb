# %% [markdown]
# # Implement a custom Autoencoder with Koopman layer

# %% [markdown]
# ## Version Control

# %% [markdown]
# To Do:
# 1) Account for trailing batch - Make robust (fixed issue by reshaping input data)
# 2) Get Koopman operator, K
# 3) Preprocess Data
# 4) Make sure sim data is different for different ground parameters
# 5) Use static Koopman AE to train and get Koopman

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow import keras
from sklearn.model_selection import train_test_split
import  numpy as np
import pandas as pd
import time 
import os

# %%
plt.rcParams['figure.figsize'] = [9, 6]
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
#from google.colab import drive
#drive.mount('/gdrive')

# %% [markdown]
# Comment out if don't need

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data

# %% [markdown]
# **Dyanmics of the Simple Pendulum**
#
#
# ![dynamics](\images\dynamics.PNG)
#
#
# $\lambda = -1$
# $\mu = -0.05$

# %%
discrete_train = pd.read_csv('data/DiscreteSpectrumExample_train1_x.csv', sep=',', header=None).values
discrete_test =pd.read_csv('data/DiscreteSpectrumExample_test_x.csv', sep=',', header=None).values
discrete_validation = pd.read_csv('data/DiscreteSpectrumExample_val_x.csv', sep=',', header=None).values

# %%
trajLength = 64 #length of each trajectory in the dataset
numTraj = 1024 #total number of trajectories in the dataset
batch_size = int(512) # Number of snapshots in each batch

numTraj_batch = int(batch_size/trajLength)
input_dim = 2

num_batches = 10

# %%
# Normalize the data
min_val = tf.reduce_min(discrete_train)
max_val = tf.reduce_max(discrete_train)

discrete_train = (discrete_train - min_val) / (max_val - min_val)
discrete_validation = (discrete_validation - min_val) / (max_val - min_val)
discrete_test = (discrete_test - min_val) / (max_val - min_val)


#train_data = tf.cast(discrete_train, tf.float32)
#validation_data = tf.cast(discrete_validation, tf.float32)
test_data = tf.cast(discrete_test, tf.float32)

train_data = tf.cast(discrete_train[0:batch_size*num_batches], tf.float32)
validation_data = tf.cast(discrete_validation[0:batch_size*num_batches], tf.float32)
validation_data = tf.data.Dataset.from_tensor_slices((validation_data, validation_data)).batch(batch_size)

# %% [markdown]
# ## Preprocess data

# %%
x_train = train_data
y_train = train_data

tf.shape(x_train)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([5120,    2])>

# %%
trail = train_data[trajLength*100:trajLength*110,:]
plt.grid()
plt.plot(x_train) #51 samples for each trajectory
plt.title("x1 and x2 vs time")
plt.show()

# %% [markdown]
# # Custom Model definition

# %% [markdown]
# ## Encoder

# %%
class EncoderLayer(keras.layers.Layer):
    """
    Custom class to create a encoder layer
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * x + b: tensor
        linear combination of weights times input + bias for the layer
    """
    
    def __init__(self, units=32, name=None):
        super(EncoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Encoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, inputs):
        #print("Encoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(inputs, self.w) + self.b

# %%
class EncoderModel(keras.Model):
    """
    Custom Model to create an encoder with one input
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    """
    
    def __init__(self, name=None):
        super(EncoderModel, self).__init__(name=name)
        self.enc1 = EncoderLayer(32)
        self.enc2 = EncoderLayer(64)
        self.enc3 = EncoderLayer(128)

    def call(self, input):
        x = input
        x = self.enc1(x)
        x = tf.nn.elu(x)
        x = self.enc2(x)
        x = tf.nn.elu(x)

        # Encoder output layer
        z = self.enc3(x)
        z = tf.nn.elu(z)
        return z

# %% [markdown]
# ## Koopman

# %%
class KoopmanLayer(keras.layers.Layer):
    """
    Custom class to calculate the Koopman operator K on latent variables
    Adds a linear loss as mse(Z2-Z2_tilde)
    
    Parameters
    ----------
    Z: tensor 
        inputs are the latent variabes (output from encoder)
        input dimension is (m, 128)
        m is the number of time snapshots for each input dimension of X
        128 is the number of latent varibales (observables)

    Return
    ----------
    Z: tensor
        return the original input Z 

    Z2_tilde: tensor
        return the prediction by linearity from K (z2_tilde = K^m * z(1,:))
    """

    def __init__(self, trajLength, numTraj):
        super(KoopmanLayer, self).__init__()
        self.trajLength = trajLength
        self.numTraj = numTraj

    def build(self, Z):
        # Initialize K as a weight
            self.K =  self.add_weight(
                name = 'Koopman_weight',
                shape=(Z[-1], Z[-1]),
                initializer="random_normal",
                trainable=True,
            )

    def timeShift(self,Z,latent_dim):
        '''
        Shifts trajectories one time step
        Parameters:
        -----------
            Z: tensor
                Batch data of latent variables (in the lifted space)
                
            latent_dim: tensor shape
                Dimension of the lifted space (columns of Z)
        '''
        Z1 = []
        z1 = []
        Z2 = []

        for i in range(self.numTraj):
            Z1.append(Z[i*self.trajLength:(i+1)*self.trajLength-1,:])
            Z2.append(Z[i*self.trajLength+1:(i+1)*self.trajLength,:])
            z1.append(Z[i*self.trajLength,:])
        return tf.reshape(Z1, [-1, latent_dim]), tf.reshape(Z2, [-1, latent_dim]), tf.reshape(z1, [-1, latent_dim])       

    def call(self, Z):
        latent_dim = tf.shape(Z)[1]
        shift_len = (self.trajLength-1)*self.numTraj # length of rows for forward time shifted Z
        Z1, Z2, z1 = self.timeShift(Z,latent_dim)

        # Find Z2_tilde
        Z2_tilde = tf.zeros([shift_len, latent_dim], dtype=tf.float32)
        for traj in range(self.numTraj): # loop over numnber of traj
            for m in range(self.trajLength-1): #loop over snapshots in each traj
                 indices = tf.constant([[traj*self.trajLength]])
                 if m == 0: 
                     updates = [tf.linalg.matvec(self.K, z1[0,:])]
                     tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                 else:
                    updates = [tf.linalg.matvec(tf.matmul(self.K,self.K), z1[traj,:])]
                    tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                    
        # Find linear loss
        Linear_loss = tf.reduce_mean(tf.square(Z2-Z2_tilde))
        self.add_loss(Linear_loss)
        
        # prints for debugging dimensions
        #print("Koopman layer, K",tf.shape(K))
        #print("Koopman layer, m",tf.shape(m))
        #print("Koopman layer, Z",tf.shape(Z))
        #print("Koopman layer, z1",tf.shape(z1))
        #print("Koopman layer, Z2 ",tf.shape(Z2))
        #print("Koopman layer, Z2_tilde",tf.shape(Z2_tilde))
        
        return Z, tf.matmul(Z1,self.K), Z2_tilde,

# %%
class Koopman_Model(keras.Model):
    """
    Custom Model to create an encoder with koopman layer
    
    Parameters
    ----------
    input: tensor 
        z - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space

    z2_tilde: tensor
        Latent variables of prediction obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    K: tensor
        Koopman operator in the lifted space
    """
    
    def __init__(self, trajLength, numTraj , name=None):
        super(Koopman_Model, self).__init__(name=name)
        self.koopman = KoopmanLayer(trajLength,numTraj)


    def call(self, input):
        z = input
        z, Z2_hat , Z2_tilde= self.koopman(z)
        return z, Z2_hat, Z2_tilde

# %% [markdown]
# ## Decoder

# %%
class DecoderLayer(keras.layers.Layer):
    """
    Custom class to create a decoder layer with two inputs
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * input1 + b: tensor
        linear combination of weights times input1 + bias for the layer
        
    W.T * input2 + b: tensor
        linear combination of weights times input2 + bias for the layer
    """

    def __init__(self, units=32, name=None):
        super(DecoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Decoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, input1, input2, input3):
        #print("Decoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(input1, self.w) + self.b, tf.matmul(input2, self.w) + self.b, tf.matmul(input3, self.w)

# %%
class DecoderModel(keras.Model):
    """
    Custom Model to create a decoder with two inputs
    
    Parameters
    ----------
    input 1: tensor 
        z - the lifted output of the koopman layer (encoder output)
    
    input 2: tensor 
        z2_tilde - obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    """
    
    def __init__(self, name=None):
        super(DecoderModel, self).__init__(name=name)
        self.dec1 = DecoderLayer(64)
        self.dec2 = DecoderLayer(32)
        self.outputLayer = DecoderLayer(2)

    def call(self, input1, input2, input3):
        z = input1
        z2_hat = input2
        z2_tilde = input3

        z, z2_hat, z2_tilde = self.dec1(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec2(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        # Decoder output layer
        x_hat, x2_hat, x2_tilde = self.outputLayer(z, z2_hat, z2_tilde)
        x_hat = tf.nn.elu(x_hat)
        x2_hat = tf.nn.elu(x2_hat)
        x2_tilde = tf.nn.elu(x2_tilde)

        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# ## Koopman Autoencoder

# %%
class Koopman_AE_Model(keras.Model):
    """
    Custom Model to create a Koopman Autoencoder
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    """
    
    def __init__(self, trajLength, numTraj , name=None):
        super(Koopman_AE_Model, self).__init__(name=name)
        self.enc = EncoderModel()
        self.koopman = Koopman_Model(trajLength, numTraj)
        self.dec = DecoderModel()

    def call(self, input):
        x = input
        z = self.enc(x)
        z, z2_hat, z2_tilde = self.koopman(z)
        x_hat, x2_hat, x2_tilde = self.dec(z, z2_hat, z2_tilde)
        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# # Custom Training Loop

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.batch(batch_size)

# %%
koopmanAEModel = Koopman_AE_Model(trajLength, numTraj_batch, name="Koopman_AE_Model")

# %%
def tot_loss(model, x, x_hat, x2_hat, x2_tilde):
    """Calculates total loss as sum of recon_loss + predict_loss + Koopman_loss"""
    #alpha1 = 0.1, alpha2 = 1e-7, alpha3 = 1e-15
    alpha1 = 1

    x2 = []
    for i in range(numTraj_batch):
        x2.append(x[i*trajLength+1:(i+1)*trajLength])
    x2 = tf.reshape(x2, [-1, x_train.shape[-1]])


    recon_loss = tf.reduce_mean(tf.abs(x-x_hat))
    predict_loss = tf.reduce_mean(tf.abs(x2-x2_hat))
    lin_loss = tf.reduce_mean(tf.abs(x2-x2_tilde))
    return alpha1 * (recon_loss + predict_loss) + lin_loss + sum(model.losses)

# %%
# Preprocess data
train_ds = tf.data.Dataset.from_tensor_slices((train_data, train_data)).batch(batch_size)

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(1e-4)

epochs = 10          

epoch_train_loss = [] # total loss for each epoch
epoch_validation_loss = []

for epoch in range(epochs):

    print("\nStart of epoch %d" % (epoch,))
    start_time = time.time()

    batch_train_loss_list = [] # total loss for each batch 
    batch_validation_loss_list = []
    
    print("\nStart of epoch %d" % (epoch,))
    start_time = time.time()

    # Iterate over the train batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
        batch_train_loss = 0
        with tf.GradientTape() as tape:
            #batch_length =  len(x_batch_train) #num elements in each batch
            reconstruction, prediction, linarity = koopmanAEModel(x_batch_train)
            # total avg loss for each batch
            batch_train_loss = tot_loss(koopmanAEModel, y_batch_train, reconstruction, prediction, linarity)
            batch_train_loss_list.append(batch_train_loss)

        grads = tape.gradient(batch_train_loss, koopmanAEModel.trainable_variables)
        optimizer.apply_gradients(zip(grads, koopmanAEModel.trainable_variables))
            
        # Log every 100 batches.
        if step % 1 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(batch_train_loss))
            )
    
    # outside batch loop
    avg_train_loss = np.sum(batch_train_loss_list)/num_batches
    epoch_train_loss.append(avg_train_loss)

    print(
            "Average training loss at epoch %d: %.4f"
            % (epoch, float(avg_train_loss))
        )
    print("Time taken: %.2fs" % (time.time() - start_time))
    print("Sum of Koopman Layer weights: %0.3f" % np.sum(koopmanAEModel.koopman.get_weights()[0]))
# Out:
# Start of epoch 0
#
# Start of epoch 0
# Training loss (for one batch) at step 0: 1.6151
# Training loss (for one batch) at step 1: 1.4378
# Training loss (for one batch) at step 2: 1.3192
# Training loss (for one batch) at step 3: 1.5334
# Training loss (for one batch) at step 4: 1.2655
# Training loss (for one batch) at step 5: 1.2772
# Training loss (for one batch) at step 6: 1.0223
# Training loss (for one batch) at step 7: 1.5006
# Training loss (for one batch) at step 8: 1.1590
# Training loss (for one batch) at step 9: 1.0107
# Average training loss at epoch 0: 1.3141
# Time taken: 4.06s
# Sum of Koopman Layer weights: 4.704
#
# Start of epoch 1
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 1.3724
# Training loss (for one batch) at step 1: 1.2390
# Training loss (for one batch) at step 2: 1.1369
# Training loss (for one batch) at step 3: 1.2843
# Training loss (for one batch) at step 4: 1.0471
# Training loss (for one batch) at step 5: 1.0509
# Training loss (for one batch) at step 6: 0.8549
# Training loss (for one batch) at step 7: 1.2370
# Training loss (for one batch) at step 8: 0.9675
# Training loss (for one batch) at step 9: 0.8604
# Average training loss at epoch 1: 1.1050
# Time taken: 4.25s
# Sum of Koopman Layer weights: 4.521
#
# Start of epoch 2
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 1.1558
# Training loss (for one batch) at step 1: 1.0286
# Training loss (for one batch) at step 2: 0.9591
# Training loss (for one batch) at step 3: 1.0550
# Training loss (for one batch) at step 4: 0.8409
# Training loss (for one batch) at step 5: 0.8537
# Training loss (for one batch) at step 6: 0.6935
# Training loss (for one batch) at step 7: 0.9971
# Training loss (for one batch) at step 8: 0.7746
# Training loss (for one batch) at step 9: 0.6880
# Average training loss at epoch 2: 0.9046
# Time taken: 4.09s
# Sum of Koopman Layer weights: 4.291
#
# Start of epoch 3
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.9304
# Training loss (for one batch) at step 1: 0.8181
# Training loss (for one batch) at step 2: 0.7601
# Training loss (for one batch) at step 3: 0.8312
# Training loss (for one batch) at step 4: 0.6704
# Training loss (for one batch) at step 5: 0.6619
# Training loss (for one batch) at step 6: 0.5527
# Training loss (for one batch) at step 7: 0.7823
# Training loss (for one batch) at step 8: 0.6307
# Training loss (for one batch) at step 9: 0.5513
# Average training loss at epoch 3: 0.7189
# Time taken: 4.19s
# Sum of Koopman Layer weights: 4.055
#
# Start of epoch 4
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.7465
# Training loss (for one batch) at step 1: 0.6678
# Training loss (for one batch) at step 2: 0.6272
# Training loss (for one batch) at step 3: 0.7141
# Training loss (for one batch) at step 4: 0.6199
# Training loss (for one batch) at step 5: 0.5922
# Training loss (for one batch) at step 6: 0.5161
# Training loss (for one batch) at step 7: 0.6860
# Training loss (for one batch) at step 8: 0.5870
# Training loss (for one batch) at step 9: 0.5063
# Average training loss at epoch 4: 0.6263
# Time taken: 4.05s
# Sum of Koopman Layer weights: 3.902
#
# Start of epoch 5
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.6800
# Training loss (for one batch) at step 1: 0.6172
# Training loss (for one batch) at step 2: 0.5814
# Training loss (for one batch) at step 3: 0.6642
# Training loss (for one batch) at step 4: 0.6015
# Training loss (for one batch) at step 5: 0.5695
# Training loss (for one batch) at step 6: 0.4948
# Training loss (for one batch) at step 7: 0.6687
# Training loss (for one batch) at step 8: 0.5712
# Training loss (for one batch) at step 9: 0.4900
# Average training loss at epoch 5: 0.5939
# Time taken: 4.19s
# Sum of Koopman Layer weights: 3.925
#
# Start of epoch 6
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.6705
# Training loss (for one batch) at step 1: 0.6036
# Training loss (for one batch) at step 2: 0.5656
# Training loss (for one batch) at step 3: 0.6443
# Training loss (for one batch) at step 4: 0.5908
# Training loss (for one batch) at step 5: 0.5637
# Training loss (for one batch) at step 6: 0.4855
# Training loss (for one batch) at step 7: 0.6530
# Training loss (for one batch) at step 8: 0.5663
# Training loss (for one batch) at step 9: 0.4816
# Average training loss at epoch 6: 0.5825
# Time taken: 4.11s
# Sum of Koopman Layer weights: 3.985
#
# Start of epoch 7
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.6719
# Training loss (for one batch) at step 1: 0.5850
# Training loss (for one batch) at step 2: 0.5487
# Training loss (for one batch) at step 3: 0.6388
# Training loss (for one batch) at step 4: 0.5823
# Training loss (for one batch) at step 5: 0.5572
# Training loss (for one batch) at step 6: 0.4761
# Training loss (for one batch) at step 7: 0.6524
# Training loss (for one batch) at step 8: 0.5613
# Training loss (for one batch) at step 9: 0.4741
# Average training loss at epoch 7: 0.5748
# Time taken: 4.16s
# Sum of Koopman Layer weights: 4.005
#
# Start of epoch 8
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.6701
# Training loss (for one batch) at step 1: 0.5727
# Training loss (for one batch) at step 2: 0.5363
# Training loss (for one batch) at step 3: 0.6379
# Training loss (for one batch) at step 4: 0.5782
# Training loss (for one batch) at step 5: 0.5516
# Training loss (for one batch) at step 6: 0.4677
# Training loss (for one batch) at step 7: 0.6537
# Training loss (for one batch) at step 8: 0.5574
# Training loss (for one batch) at step 9: 0.4704
# Average training loss at epoch 8: 0.5696
# Time taken: 4.01s
# Sum of Koopman Layer weights: 3.997
#
# Start of epoch 9
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.6662
# Training loss (for one batch) at step 1: 0.5666
# Training loss (for one batch) at step 2: 0.5318
# Training loss (for one batch) at step 3: 0.6344
# Training loss (for one batch) at step 4: 0.5728
# Training loss (for one batch) at step 5: 0.5498
# Training loss (for one batch) at step 6: 0.4639
# Training loss (for one batch) at step 7: 0.6486
# Training loss (for one batch) at step 8: 0.5525
# Training loss (for one batch) at step 9: 0.4656
# Average training loss at epoch 9: 0.5652
# Time taken: 4.03s
# Sum of Koopman Layer weights: 4.015

# %% [markdown]
# # Plots

# %%
input = x_train[0:batch_size]
plt.plot(input)
# Out:
# [<matplotlib.lines.Line2D at 0x2538ba07460>,
#  <matplotlib.lines.Line2D at 0x2538b9ff220>]

# %%
out1, out2, out3 = koopmanAEModel(input)
plt.plot(out1)
# Out:
# [<matplotlib.lines.Line2D at 0x2538ba71d30>,
#  <matplotlib.lines.Line2D at 0x2538ba71df0>]

# %% [markdown]
# # Save the Model

# %%
koopmanAEModel.save('checkpoints/Static_koopman')
# Out:
# INFO:tensorflow:Assets written to: checkpoints/Static_koopman\assets

# %% [markdown]
# # Load the Model

# %%
new_model = tf.keras.models.load_model('checkpoints/Static_koopman', compile=False)

# %%
new_out1, new_out2, new_out3 = new_model(input)
plt.plot(new_out1)
# Out:
# [<matplotlib.lines.Line2D at 0x2538b384d30>,
#  <matplotlib.lines.Line2D at 0x253d62485e0>]

# %%
new_model.summary()
# Out:
# Model: "Koopman_AE_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_model_8 (EncoderMode multiple                  10528
# _________________________________________________________________
# koopman__model_8 (Koopman_Mo multiple                  16384
# _________________________________________________________________
# decoder_model_8 (DecoderMode multiple                  10402
# =================================================================
# Total params: 37,314
# Trainable params: 37,314
# Non-trainable params: 0
# _________________________________________________________________

# %%
Z = new_model.enc(x_train)
K = new_model.koopman.get_weights()
K = np.squeeze(K)
print(K)
# Out:
# [[ 0.00933451  0.01938306  0.00339036 ...  0.00747392 -0.00602454
#    0.0791733 ]
#  [ 0.04639518  0.03188547 -0.03451071 ... -0.01579059 -0.05339212
#    0.06848475]
#  [ 0.03526893  0.07508467 -0.01717958 ... -0.01137986  0.01902704
#    0.01166069]
#  ...
#  [-0.12252416  0.00899877  0.00869909 ...  0.07315812 -0.07716161
#   -0.0664868 ]
#  [-0.02549039 -0.0118973  -0.03328213 ...  0.04393491  0.117229
#    0.05244055]
#  [-0.05632119  0.00464312 -0.04100421 ...  0.01472146  0.02091232
#   -0.10231933]]
