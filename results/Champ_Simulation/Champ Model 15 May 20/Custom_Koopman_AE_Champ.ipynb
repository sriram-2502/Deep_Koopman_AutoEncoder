# %% [markdown]
# # Implement a custom Autoencoder with Koopman layer

# %% [markdown]
# ## Version Control

# %% [markdown]
# To Do:
# 1) Account for trailing batch - Make robust (fixed issue by reshaping input data)
# 2) Address Sp issue for loss function
# 3) Try different L_inf norm hyperparameter

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras

import  numpy as np
import pandas as pd

import matplotlib.colors as mcol
import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.animation as animation

import seaborn as sns

import time 
import os

import glob
import csv

# %%
plt.rcParams['figure.figsize'] = [9, 6]
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.style.use('default')

# %%
#from google.colab import drive
#drive.mount('/gdrive')

# %% [markdown]
# Comment out if don't need

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data

# %% [markdown]
# ### Read Sim Data Functions

# %%
def preprocessSimData(df, desiredStates:list, initialIndex:int=300, finalIndex:int=812):
    '''
    Preprocess text file (fixing formatting issue in data as well) while returning a dataframe object with the desired states selected

    Parameters:
    -----------
    df: dataFrame
        Panda dataframe that is read from one of the recorded simulation .txt files
    desiredStates: list
        List of desired states to return as a panda dataframe object in sequential order

    Return:
    ----------
    stateMatrix: dataFrame
        State matrix with desired states
    '''



    # Fix formatting Variables
    falseList = ['time_lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort', 'nan']
    df.columns = falseList
    df['time_lf_hip_joint_position'] = df.time_lf_hip_joint_position.str[0:8] + ' ' + df.time_lf_hip_joint_position.str[8:]


    # Data and State Name List
    data = df.values # np array of data values
    namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

    dictStates = {}
    staticCounter = 0 # Variable to account for formatting issue
    for index in range(len(namesList)-1):
        if index == 0 and staticCounter == 0: # Condition for formatting issue of collected data
            for j in range(len(data[:,index])): # Looping through all elements in column 0 and converting to float
                if j == 0: # Initialize array
                    array1 = float(data[j,index][0:8])
                    #print(array1)
                    array2 = float(data[j,index][8:])
                    #print(array2)
                else:
                    array1 = np.vstack((array1,float(data[j,index][0:8])))
                    array2 = np.vstack((array2,float(data[j,index][8:])))
            dictStates[namesList[index]] = np.squeeze(array1[initialIndex:finalIndex])
            dictStates[namesList[index+1]] = np.squeeze(array2[initialIndex:finalIndex])        
        else:
            dictStates[namesList[index+1]] = data[initialIndex:finalIndex,index]
    for counter, names in enumerate(desiredStates):
        if counter == 0:
            stateMatrix = np.reshape(dictStates[names], (-1,1))
        else:
            stateMatrix = np.hstack((stateMatrix, np.reshape(dictStates[names], (-1,1))))
    return pd.DataFrame(stateMatrix, columns = desiredStates)



def preprocessFile(fileNames:list, initialIndex:int, finalIndex:int, desiredStates:list):
    '''
    Given fileNames to read, reads the file(s) and returns all data concatenated in a panda dataframe framework

    Paramaters:
    -----------
    fileNamess:list
        List of filenames to read and concatenate data together
    intialIndex: int
        Index to start reading each file's data from
    finalIndex: int
        Index to stop reading each file's data from
    desiredStates:list
        List of states to read
    
    Return:
    ----------
    totalData: dataFrame
        Returns data of all filenames with given states in one panda dataframe
    '''

    filePaths = []
    for i in fileNames:
        filePaths.append(glob.glob(i))
    #print(filePaths)


    dataFrameList = []
    for i in filePaths:
        for j in i:
            df = pd.read_csv(j, sep= " ", header=None)
            dataFrameList.append(preprocessSimData(df, desiredStates, initialIndex=initialIndex, finalIndex=finalIndex)) # 712-200 = 512 --> 512-1 is 512 indices (i.e. [0, 511])

    totalData = pd.concat(dataFrameList)
    return totalData

# %% [markdown]
# ### Read full data

# %%
# List of states
namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

# %%
desiredStates = ['lf_hip_joint_position', 'lf_hip_joint_vel', 'lf_lower_leg_joint_position', 
                'lf_lower_leg_joint_vel', 'lf_hip_joint_effort', 'lf_lower_leg_joint_effort']

input_dim = len(desiredStates)
output_dim = input_dim

trajLength = 2**6 # Length of each trajectory in the dataset

filePath = "simData"
fileNames = [filePath + '/empty_world_ground_2/joint_state_test_emptyWorld_forward_0.5*']


numTraj = 256 # Total number of trajectories in the dataset (train)
numTraj_val = 4
numTraj_test = 4
batch_size = int(2**8) # Number of snapshots in each batch
numTraj_batch = int(batch_size/trajLength)
numTraj_batch = int(batch_size/trajLength)

initialIndex, finalIndex= 400, 400+trajLength*(numTraj+numTraj_val+numTraj_test)

num_batches_train = int(trajLength*numTraj/batch_size) ## num_batches = trajLength*numTraj/batch_size 
num_batches_val = int(trajLength*numTraj_val/batch_size)

# %%
doggoFrame = preprocessFile(fileNames,initialIndex,finalIndex, desiredStates)
doggoFrame.head(5)
# Out:
#   lf_hip_joint_position lf_hip_joint_vel lf_lower_leg_joint_position  \
# 0                0.0013           3.6865                     -1.4667
# 1               -0.0027          -3.9149                     -1.5198
# 2                0.0009           3.4271                     -1.5245
# 3               -0.0012          -2.4308                     -1.5679
# 4                0.0009           1.4415                      -1.584
#
#   lf_lower_leg_joint_vel lf_hip_joint_effort lf_lower_leg_joint_effort
# 0                19.5187              4.1101                      25.0
# 1               -30.1504             -3.6843                  -24.6202
# 2                15.1851              3.5978                   21.3211
# 3                -19.652             -2.8346                  -15.4825
# 4                 2.1823               1.589                    8.4289

# %%
plt.figure(figsize=(16,4))
plt.plot(doggoFrame.values[0:5000,2])
plt.title("Graph of data")
# Out:
# Text(0.5, 1.0, 'Graph of data')

# %%
plt.figure(figsize=(9,6))
plt.plot(doggoFrame.values[0:,0], doggoFrame.values[0:,1],lw=1)
plt.title("Phase Portrait")
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\dot\theta$")
plt.tight_layout()

# %%
print("Datapoints: ", len(doggoFrame.index))
# Out:
# Datapoints:  16896

# %%
doggo_train = doggoFrame.values[:numTraj*trajLength,:]
doggo_validation = doggoFrame.values[numTraj*trajLength:(numTraj+numTraj_val)*trajLength,:]
doggo_test = doggoFrame.values[(numTraj+numTraj_val)*trajLength:(numTraj+numTraj_val+numTraj_test)*trajLength,:]

doggo_train = np.asarray(doggo_train).astype('float32')
doggo_test = np.asarray(doggo_test).astype('float32')
doggo_validation = np.asarray(doggo_validation).astype('float32')

# %%
print("Size of doggo_train:", len(doggo_train))
print("Size of doggo_validation:", len(doggo_validation))
print("Size of doggo_test:", len(doggo_test))
# Out:
# Size of doggo_train: 16384
# Size of doggo_validation: 256
# Size of doggo_test: 256

# %% [markdown]
# ### Make into dataset

# %%
# Normalize the data
min_val = tf.reduce_min(doggo_train)
max_val = tf.reduce_max(doggo_train)

#doggo_train = (doggo_train - min_val) / (max_val - min_val)
#doggo_validation = (doggo_validation - min_val) / (max_val - min_val)
#doggo_test = (doggo_test - min_val) / (max_val - min_val)

train_data = tf.cast(doggo_train[0:batch_size*num_batches_train], tf.float32)
validation_data = tf.cast(doggo_validation[0:batch_size*num_batches_val], tf.float32)
validation_data = tf.data.Dataset.from_tensor_slices((validation_data, validation_data)).batch(batch_size)
test_data = tf.cast(doggo_test, tf.float32)

# %%
x_train = train_data
y_train = train_data

# %% [markdown]
# # Custom Model definition

# %% [markdown]
# ## Encoder

# %%
class EncoderLayer(keras.layers.Layer):
    """
    Custom class to create a encoder layer
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * x + b: tensor
        linear combination of weights times input + bias for the layer
    """
    
    def __init__(self, units=32, name=None):
        super(EncoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Encoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, inputs):
        #print("Encoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(inputs, self.w) + self.b

# %%
class EncoderModel(keras.Model):
    """
    Custom Model to create an encoder with one input
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    """
    
    def __init__(self, name=None):
        super(EncoderModel, self).__init__(name=name)
        self.enc1 = EncoderLayer(256)
        self.enc2 = EncoderLayer(256)
        self.enc3 = EncoderLayer(256)
        self.enc4 = EncoderLayer(256)
        self.enc5 = EncoderLayer(256)
        self.enc6 = EncoderLayer(256)
        self.enc7 = EncoderLayer(256)

    def call(self, input):
        x = input
        x = self.enc1(x)
        x = tf.nn.tanh(x)
        x = self.enc2(x)
        x = tf.nn.elu(x)

        # Encoder output layer
        x = self.enc3(x)
        x = tf.nn.tanh(x)
        x = self.enc4(x)
        x = tf.nn.elu(x)
        x = self.enc5(x)
        x = tf.nn.tanh(x)
        x = self.enc6(x)
        x = tf.nn.elu(x)
        x = self.enc7(x)
        z = tf.nn.tanh(x)
        return z

# %% [markdown]
# ## Koopman

# %%
class KoopmanLayer(keras.layers.Layer):
    """
    Custom class to calculate the Koopman operator K on latent variables
    Adds a linear loss as mse(Z2-Z2_tilde)
    
    Parameters
    ----------
    Z: tensor 
        inputs are the latent variabes (output from encoder)
        input dimension is (m, 128)
        m is the number of time snapshots for each input dimension of X
        128 is the number of latent varibales (observables)

    Return
    ----------
    Z: tensor
        return the original input Z 

    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    Z2_tilde: tensor
        return the prediction by linearity from K (z2_tilde = K^m * z(1,:))
    """

    def __init__(self, trajLength, numTraj_batch):
        super(KoopmanLayer, self).__init__()
        self.trajLength = trajLength
        self.numTraj_batch = numTraj_batch

    def build(self, Z):
        # Initialize K as a weight
            self.K =  self.add_weight(
                name = 'Koopman_weight',
                shape=(Z[-1], Z[-1]),
                initializer="random_normal",
                trainable=True,
            )

    def timeShift(self,Z,latent_dim):
        '''
        Shifts trajectories one time step
        Parameters:
        -----------
            Z: tensor
                Batch data of latent variables (in the lifted space)
                
            latent_dim: tensor shape
                Dimension of the lifted space (columns of Z)
        '''
        Z1 = []
        z1 = []
        Z2 = []

        for i in range(self.numTraj_batch):
            Z1.append(Z[i*self.trajLength:(i+1)*self.trajLength-1,:])
            Z2.append(Z[i*self.trajLength+1:(i+1)*self.trajLength,:])
            z1.append(Z[i*self.trajLength,:])
        return tf.reshape(Z1, [-1, latent_dim]), tf.reshape(Z2, [-1, latent_dim]), tf.reshape(z1, [-1, latent_dim])       

    def call(self, Z):
        latent_dim = tf.shape(Z)[1]
        shift_len = (self.trajLength-1)*self.numTraj_batch # length of rows for forward time shifted Z
        Z1, Z2, z1 = self.timeShift(Z,latent_dim)

        # Find Z2_tilde
        Z2_tilde = tf.zeros([shift_len, latent_dim], dtype=tf.float32)
        for traj in range(self.numTraj_batch): # loop over numnber of traj
            for m in range(self.trajLength-1): #loop over snapshots in each traj
                 #K = tf.zeros([latent_dim, latent_dim], dtype=tf.float32)
                 
                 indices = tf.constant([[traj*(self.trajLength-1)+m]])
                 if m == 0:
                    K = self.K 
                    # Matrix matvec works out to get Kz' and returns as row vector
                    updates = [tf.linalg.matvec(K, z1[traj,:])] #updates the row tensor at index = indices 
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                 else:
                    K = tf.matmul(K,self.K)
                    updates = [tf.linalg.matvec(K, z1[traj,:])]
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
           
        # Find linear loss
        Linear_loss = tf.reduce_mean(tf.square(tf.subtract(Z2,Z2_tilde)))
        self.add_loss(Linear_loss)
        
        # prints for debugging dimensions
        #print("Koopman layer, K",tf.shape(K))
        #print("Koopman layer, m",tf.shape(m))
        #print("Koopman layer, Z",tf.shape(Z))
        #print("Koopman layer, z1",tf.shape(z1))
        #print("Koopman layer, Z2 ",tf.shape(Z2))
        #print("Koopman layer, Z2_tilde",tf.shape(Z2_tilde))
        
        return Z, tf.matmul(Z1,self.K), Z2_tilde,

# %%
class Koopman_Model(keras.Model):
    """
    Custom Model to create an encoder with koopman layer
    
    Parameters
    ----------
    input: tensor 
        z - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    
    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    z2_tilde: tensor
        Latent variables of prediction obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    """
    
    def __init__(self, trajLength, numTraj_batch, name=None):
        super(Koopman_Model, self).__init__(name=name)
        self.koopman = KoopmanLayer(trajLength,numTraj_batch)


    def call(self, input):
        z = input
        z, Z2_hat, z2_tilde = self.koopman(z)
        return z, Z2_hat, z2_tilde

# %% [markdown]
# ## Decoder

# %%
class DecoderLayer(keras.layers.Layer):
    """
    Custom class to create a decoder layer with two inputs
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * input1 + b: tensor
        linear combination of weights times input1 + bias for the layer
        
    W.T * input2 + b: tensor
        linear combination of weights times input2 + bias for the layer

    W.T * input3 + b: tensor
        linear combination of weights times input3 + bias for the layer
    """

    def __init__(self, units=32, name=None):
        super(DecoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Decoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, input1, input2, input3):
        #print("Decoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(input1, self.w) + self.b, tf.matmul(input2, self.w) + self.b, tf.matmul(input3, self.w) + self.b

# %%
class DecoderModel(keras.Model):
    """
    Custom Model to create a decoder with two inputs
    
    Parameters
    ----------
    input 1: tensor 
        z - the lifted output of the koopman layer (encoder output)
    
    input 2: tensor 
        z2_tilde - obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Prediction of the original state inputs x (label values are forward time shifted x)

    x2_tilde: tensor
        Prediction obtained by linearity from K 
    
    """
    
    def __init__(self, outputDim, name=None):
        super(DecoderModel, self).__init__(name=name)
        self.dec1 = DecoderLayer(256)
        self.dec2 = DecoderLayer(256)
        self.dec3 = DecoderLayer(256)
        self.dec4 = DecoderLayer(256)
        self.outputLayer = DecoderLayer(outputDim)

    def call(self, input1, input2, input3):
        z = input1
        z2_hat = input2
        z2_tilde = input3

        z, z2_hat, z2_tilde = self.dec1(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec2(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec3(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec4(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        # Decoder output layer
        x_hat, x2_hat, x2_tilde = self.outputLayer(z, z2_hat, z2_tilde)
        #x_hat = tf.nn.elu(x_hat)
        #x2_hat = tf.nn.elu(x2_hat)
        #x2_tilde = tf.nn.elu(x2_tilde)

        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# ## Koopman Autoencoder

# %%
class Koopman_AE_Model(keras.Model):
    """
    Custom Model to create a Koopman Autoencoder
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    
    x2_tilde: tensor
        Prediction obtained by linearity from K 
    """
    
    def __init__(self, inputDim, outputDim, trajLength, numTraj, name=None):
        super(Koopman_AE_Model, self).__init__(name=name)
        self.enc = EncoderModel()
        self.koopman = Koopman_Model(trajLength, numTraj)
        self.dec = DecoderModel(outputDim)

    def call(self, input):
        x = input
        z = self.enc(x)
        z, z2_hat, z2_tilde = self.koopman(z)
        x_hat, x2_hat, x2_tilde = self.dec(z, z2_hat, z2_tilde)
        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# # Custom Training Loop

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.batch(batch_size)

# %%
class MyStaticModel():
    def __init__(self, input_dim, batch_size, trajLength, num_batches_train, num_batches_val, epochNum, lr):
        # Initialize constants
        self.batch_size = batch_size
        self.trajLength = int(trajLength) #should be int
        self.numtraj_batch = int(self.batch_size/self.trajLength) # should be int
        self.num_batches_train = num_batches_train
        self.num_batches_val = num_batches_val

        self.epochNum = epochNum
        self.lr = lr

        self.inputs = tf.keras.layers.Input(shape=(input_dim,))
        self.graphCounter = 0 

    ######################################  LOSS FUNCTIONS  ###################################################
    def tot_loss(self, model, x, x_hat, x2_hat, x2_tilde):
        """Calculates total loss as sum of recon_loss + predict_loss + Koopman_loss"""
        #alpha1 = 0.1, alpha2 = 1e-7, alpha3 = 1e-15
        alpha1 = 0.1
        alpha2 = 1e-7
        alpha3 = 1e-15

        x2 = []
        x2_SP = []
        x2_tilde_SP = []
        for i in range(self.numtraj_batch):
            predict_length = self.trajLength-1
            x2.append(x[i*self.trajLength+1:(i+1)*self.trajLength]) # forward time shift x to get x2
            x2_SP.append(x[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # forward time shift x to get x2 for Sp timesteps
            #x2_tilde_SP.append(x2_tilde[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # get Sp timesteps from x2_tilde
            # Shape currently goes from 31 to 27.. but somehow indexing does not work
            x2_tilde_SP = x2_tilde

        #print("In loss function x2", tf.shape(x2))
        #print("In loss function x2_SP", tf.shape(x2_SP))
        #print("In loss function x2_tilde_SP", tf.shape(x2_tilde_SP))

        x2 = tf.reshape(x2, [-1, x.shape[-1]])
        x2_SP = tf.reshape(x2_SP, [-1, x.shape[-1]])
        x2_tilde_SP = tf.reshape(x2_tilde_SP, [-1, x.shape[-1]])

        recon_loss = tf.reduce_mean(tf.square(tf.subtract(x,x_hat)))
        predict_loss =tf.reduce_mean(tf.square(tf.subtract(x2_SP,x2_tilde_SP)))

        weights  = model.trainable_variables
        lossL2 = tf.add_n([tf.nn.l2_loss(w) for w in weights if 'bias' not in w.name])

        Linf_loss = tf.add(tf.norm(tf.subtract(x,x_hat), ord=np.inf), tf.norm(tf.subtract(x2,x2_hat), ord=np.inf))
        '''
        print("-------------------------------")
        print("L_inf loss: ", alpha2*Linf_loss)
        print("recon_loss + predict_loss: ", alpha1*(recon_loss+predict_loss))
        print("L2 Loss: ", alpha3*lossL2)
        print("Lifted Loss: ", sum(model.losses))
        '''
        return alpha1*(recon_loss+predict_loss) + alpha2*Linf_loss + alpha3*lossL2 + sum(model.losses)

    ###############################################  GRAPH FUNCTIONS     #########################################################

    def graphPlot(self, error, error_min, error_max, error_val, error_min_val, error_max_val):
        '''
        Graph plots for loss over all epochs
        Parameters:
        error: list
            Training Loss Error for all epochs
        error_val: list
            Validation Loss Error for all epochs
        '''
        saveFiles = True
        imgPath = 'graphs/'
        csvPath = 'csvFiles/'

        csvFileName = 'epochLosses.csv'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making graph folder. Folder already exists...")

            try:
                os.mkdir(csvPath)
            except:
                print("Tried making csv folder. Folder already exists...")
        
        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Training Loss")
        plt.plot(error_val, label = "Validation Loss")
        textTitle = "All Epoch Loss %d" % self.graphCounter
        self.graphCounter += 1
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight') 
        plt.close()

        # Save data into csv file
        csvDict = {'Epoch Training Loss': error, 'Epoch Training Min Loss': error_min, 'Epoch Training Max Loss': error_max,
                    'Epoch Validation Loss': error_val, 'Epoch Validation Min Loss' : error_min_val, 
                    'Epoch Validation Max Loss': error_max_val}
        df = pd.DataFrame(csvDict)
        df.to_csv(csvPath+csvFileName)
            

    
    def graphBatchLossPlot(self, epochNum, error, error_val):
        '''
        Graphs the loss of each batch
        
        Parameter:
        ----------
        epochNum: int
            Current epoch number
        error: list
            Training error for batch
        error_val: list
            Validation error for batch

        Return:
        -------
        None
        '''
        saveFiles = True
        imgPath = 'graphs/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Batch Training Loss")
        plt.plot(error_val, label="Batch Validation Loss")
        textTitle = "BatchLoss_Epoch_%d" % (epochNum)
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
        plt.close() 

    
    def graphEigenfunctions(self, model, K):
        '''
        Graphs the eigenfunction given K and the model (used sample from hypercube)
        Parameter:
        ----------
        model: keras model
            Koopman autoencoder model
        K:
            Koopman operator
        
        Return:
        ----------
        None
        '''
        saveFiles = True
        imgPath = 'graphs/eigenfunctions/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        x1 = tf.linspace(-1,1,256)
        x2 = tf.linspace(-1,1,256)
        x1, x2 = tf.meshgrid(x1, x2)
        X = tf.reshape([[x1],[x2]], [-1, 2])

        Z = model.enc(X)
        complex_Z = tf.complex(Z, tf.zeros(tf.shape(Z))) # make Z complex with zero complex part

        eig_values, right_eig_vectors = tf.linalg.eig(tf.squeeze(K))
        W = tf.transpose(tf.linalg.inv(right_eig_vectors))
        Psi = tf.matmul(complex_Z,W)

        eig_dominant = tf.abs(eig_values)
        counter = 0
        for eig in eig_values:
            cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["b","w","r"])
            #normalize = mpl.colors.Normalize(vmin=np.min(Psi[:,counter]), vmax=np.max(Psi[:,counter]))
            plt.figure(counter)
            fig, axs = plt.subplots(2)
            
            p1 = axs[0].scatter(x1, x2, c=tf.abs(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p1, ax=axs[0])
            fig_title1 = "|Psi| %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig)) 
            axs[0].set_title(fig_title1)
            
            p2 = axs[1].scatter(x1, x2, c=tf.math.angle(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p2, ax=axs[1])
            fig_title2 = "angle(Psi) %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig))  
            axs[1].set_title(fig_title2)

            fig.tight_layout()
            textTitle = "Psi_%0.04f_epoch%d"%(eig, counter)
            counter += 1
            if saveFiles:
                plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
            plt.close('all') 

    ###############################################     FIT FUNCTION        #########################################################

    def fit(self, model, x, y, validation_data, batch_size):
        '''
        Given a tensorflow model, training data (x,y), validation data, and the batch size, trains the model over specified datapoints
        Parameter:
        ----------
        model: Tensorflow model
        x:
            Training data 
        y:
            Training data for evaluation (for AE, same as x)
        validation_data: tensorflow batch?
            Data in a batch (See tensorflow tutorial)
        batch_size: int
            The batch size for training
        Return:
        ---------
        None
        '''
        # Preprocess data
        train_ds = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)

        # Define the optimizer
        optimizer = tf.keras.optimizers.Adam(self.lr)

        epochs = self.epochNum     
        
        # Initialize variables for csv file
        epoch_train_loss = [] # total loss for each epoch
        epoch_train_min_loss = []
        epoch_train_max_loss = []
        
        epoch_validation_loss = []
        epoch_validation_min_loss = []
        epoch_validation_max_loss = []



        start_time_total = time.time()
        for epoch in range(epochs):

            print("\nStart of epoch %d" % (epoch))
            start_time = time.time()

            batch_train_loss_list = [] # total loss for each batch 
            batch_validation_loss_list = []


            ###############################################     Training loop     ###################################################
            # Iterate over the train batches of the dataset.
            for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
                with tf.GradientTape() as tape:
                    reconstruction, prediction, linearity = model(x_batch_train)

                    # total avg loss for each batch
                    batch_train_loss = self.tot_loss(model, y_batch_train, reconstruction, prediction, linearity)
                    batch_train_loss_list.append(batch_train_loss)

                grads = tape.gradient(batch_train_loss, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
                              
            # outside batch loop
            avg_train_loss = np.sum(batch_train_loss_list)/self.num_batches_train
            min_train_loss = np.amin(batch_train_loss_list)
            max_train_loss = np.amax(batch_train_loss_list)
            epoch_train_loss.append(avg_train_loss)
            epoch_train_min_loss.append(min_train_loss)
            epoch_train_max_loss.append(max_train_loss)


            print("Average training loss at epoch %d: %.7f"% (epoch, float(avg_train_loss)))


            ###############################################   Validaiton  loop     ###################################################
            for step, (x_batch_val, y_batch_val) in enumerate(validation_data):
                reconstruction_val, pred_val, linearity_val = model(x_batch_val)

                batch_validation_loss = self.tot_loss(model, y_batch_val, reconstruction_val, pred_val, linearity_val)
                batch_validation_loss_list.append(batch_validation_loss)

            # outside batch loop
            epoch_validation_loss.append(np.sum(batch_validation_loss_list)/self.num_batches_val)
            epoch_validation_min_loss.append(np.amin(batch_validation_loss_list))
            epoch_validation_max_loss.append(np.amax(batch_validation_loss_list))

            print(f"Epoch val loss: {np.sum(batch_validation_loss_list)/num_batches_val}")
            print("Time taken: %.2fs" % (time.time()- start_time_total))
            #self.graphBatchLossPlot(epoch, batch_train_loss_list, batch_validation_loss_list)
            #K = model.koopman.get_weights()
            #self.graphEigenfunctions(model, K)

        self.graphPlot(epoch_train_loss, epoch_train_min_loss, epoch_train_max_loss, epoch_validation_loss, 
                        epoch_validation_min_loss, epoch_validation_max_loss)
        print("Total time taken: %.2fs" % (time.time() - start_time_total))

# %%
epochNum = 700
lr = 1e-4

Training_class = MyStaticModel(input_dim, batch_size, trajLength, num_batches_train, num_batches_val, epochNum = epochNum, lr=lr)
koopmanAEModel = Koopman_AE_Model(input_dim, output_dim, trajLength, numTraj_batch, name="Koopman_AE_Model")
Training_class.fit(koopmanAEModel,x=train_data, y=train_data, validation_data=validation_data, batch_size=batch_size)
# Out:
# Start of epoch 0
# Average training loss at epoch 0: 6.8650951
# Epoch val loss: 7.0734076499938965
# Time taken: 46.32s
#
# Start of epoch 1
# Average training loss at epoch 1: 5.3751011
# Epoch val loss: 6.649107933044434
# Time taken: 93.43s
#
# Start of epoch 2
# Average training loss at epoch 2: 5.0382395
# Epoch val loss: 6.3466315269470215
# Time taken: 129.10s
#
# Start of epoch 3
# Average training loss at epoch 3: 4.8330984
# Epoch val loss: 6.092898845672607
# Time taken: 164.85s
#
# Start of epoch 4
# Average training loss at epoch 4: 4.6711454
# Epoch val loss: 5.994772911071777
# Time taken: 201.14s
#
# Start of epoch 5
# Average training loss at epoch 5: 4.5602674
# Epoch val loss: 5.876734256744385
# Time taken: 236.49s
#
# Start of epoch 6
# Average training loss at epoch 6: 4.4778566
# Epoch val loss: 5.796935081481934
# Time taken: 271.93s
#
# Start of epoch 7
# Average training loss at epoch 7: 4.4160585
# Epoch val loss: 5.763924598693848
# Time taken: 307.34s
#
# Start of epoch 8
# Average training loss at epoch 8: 4.3690228
# Epoch val loss: 5.703346252441406
# Time taken: 342.96s
#
# Start of epoch 9
# Average training loss at epoch 9: 4.3294339
# Epoch val loss: 5.6537089347839355
# Time taken: 378.51s
#
# Start of epoch 10
# Average training loss at epoch 10: 4.2968903
# Epoch val loss: 5.630998134613037
# Time taken: 414.36s
#
# Start of epoch 11
# Average training loss at epoch 11: 4.2735128
# Epoch val loss: 5.585525989532471
# Time taken: 449.63s
#
# Start of epoch 12
# Average training loss at epoch 12: 4.2552795
# Epoch val loss: 5.5630669593811035
# Time taken: 485.22s
#
# Start of epoch 13
# Average training loss at epoch 13: 4.2402253
# Epoch val loss: 5.555784702301025
# Time taken: 520.99s
#
# Start of epoch 14
# Average training loss at epoch 14: 4.2284074
# Epoch val loss: 5.527247905731201
# Time taken: 556.93s
#
# Start of epoch 15
# Average training loss at epoch 15: 4.2178979
# Epoch val loss: 5.523829936981201
# Time taken: 592.71s
#
# Start of epoch 16
# Average training loss at epoch 16: 4.2082825
# Epoch val loss: 5.532599449157715
# Time taken: 628.52s
#
# Start of epoch 17
# Average training loss at epoch 17: 4.2010651
# Epoch val loss: 5.508228302001953
# Time taken: 664.13s
#
# Start of epoch 18
# Average training loss at epoch 18: 4.1938601
# Epoch val loss: 5.5232133865356445
# Time taken: 700.32s
#
# Start of epoch 19
# Average training loss at epoch 19: 4.1881404
# Epoch val loss: 5.528766632080078
# Time taken: 736.33s
#
# Start of epoch 20
# Average training loss at epoch 20: 4.1833138
# Epoch val loss: 5.507734775543213
# Time taken: 772.06s
#
# Start of epoch 21
# Average training loss at epoch 21: 4.1791234
# Epoch val loss: 5.526472568511963
# Time taken: 806.99s
#
# Start of epoch 22
# Average training loss at epoch 22: 4.1760077
# Epoch val loss: 5.5471930503845215
# Time taken: 841.76s
#
# Start of epoch 23
# Average training loss at epoch 23: 4.1727433
# Epoch val loss: 5.525686264038086
# Time taken: 877.09s
#
# Start of epoch 24
# Average training loss at epoch 24: 4.1700606
# Epoch val loss: 5.528553485870361
# Time taken: 911.68s
#
# Start of epoch 25
# Average training loss at epoch 25: 4.1678944
# Epoch val loss: 5.544281005859375
# Time taken: 945.69s
#
# Start of epoch 26
# Average training loss at epoch 26: 4.1645427
# Epoch val loss: 5.522976875305176
# Time taken: 980.82s
#
# Start of epoch 27
# Average training loss at epoch 27: 4.1609874
# Epoch val loss: 5.511693000793457
# Time taken: 1015.83s
#
# Start of epoch 28
# Average training loss at epoch 28: 4.1578369
# Epoch val loss: 5.517019748687744
# Time taken: 1050.40s
#
# Start of epoch 29
# Average training loss at epoch 29: 4.1543870
# Epoch val loss: 5.516216278076172
# Time taken: 1085.49s
#
# Start of epoch 30
# Average training loss at epoch 30: 4.1512337
# Epoch val loss: 5.520513534545898
# Time taken: 1120.88s
#
# Start of epoch 31
# Average training loss at epoch 31: 4.1483736
# Epoch val loss: 5.527644157409668
# Time taken: 1155.61s
#
# Start of epoch 32
# Average training loss at epoch 32: 4.1455278
# Epoch val loss: 5.526072978973389
# Time taken: 1190.62s
#
# Start of epoch 33
# Average training loss at epoch 33: 4.1428013
# Epoch val loss: 5.529541969299316
# Time taken: 1225.10s
#
# Start of epoch 34
# Average training loss at epoch 34: 4.1400628
# Epoch val loss: 5.531702995300293
# Time taken: 1259.88s
#
# Start of epoch 35
# Average training loss at epoch 35: 4.1372623
# Epoch val loss: 5.531523704528809
# Time taken: 1295.14s
#
# Start of epoch 36
# Average training loss at epoch 36: 4.1344938
# Epoch val loss: 5.53940486907959
# Time taken: 1330.10s
#
# Start of epoch 37
# Average training loss at epoch 37: 4.1318378
# Epoch val loss: 5.548940181732178
# Time taken: 1365.18s
#
# Start of epoch 38
# Average training loss at epoch 38: 4.1294289
# Epoch val loss: 5.562298774719238
# Time taken: 1399.85s
#
# Start of epoch 39
# Average training loss at epoch 39: 4.1269970
# Epoch val loss: 5.579606056213379
# Time taken: 1435.07s
#
# Start of epoch 40
# Average training loss at epoch 40: 4.1245332
# Epoch val loss: 5.595798015594482
# Time taken: 1469.88s
#
# Start of epoch 41
# Average training loss at epoch 41: 4.1221809
# Epoch val loss: 5.6061530113220215
# Time taken: 1504.44s
#
# Start of epoch 42
# Average training loss at epoch 42: 4.1200047
# Epoch val loss: 5.604806423187256
# Time taken: 1539.12s
#
# Start of epoch 43
# Average training loss at epoch 43: 4.1194067
# Epoch val loss: 5.580730438232422
# Time taken: 1574.42s
#
# Start of epoch 44
# Average training loss at epoch 44: 4.1174555
# Epoch val loss: 5.5921807289123535
# Time taken: 1608.64s
#
# Start of epoch 45
# Average training loss at epoch 45: 4.1366091
# Epoch val loss: 5.5801167488098145
# Time taken: 1643.04s
#
# Start of epoch 46
# Average training loss at epoch 46: 4.1226945
# Epoch val loss: 5.533143043518066
# Time taken: 1677.24s
#
# Start of epoch 47
# Average training loss at epoch 47: 4.1232581
# Epoch val loss: 5.526470184326172
# Time taken: 1711.68s
#
# Start of epoch 48
# Average training loss at epoch 48: 4.1138682
# Epoch val loss: 5.5968337059021
# Time taken: 1746.41s
#
# Start of epoch 49
# Average training loss at epoch 49: 4.1009483
# Epoch val loss: 5.559239864349365
# Time taken: 1781.07s
#
# Start of epoch 50
# Average training loss at epoch 50: 4.1052170
# Epoch val loss: 5.601388454437256
# Time taken: 1815.45s
#
# Start of epoch 51
# Average training loss at epoch 51: 4.0991645
# Epoch val loss: 5.565123081207275
# Time taken: 1849.85s
#
# Start of epoch 52
# Average training loss at epoch 52: 4.0795088
# Epoch val loss: 5.577124118804932
# Time taken: 1884.38s
#
# Start of epoch 53
# Average training loss at epoch 53: 4.0829611
# Epoch val loss: 5.460961818695068
# Time taken: 1919.59s
#
# Start of epoch 54
# Average training loss at epoch 54: 4.0853925
# Epoch val loss: 5.596299171447754
# Time taken: 1954.91s
#
# Start of epoch 55
# Average training loss at epoch 55: 4.0840859
# Epoch val loss: 5.550349712371826
# Time taken: 1990.07s
#
# Start of epoch 56
# Average training loss at epoch 56: 4.0716987
# Epoch val loss: 5.573284149169922
# Time taken: 2024.43s
#
# Start of epoch 57
# Average training loss at epoch 57: 4.0684795
# Epoch val loss: 5.528895378112793
# Time taken: 2059.09s
#
# Start of epoch 58
# Average training loss at epoch 58: 4.0865288
# Epoch val loss: 5.60014533996582
# Time taken: 2093.44s
#
# Start of epoch 59
# Average training loss at epoch 59: 4.0954905
# Epoch val loss: 5.611515998840332
# Time taken: 2128.30s
#
# Start of epoch 60
# Average training loss at epoch 60: 4.0593290
# Epoch val loss: 5.567122459411621
# Time taken: 2163.10s
#
# Start of epoch 61
# Average training loss at epoch 61: 4.0758176
# Epoch val loss: 5.607586860656738
# Time taken: 2198.31s
#
# Start of epoch 62
# Average training loss at epoch 62: 4.0659952
# Epoch val loss: 5.554791450500488
# Time taken: 2233.09s
#
# Start of epoch 63
# Average training loss at epoch 63: 4.0492344
# Epoch val loss: 5.5428924560546875
# Time taken: 2268.14s
#
# Start of epoch 64
# Average training loss at epoch 64: 4.0525751
# Epoch val loss: 5.556222915649414
# Time taken: 2303.27s
#
# Start of epoch 65
# Average training loss at epoch 65: 4.0886431
# Epoch val loss: 5.66729211807251
# Time taken: 2338.12s
#
# Start of epoch 66
# Average training loss at epoch 66: 4.0453939
# Epoch val loss: 5.609369277954102
# Time taken: 2372.83s
#
# Start of epoch 67
# Average training loss at epoch 67: 4.0357723
# Epoch val loss: 5.548917770385742
# Time taken: 2407.37s
#
# Start of epoch 68
# Average training loss at epoch 68: 4.0142426
# Epoch val loss: 5.589964389801025
# Time taken: 2442.13s
#
# Start of epoch 69
# Average training loss at epoch 69: 4.0614529
# Epoch val loss: 5.640445709228516
# Time taken: 2477.17s
#
# Start of epoch 70
# Average training loss at epoch 70: 4.0354776
# Epoch val loss: 5.523900032043457
# Time taken: 2511.58s
#
# Start of epoch 71
# Average training loss at epoch 71: 4.0070138
# Epoch val loss: 5.602036476135254
# Time taken: 2546.06s
#
# Start of epoch 72
# Average training loss at epoch 72: 4.0052161
# Epoch val loss: 5.658994674682617
# Time taken: 2581.10s
#
# Start of epoch 73
# Average training loss at epoch 73: 4.0296340
# Epoch val loss: 5.56724214553833
# Time taken: 2615.73s
#
# Start of epoch 74
# Average training loss at epoch 74: 4.0128527
# Epoch val loss: 5.630083084106445
# Time taken: 2651.04s
#
# Start of epoch 75
# Average training loss at epoch 75: 4.0162997
# Epoch val loss: 5.652361869812012
# Time taken: 2686.72s
#
# Start of epoch 76
# Average training loss at epoch 76: 4.0028644
# Epoch val loss: 5.512461185455322
# Time taken: 2721.25s
#
# Start of epoch 77
# Average training loss at epoch 77: 4.0456524
# Epoch val loss: 5.518393516540527
# Time taken: 2755.32s
#
# Start of epoch 78
# Average training loss at epoch 78: 4.0230036
# Epoch val loss: 5.53867244720459
# Time taken: 2789.14s
#
# Start of epoch 79
# Average training loss at epoch 79: 3.9924767
# Epoch val loss: 5.626527309417725
# Time taken: 2823.83s
#
# Start of epoch 80
# Average training loss at epoch 80: 3.9993615
# Epoch val loss: 5.630379676818848
# Time taken: 2858.62s
#
# Start of epoch 81
# Average training loss at epoch 81: 4.0068893
# Epoch val loss: 5.524231433868408
# Time taken: 2893.52s
#
# Start of epoch 82
# Average training loss at epoch 82: 3.9798918
# Epoch val loss: 5.554625988006592
# Time taken: 2927.73s
#
# Start of epoch 83
# Average training loss at epoch 83: 4.0114150
# Epoch val loss: 5.494215488433838
# Time taken: 2962.34s
#
# Start of epoch 84
# Average training loss at epoch 84: 4.0114012
# Epoch val loss: 5.50238561630249
# Time taken: 2997.07s
#
# Start of epoch 85
# Average training loss at epoch 85: 3.9719467
# Epoch val loss: 5.625457286834717
# Time taken: 3031.73s
#
# Start of epoch 86
# Average training loss at epoch 86: 4.0006790
# Epoch val loss: 5.577698707580566
# Time taken: 3066.31s
#
# Start of epoch 87
# Average training loss at epoch 87: 3.9847991
# Epoch val loss: 5.682432651519775
# Time taken: 3100.58s
#
# Start of epoch 88
# Average training loss at epoch 88: 4.0014005
# Epoch val loss: 5.604935646057129
# Time taken: 3135.62s
#
# Start of epoch 89
# Average training loss at epoch 89: 3.9782410
# Epoch val loss: 5.788094997406006
# Time taken: 3170.19s
#
# Start of epoch 90
# Average training loss at epoch 90: 4.0082006
# Epoch val loss: 5.4777984619140625
# Time taken: 3204.92s
#
# Start of epoch 91
# Average training loss at epoch 91: 3.9890957
# Epoch val loss: 5.597753524780273
# Time taken: 3239.28s
#
# Start of epoch 92
# Average training loss at epoch 92: 3.9547024
# Epoch val loss: 5.626227855682373
# Time taken: 3274.04s
#
# Start of epoch 93
# Average training loss at epoch 93: 3.9538622
# Epoch val loss: 5.623915195465088
# Time taken: 3308.74s
#
# Start of epoch 94
# Average training loss at epoch 94: 3.9745364
# Epoch val loss: 5.572068691253662
# Time taken: 3343.04s
#
# Start of epoch 95
# Average training loss at epoch 95: 3.9404595
# Epoch val loss: 5.528301239013672
# Time taken: 3377.71s
#
# Start of epoch 96
# Average training loss at epoch 96: 3.9401112
# Epoch val loss: 5.613327503204346
# Time taken: 3413.19s
#
# Start of epoch 97
# Average training loss at epoch 97: 3.9447765
# Epoch val loss: 5.525540828704834
# Time taken: 3447.39s
#
# Start of epoch 98
# Average training loss at epoch 98: 3.9721549
# Epoch val loss: 5.584447383880615
# Time taken: 3482.28s
#
# Start of epoch 99
# Average training loss at epoch 99: 4.0276060
# Epoch val loss: 5.577725887298584
# Time taken: 3516.95s
#
# Start of epoch 100
# Average training loss at epoch 100: 3.9285831
# Epoch val loss: 5.516191482543945
# Time taken: 3551.96s
#
# Start of epoch 101
# Average training loss at epoch 101: 3.9171672
# Epoch val loss: 5.555273532867432
# Time taken: 3587.15s
#
# Start of epoch 102
# Average training loss at epoch 102: 3.9711666
# Epoch val loss: 5.483157157897949
# Time taken: 3621.44s
#
# Start of epoch 103
# Average training loss at epoch 103: 3.9512935
# Epoch val loss: 5.667230606079102
# Time taken: 3656.26s
#
# Start of epoch 104
# Average training loss at epoch 104: 3.9491482
# Epoch val loss: 5.563927173614502
# Time taken: 3691.14s
#
# Start of epoch 105
# Average training loss at epoch 105: 3.9256134
# Epoch val loss: 5.567218780517578
# Time taken: 3725.86s
#
# Start of epoch 106
# Average training loss at epoch 106: 3.9087353
# Epoch val loss: 5.573533535003662
# Time taken: 3761.08s
#
# Start of epoch 107
# Average training loss at epoch 107: 3.9129930
# Epoch val loss: 5.521254062652588
# Time taken: 3796.39s
#
# Start of epoch 108
# Average training loss at epoch 108: 3.9542627
# Epoch val loss: 5.733118057250977
# Time taken: 3831.36s
#
# Start of epoch 109
# Average training loss at epoch 109: 3.9995837
# Epoch val loss: 5.360268592834473
# Time taken: 3866.68s
#
# Start of epoch 110
# Average training loss at epoch 110: 4.0187407
# Epoch val loss: 5.482726573944092
# Time taken: 3901.08s
#
# Start of epoch 111
# Average training loss at epoch 111: 3.9916573
# Epoch val loss: 5.65665864944458
# Time taken: 3935.85s
#
# Start of epoch 112
# Average training loss at epoch 112: 3.9286342
# Epoch val loss: 5.616761684417725
# Time taken: 3970.12s
#
# Start of epoch 113
# Average training loss at epoch 113: 3.9431067
# Epoch val loss: 5.705530643463135
# Time taken: 4005.16s
#
# Start of epoch 114
# Average training loss at epoch 114: 3.9527583
# Epoch val loss: 5.701613903045654
# Time taken: 4039.80s
#
# Start of epoch 115
# Average training loss at epoch 115: 3.9302218
# Epoch val loss: 6.9127583503723145
# Time taken: 4074.12s
#
# Start of epoch 116
# Average training loss at epoch 116: 4.0401511
# Epoch val loss: 5.523868083953857
# Time taken: 4108.58s
#
# Start of epoch 117
# Average training loss at epoch 117: 3.9764884
# Epoch val loss: 5.557730674743652
# Time taken: 4143.75s
#
# Start of epoch 118
# Average training loss at epoch 118: 3.9203978
# Epoch val loss: 5.525087356567383
# Time taken: 4178.33s
#
# Start of epoch 119
# Average training loss at epoch 119: 3.8934298
# Epoch val loss: 5.5828142166137695
# Time taken: 4212.80s
#
# Start of epoch 120
# Average training loss at epoch 120: 3.9251404
# Epoch val loss: 5.60698938369751
# Time taken: 4247.62s
#
# Start of epoch 121
# Average training loss at epoch 121: 3.9307890
# Epoch val loss: 5.594181060791016
# Time taken: 4282.87s
#
# Start of epoch 122
# Average training loss at epoch 122: 3.9225039
# Epoch val loss: 5.866811752319336
# Time taken: 4317.87s
#
# Start of epoch 123
# Average training loss at epoch 123: 3.9349241
# Epoch val loss: 5.42709493637085
# Time taken: 4353.01s
#
# Start of epoch 124
# Average training loss at epoch 124: 3.8918462
# Epoch val loss: 5.497344493865967
# Time taken: 4387.65s
#
# Start of epoch 125
# Average training loss at epoch 125: 3.9121020
# Epoch val loss: 5.509544849395752
# Time taken: 4422.07s
#
# Start of epoch 126
# Average training loss at epoch 126: 3.8812804
# Epoch val loss: 6.034726142883301
# Time taken: 4457.95s
#
# Start of epoch 127
# Average training loss at epoch 127: 3.8885465
# Epoch val loss: 5.740659713745117
# Time taken: 4492.93s
#
# Start of epoch 128
# Average training loss at epoch 128: 3.9630890
# Epoch val loss: 5.52609395980835
# Time taken: 4527.32s
#
# Start of epoch 129
# Average training loss at epoch 129: 3.8764048
# Epoch val loss: 5.918197154998779
# Time taken: 4562.14s
#
# Start of epoch 130
# Average training loss at epoch 130: 3.9616742
# Epoch val loss: 5.951078414916992
# Time taken: 4596.42s
#
# Start of epoch 131
# Average training loss at epoch 131: 3.9624701
# Epoch val loss: 5.671908378601074
# Time taken: 4631.37s
#
# Start of epoch 132
# Average training loss at epoch 132: 4.0528040
# Epoch val loss: 6.124265193939209
# Time taken: 4665.77s
#
# Start of epoch 133
# Average training loss at epoch 133: 3.9516451
# Epoch val loss: 5.996947765350342
# Time taken: 4700.41s
#
# Start of epoch 134
# Average training loss at epoch 134: 3.9330325
# Epoch val loss: 6.144923686981201
# Time taken: 4735.35s
#
# Start of epoch 135
# Average training loss at epoch 135: 3.9588468
# Epoch val loss: 5.568377494812012
# Time taken: 4770.29s
#
# Start of epoch 136
# Average training loss at epoch 136: 3.8830414
# Epoch val loss: 6.725238800048828
# Time taken: 4805.04s
#
# Start of epoch 137
# Average training loss at epoch 137: 3.9221466
# Epoch val loss: 6.963479995727539
# Time taken: 4839.71s
#
# Start of epoch 138
# Average training loss at epoch 138: 3.9268870
# Epoch val loss: 5.825673580169678
# Time taken: 4874.09s
#
# Start of epoch 139
# Average training loss at epoch 139: 3.8726273
# Epoch val loss: 5.560689449310303
# Time taken: 4909.14s
#
# Start of epoch 140
# Average training loss at epoch 140: 3.8811164
# Epoch val loss: 6.682933330535889
# Time taken: 4944.56s
#
# Start of epoch 141
# Average training loss at epoch 141: 4.0344467
# Epoch val loss: 6.3564133644104
# Time taken: 4979.69s
#
# Start of epoch 142
# Average training loss at epoch 142: 3.8716276
# Epoch val loss: 7.132555961608887
# Time taken: 5013.92s
#
# Start of epoch 143
# Average training loss at epoch 143: 3.9309921
# Epoch val loss: 5.639735698699951
# Time taken: 5048.71s
#
# Start of epoch 144
# Average training loss at epoch 144: 3.9229236
# Epoch val loss: 5.741466999053955
# Time taken: 5083.20s
#
# Start of epoch 145
# Average training loss at epoch 145: 3.8805451
# Epoch val loss: 5.887204647064209
# Time taken: 5117.80s
#
# Start of epoch 146
# Average training loss at epoch 146: 3.9213462
# Epoch val loss: 6.677475929260254
# Time taken: 5152.13s
#
# Start of epoch 147
# Average training loss at epoch 147: 3.9357278
# Epoch val loss: 5.472337245941162
# Time taken: 5188.17s
#
# Start of epoch 148
# Average training loss at epoch 148: 3.8572574
# Epoch val loss: 5.80961275100708
# Time taken: 5223.20s
#
# Start of epoch 149
# Average training loss at epoch 149: 3.8368678
# Epoch val loss: 7.356273651123047
# Time taken: 5257.76s
#
# Start of epoch 150
# Average training loss at epoch 150: 3.8594799
# Epoch val loss: 6.430434703826904
# Time taken: 5292.40s
#
# Start of epoch 151
# Average training loss at epoch 151: 3.9253817
# Epoch val loss: 5.721881866455078
# Time taken: 5327.36s
#
# Start of epoch 152
# Average training loss at epoch 152: 3.8608809
# Epoch val loss: 5.854665279388428
# Time taken: 5362.27s
#
# Start of epoch 153
# Average training loss at epoch 153: 3.7967975
# Epoch val loss: 5.980685234069824
# Time taken: 5397.15s
#
# Start of epoch 154
# Average training loss at epoch 154: 3.8047795
# Epoch val loss: 7.295050621032715
# Time taken: 5431.87s
#
# Start of epoch 155
# Average training loss at epoch 155: 3.9284334
# Epoch val loss: 5.585710525512695
# Time taken: 5466.91s
#
# Start of epoch 156
# Average training loss at epoch 156: 3.9071343
# Epoch val loss: 6.704032897949219
# Time taken: 5501.45s
#
# Start of epoch 157
# Average training loss at epoch 157: 3.8752065
# Epoch val loss: 5.56592321395874
# Time taken: 5536.60s
#
# Start of epoch 158
# Average training loss at epoch 158: 3.8280697
# Epoch val loss: 5.607222080230713
# Time taken: 5571.41s
#
# Start of epoch 159
# Average training loss at epoch 159: 3.8530545
# Epoch val loss: 6.210461616516113
# Time taken: 5606.40s
#
# Start of epoch 160
# Average training loss at epoch 160: 3.7908387
# Epoch val loss: 6.471674919128418
# Time taken: 5641.30s
#
# Start of epoch 161
# Average training loss at epoch 161: 3.8573451
# Epoch val loss: 7.405474662780762
# Time taken: 5675.93s
#
# Start of epoch 162
# Average training loss at epoch 162: 3.9105587
# Epoch val loss: 6.383603096008301
# Time taken: 5710.33s
#
# Start of epoch 163
# Average training loss at epoch 163: 3.8340971
# Epoch val loss: 7.5625691413879395
# Time taken: 5745.22s
#
# Start of epoch 164
# Average training loss at epoch 164: 3.8921061
# Epoch val loss: 6.351083755493164
# Time taken: 5779.81s
#
# Start of epoch 165
# Average training loss at epoch 165: 3.8158476
# Epoch val loss: 6.311953544616699
# Time taken: 5814.82s
#
# Start of epoch 166
# Average training loss at epoch 166: 3.9186094
# Epoch val loss: 6.252917289733887
# Time taken: 5849.86s
#
# Start of epoch 167
# Average training loss at epoch 167: 3.8605151
# Epoch val loss: 6.061732769012451
# Time taken: 5884.89s
#
# Start of epoch 168
# Average training loss at epoch 168: 3.8014624
# Epoch val loss: 6.890953540802002
# Time taken: 5919.82s
#
# Start of epoch 169
# Average training loss at epoch 169: 3.8957055
# Epoch val loss: 6.542546272277832
# Time taken: 5955.06s
#
# Start of epoch 170
# Average training loss at epoch 170: 3.8028426
# Epoch val loss: 7.414308071136475
# Time taken: 5989.54s
#
# Start of epoch 171
# Average training loss at epoch 171: 3.8294001
# Epoch val loss: 5.891351699829102
# Time taken: 6024.24s
#
# Start of epoch 172
# Average training loss at epoch 172: 3.7451303
# Epoch val loss: 6.396202087402344
# Time taken: 6058.43s
#
# Start of epoch 173
# Average training loss at epoch 173: 3.8671513
# Epoch val loss: 5.51790714263916
# Time taken: 6093.48s
#
# Start of epoch 174
# Average training loss at epoch 174: 3.7950442
# Epoch val loss: 5.954409599304199
# Time taken: 6127.78s
#
# Start of epoch 175
# Average training loss at epoch 175: 3.8068113
# Epoch val loss: 6.170865058898926
# Time taken: 6162.77s
#
# Start of epoch 176
# Average training loss at epoch 176: 3.8240294
# Epoch val loss: 6.180915355682373
# Time taken: 6197.40s
#
# Start of epoch 177
# Average training loss at epoch 177: 3.8600814
# Epoch val loss: 6.958901405334473
# Time taken: 6231.75s
#
# Start of epoch 178
# Average training loss at epoch 178: 3.7624087
# Epoch val loss: 6.686933994293213
# Time taken: 6266.39s
#
# Start of epoch 179
# Average training loss at epoch 179: 3.6902003
# Epoch val loss: 6.35310173034668
# Time taken: 6301.04s
#
# Start of epoch 180
# Average training loss at epoch 180: 3.6942012
# Epoch val loss: 6.419677734375
# Time taken: 6335.68s
#
# Start of epoch 181
# Average training loss at epoch 181: 3.8124995
# Epoch val loss: 6.186581611633301
# Time taken: 6370.68s
#
# Start of epoch 182
# Average training loss at epoch 182: 3.7551200
# Epoch val loss: 6.149130821228027
# Time taken: 6406.50s
#
# Start of epoch 183
# Average training loss at epoch 183: 3.7414854
# Epoch val loss: 6.598223686218262
# Time taken: 6441.33s
#
# Start of epoch 184
# Average training loss at epoch 184: 3.7558639
# Epoch val loss: 7.04210901260376
# Time taken: 6475.83s
#
# Start of epoch 185
# Average training loss at epoch 185: 3.7136040
# Epoch val loss: 6.309482097625732
# Time taken: 6510.46s
#
# Start of epoch 186
# Average training loss at epoch 186: 3.8574584
# Epoch val loss: 5.899501800537109
# Time taken: 6545.71s
#
# Start of epoch 187
# Average training loss at epoch 187: 3.6739087
# Epoch val loss: 7.091012477874756
# Time taken: 6580.95s
#
# Start of epoch 188
# Average training loss at epoch 188: 3.7070594
# Epoch val loss: 7.090364456176758
# Time taken: 6615.40s
#
# Start of epoch 189
# Average training loss at epoch 189: 3.6987138
# Epoch val loss: 5.878612518310547
# Time taken: 6649.64s
#
# Start of epoch 190
# Average training loss at epoch 190: 3.6617687
# Epoch val loss: 6.164924144744873
# Time taken: 6684.53s
#
# Start of epoch 191
# Average training loss at epoch 191: 3.7707791
# Epoch val loss: 5.780444145202637
# Time taken: 6719.25s
#
# Start of epoch 192
# Average training loss at epoch 192: 3.6906662
# Epoch val loss: 6.082979679107666
# Time taken: 6753.67s
#
# Start of epoch 193
# Average training loss at epoch 193: 3.7040892
# Epoch val loss: 5.728578090667725
# Time taken: 6788.26s
#
# Start of epoch 194
# Average training loss at epoch 194: 3.7520838
# Epoch val loss: 5.23637056350708
# Time taken: 6823.37s
#
# Start of epoch 195
# Average training loss at epoch 195: 3.7866497
# Epoch val loss: 5.411446571350098
# Time taken: 6858.29s
#
# Start of epoch 196
# Average training loss at epoch 196: 3.7142272
# Epoch val loss: 5.718820095062256
# Time taken: 6892.90s
#
# Start of epoch 197
# Average training loss at epoch 197: 3.6083889
# Epoch val loss: 6.313329696655273
# Time taken: 6927.72s
#
# Start of epoch 198
# Average training loss at epoch 198: 3.6623459
# Epoch val loss: 6.616569519042969
# Time taken: 6962.61s
#
# Start of epoch 199
# Average training loss at epoch 199: 3.6128242
# Epoch val loss: 6.1485595703125
# Time taken: 6997.43s
#
# Start of epoch 200
# Average training loss at epoch 200: 3.5561979
# Epoch val loss: 6.818297863006592
# Time taken: 7031.78s
#
# Start of epoch 201
# Average training loss at epoch 201: 3.7257063
# Epoch val loss: 5.676192283630371
# Time taken: 7066.61s
#
# Start of epoch 202
# Average training loss at epoch 202: 3.6678953
# Epoch val loss: 5.384817600250244
# Time taken: 7101.21s
#
# Start of epoch 203
# Average training loss at epoch 203: 3.6476603
# Epoch val loss: 5.291013717651367
# Time taken: 7135.78s
#
# Start of epoch 204
# Average training loss at epoch 204: 3.5931163
# Epoch val loss: 6.314389228820801
# Time taken: 7170.71s
#
# Start of epoch 205
# Average training loss at epoch 205: 3.6189976
# Epoch val loss: 6.286141395568848
# Time taken: 7205.37s
#
# Start of epoch 206
# Average training loss at epoch 206: 3.6372981
# Epoch val loss: 6.708157062530518
# Time taken: 7240.63s
#
# Start of epoch 207
# Average training loss at epoch 207: 3.5436988
# Epoch val loss: 5.858339786529541
# Time taken: 7274.95s
#
# Start of epoch 208
# Average training loss at epoch 208: 3.5430884
# Epoch val loss: 7.047816753387451
# Time taken: 7309.27s
#
# Start of epoch 209
# Average training loss at epoch 209: 3.5289390
# Epoch val loss: 5.995223045349121
# Time taken: 7344.01s
#
# Start of epoch 210
# Average training loss at epoch 210: 3.5641413
# Epoch val loss: 6.078615665435791
# Time taken: 7378.56s
#
# Start of epoch 211
# Average training loss at epoch 211: 3.5189414
# Epoch val loss: 5.7716875076293945
# Time taken: 7413.65s
#
# Start of epoch 212
# Average training loss at epoch 212: 3.5830269
# Epoch val loss: 6.137170791625977
# Time taken: 7448.53s
#
# Start of epoch 213
# Average training loss at epoch 213: 3.6884379
# Epoch val loss: 5.508094787597656
# Time taken: 7483.31s
#
# Start of epoch 214
# Average training loss at epoch 214: 3.5132899
# Epoch val loss: 7.493747234344482
# Time taken: 7518.41s
#
# Start of epoch 215
# Average training loss at epoch 215: 3.4662633
# Epoch val loss: 7.948998928070068
# Time taken: 7552.90s
#
# Start of epoch 216
# Average training loss at epoch 216: 3.6388121
# Epoch val loss: 5.574881076812744
# Time taken: 7588.76s
#
# Start of epoch 217
# Average training loss at epoch 217: 3.4545710
# Epoch val loss: 5.969663619995117
# Time taken: 7623.49s
#
# Start of epoch 218
# Average training loss at epoch 218: 3.6798477
# Epoch val loss: 6.03326416015625
# Time taken: 7659.42s
#
# Start of epoch 219
# Average training loss at epoch 219: 3.5546613
# Epoch val loss: 6.944588661193848
# Time taken: 7695.00s
#
# Start of epoch 220
# Average training loss at epoch 220: 3.5138316
# Epoch val loss: 5.708227634429932
# Time taken: 7731.34s
#
# Start of epoch 221
# Average training loss at epoch 221: 3.5805094
# Epoch val loss: 5.595296382904053
# Time taken: 7766.60s
#
# Start of epoch 222
# Average training loss at epoch 222: 3.5348701
# Epoch val loss: 7.987622261047363
# Time taken: 7802.05s
#
# Start of epoch 223
# Average training loss at epoch 223: 3.4716425
# Epoch val loss: 6.414424896240234
# Time taken: 7837.21s
#
# Start of epoch 224
# Average training loss at epoch 224: 3.6181288
# Epoch val loss: 7.333935260772705
# Time taken: 7872.55s
#
# Start of epoch 225
# Average training loss at epoch 225: 3.4883497
# Epoch val loss: 6.506117343902588
# Time taken: 7908.35s
#
# Start of epoch 226
# Average training loss at epoch 226: 3.4316769
# Epoch val loss: 6.632318496704102
# Time taken: 7943.84s
#
# Start of epoch 227
# Average training loss at epoch 227: 3.4491482
# Epoch val loss: 7.801661491394043
# Time taken: 7979.19s
#
# Start of epoch 228
# Average training loss at epoch 228: 3.4494133
# Epoch val loss: 7.148409843444824
# Time taken: 8014.83s
#
# Start of epoch 229
# Average training loss at epoch 229: 3.5721052
# Epoch val loss: 7.3800153732299805
# Time taken: 8049.90s
#
# Start of epoch 230
# Average training loss at epoch 230: 3.3137560
# Epoch val loss: 7.965614318847656
# Time taken: 8084.76s
#
# Start of epoch 231
# Average training loss at epoch 231: 3.3515086
# Epoch val loss: 7.472273349761963
# Time taken: 8119.89s
#
# Start of epoch 232
# Average training loss at epoch 232: 3.4487123
# Epoch val loss: 6.761637210845947
# Time taken: 8154.91s
#
# Start of epoch 233
# Average training loss at epoch 233: 3.6228554
# Epoch val loss: 7.3041768074035645
# Time taken: 8189.37s
#
# Start of epoch 234
# Average training loss at epoch 234: 3.4007683
# Epoch val loss: 6.785280227661133
# Time taken: 8224.05s
#
# Start of epoch 235
# Average training loss at epoch 235: 3.4372792
# Epoch val loss: 8.131832122802734
# Time taken: 8258.99s
#
# Start of epoch 236
# Average training loss at epoch 236: 3.3404148
# Epoch val loss: 7.39823579788208
# Time taken: 8293.98s
#
# Start of epoch 237
# Average training loss at epoch 237: 3.3792753
# Epoch val loss: 7.378931999206543
# Time taken: 8328.74s
#
# Start of epoch 238
# Average training loss at epoch 238: 3.3768644
# Epoch val loss: 6.8865838050842285
# Time taken: 8363.34s
#
# Start of epoch 239
# Average training loss at epoch 239: 3.4349797
# Epoch val loss: 7.971312999725342
# Time taken: 8398.01s
#
# Start of epoch 240
# Average training loss at epoch 240: 3.4219718
# Epoch val loss: 5.762614727020264
# Time taken: 8432.68s
#
# Start of epoch 241
# Average training loss at epoch 241: 3.4240017
# Epoch val loss: 7.651891708374023
# Time taken: 8467.32s
#
# Start of epoch 242
# Average training loss at epoch 242: 3.3393636
# Epoch val loss: 6.536970138549805
# Time taken: 8502.12s
#
# Start of epoch 243
# Average training loss at epoch 243: 3.4013505
# Epoch val loss: 8.692596435546875
# Time taken: 8537.40s
#
# Start of epoch 244
# Average training loss at epoch 244: 3.4203868
# Epoch val loss: 7.160630226135254
# Time taken: 8572.06s
#
# Start of epoch 245
# Average training loss at epoch 245: 3.3966262
# Epoch val loss: 8.172273635864258
# Time taken: 8606.98s
#
# Start of epoch 246
# Average training loss at epoch 246: 3.2879634
# Epoch val loss: 8.154459953308105
# Time taken: 8641.53s
#
# Start of epoch 247
# Average training loss at epoch 247: 3.2654297
# Epoch val loss: 8.067305564880371
# Time taken: 8676.56s
#
# Start of epoch 248
# Average training loss at epoch 248: 3.3474498
# Epoch val loss: 7.377957820892334
# Time taken: 8710.98s
#
# Start of epoch 249
# Average training loss at epoch 249: 3.2866292
# Epoch val loss: 8.249739646911621
# Time taken: 8746.05s
#
# Start of epoch 250
# Average training loss at epoch 250: 3.2299075
# Epoch val loss: 7.1789655685424805
# Time taken: 8780.68s
#
# Start of epoch 251
# Average training loss at epoch 251: 3.4323235
# Epoch val loss: 5.757177829742432
# Time taken: 8815.95s
#
# Start of epoch 252
# Average training loss at epoch 252: 3.4476354
# Epoch val loss: 7.269103527069092
# Time taken: 8850.63s
#
# Start of epoch 253
# Average training loss at epoch 253: 3.2918196
# Epoch val loss: 8.23669719696045
# Time taken: 8884.88s
#
# Start of epoch 254
# Average training loss at epoch 254: 3.1266530
# Epoch val loss: 7.144082546234131
# Time taken: 8919.04s
#
# Start of epoch 255
# Average training loss at epoch 255: 3.2780604
# Epoch val loss: 7.774705410003662
# Time taken: 8954.66s
#
# Start of epoch 256
# Average training loss at epoch 256: 3.1742349
# Epoch val loss: 7.200100421905518
# Time taken: 8989.42s
#
# Start of epoch 257
# Average training loss at epoch 257: 3.1301610
# Epoch val loss: 7.721738338470459
# Time taken: 9024.00s
#
# Start of epoch 258
# Average training loss at epoch 258: 3.1528015
# Epoch val loss: 7.399402618408203
# Time taken: 9058.93s
#
# Start of epoch 259
# Average training loss at epoch 259: 3.1058154
# Epoch val loss: 7.000466346740723
# Time taken: 9093.56s
#
# Start of epoch 260
# Average training loss at epoch 260: 3.1040645
# Epoch val loss: 7.427702903747559
# Time taken: 9128.34s
#
# Start of epoch 261
# Average training loss at epoch 261: 3.0950618
# Epoch val loss: 7.514209270477295
# Time taken: 9162.61s
#
# Start of epoch 262
# Average training loss at epoch 262: 3.3042359
# Epoch val loss: 7.81429386138916
# Time taken: 9197.19s
#
# Start of epoch 263
# Average training loss at epoch 263: 3.2249563
# Epoch val loss: 7.4740891456604
# Time taken: 9231.89s
#
# Start of epoch 264
# Average training loss at epoch 264: 3.1024714
# Epoch val loss: 7.662174224853516
# Time taken: 9267.06s
#
# Start of epoch 265
# Average training loss at epoch 265: 3.1229391
# Epoch val loss: 7.242802619934082
# Time taken: 9301.68s
#
# Start of epoch 266
# Average training loss at epoch 266: 2.9699540
# Epoch val loss: 7.983520984649658
# Time taken: 9336.69s
#
# Start of epoch 267
# Average training loss at epoch 267: 3.1412709
# Epoch val loss: 7.364130973815918
# Time taken: 9371.63s
#
# Start of epoch 268
# Average training loss at epoch 268: 3.1811929
# Epoch val loss: 8.283443450927734
# Time taken: 9407.49s
#
# Start of epoch 269
# Average training loss at epoch 269: 3.1169257
# Epoch val loss: 6.841283321380615
# Time taken: 9442.43s
#
# Start of epoch 270
# Average training loss at epoch 270: 3.1574979
# Epoch val loss: 7.411015033721924
# Time taken: 9476.91s
#
# Start of epoch 271
# Average training loss at epoch 271: 3.0747809
# Epoch val loss: 7.712393283843994
# Time taken: 9511.89s
#
# Start of epoch 272
# Average training loss at epoch 272: 3.0383065
# Epoch val loss: 6.67295503616333
# Time taken: 9546.43s
#
# Start of epoch 273
# Average training loss at epoch 273: 3.0802822
# Epoch val loss: 5.933104038238525
# Time taken: 9581.00s
#
# Start of epoch 274
# Average training loss at epoch 274: 3.1081312
# Epoch val loss: 8.115429878234863
# Time taken: 9615.98s
#
# Start of epoch 275
# Average training loss at epoch 275: 2.9215858
# Epoch val loss: 7.421432971954346
# Time taken: 9650.28s
#
# Start of epoch 276
# Average training loss at epoch 276: 3.0113356
# Epoch val loss: 8.106396675109863
# Time taken: 9685.16s
#
# Start of epoch 277
# Average training loss at epoch 277: 2.9693799
# Epoch val loss: 7.662463188171387
# Time taken: 9719.96s
#
# Start of epoch 278
# Average training loss at epoch 278: 2.9205592
# Epoch val loss: 7.735835075378418
# Time taken: 9755.02s
#
# Start of epoch 279
# Average training loss at epoch 279: 2.9242167
# Epoch val loss: 7.151855945587158
# Time taken: 9789.16s
#
# Start of epoch 280
# Average training loss at epoch 280: 3.0528104
# Epoch val loss: 6.850775718688965
# Time taken: 9823.42s
#
# Start of epoch 281
# Average training loss at epoch 281: 3.0410855
# Epoch val loss: 8.932734489440918
# Time taken: 9857.94s
#
# Start of epoch 282
# Average training loss at epoch 282: 3.7231650
# Epoch val loss: 7.978333950042725
# Time taken: 9892.52s
#
# Start of epoch 283
# Average training loss at epoch 283: 3.1529012
# Epoch val loss: 8.6919527053833
# Time taken: 9926.69s
#
# Start of epoch 284
# Average training loss at epoch 284: 2.9551237
# Epoch val loss: 7.303424835205078
# Time taken: 9961.09s
#
# Start of epoch 285
# Average training loss at epoch 285: 2.8981271
# Epoch val loss: 7.15059232711792
# Time taken: 9997.08s
#
# Start of epoch 286
# Average training loss at epoch 286: 3.0116897
# Epoch val loss: 5.577446937561035
# Time taken: 10032.05s
#
# Start of epoch 287
# Average training loss at epoch 287: 2.9695146
# Epoch val loss: 6.233819007873535
# Time taken: 10067.07s
#
# Start of epoch 288
# Average training loss at epoch 288: 3.0266974
# Epoch val loss: 7.290851593017578
# Time taken: 10101.73s
#
# Start of epoch 289
# Average training loss at epoch 289: 3.0973787
# Epoch val loss: 6.786791801452637
# Time taken: 10136.44s
#
# Start of epoch 290
# Average training loss at epoch 290: 2.9033589
# Epoch val loss: 6.552229881286621
# Time taken: 10171.29s
#
# Start of epoch 291
# Average training loss at epoch 291: 2.8785186
# Epoch val loss: 7.518021583557129
# Time taken: 10206.04s
#
# Start of epoch 292
# Average training loss at epoch 292: 3.0247674
# Epoch val loss: 6.553840637207031
# Time taken: 10240.70s
#
# Start of epoch 293
# Average training loss at epoch 293: 2.9444633
# Epoch val loss: 7.825292587280273
# Time taken: 10274.87s
#
# Start of epoch 294
# Average training loss at epoch 294: 3.0774632
# Epoch val loss: 6.985446453094482
# Time taken: 10309.75s
#
# Start of epoch 295
# Average training loss at epoch 295: 3.0150676
# Epoch val loss: 6.441917419433594
# Time taken: 10344.62s
#
# Start of epoch 296
# Average training loss at epoch 296: 2.9101143
# Epoch val loss: 7.838149547576904
# Time taken: 10379.70s
#
# Start of epoch 297
# Average training loss at epoch 297: 2.9879065
# Epoch val loss: 7.620830059051514
# Time taken: 10414.67s
#
# Start of epoch 298
# Average training loss at epoch 298: 2.9090934
# Epoch val loss: 7.699464321136475
# Time taken: 10449.01s
#
# Start of epoch 299
# Average training loss at epoch 299: 2.8889084
# Epoch val loss: 7.702669620513916
# Time taken: 10483.30s
#
# Start of epoch 300
# Average training loss at epoch 300: 2.9966173
# Epoch val loss: 5.642255783081055
# Time taken: 10518.21s
#
# Start of epoch 301
# Average training loss at epoch 301: 3.0256827
# Epoch val loss: 7.147774696350098
# Time taken: 10552.87s
#
# Start of epoch 302
# Average training loss at epoch 302: 2.9029474
# Epoch val loss: 6.168370723724365
# Time taken: 10587.61s
#
# Start of epoch 303
# Average training loss at epoch 303: 2.8948545
# Epoch val loss: 6.727781772613525
# Time taken: 10622.72s
#
# Start of epoch 304
# Average training loss at epoch 304: 2.8440285
# Epoch val loss: 7.223711967468262
# Time taken: 10657.70s
#
# Start of epoch 305
# Average training loss at epoch 305: 2.7018929
# Epoch val loss: 6.200872898101807
# Time taken: 10692.36s
#
# Start of epoch 306
# Average training loss at epoch 306: 2.9217653
# Epoch val loss: 7.046262741088867
# Time taken: 10726.69s
#
# Start of epoch 307
# Average training loss at epoch 307: 2.9203806
# Epoch val loss: 6.120752334594727
# Time taken: 10761.26s
#
# Start of epoch 308
# Average training loss at epoch 308: 2.9067931
# Epoch val loss: 6.922351837158203
# Time taken: 10796.48s
#
# Start of epoch 309
# Average training loss at epoch 309: 3.0682025
# Epoch val loss: 6.422883987426758
# Time taken: 10831.45s
#
# Start of epoch 310
# Average training loss at epoch 310: 2.9275308
# Epoch val loss: 6.4468817710876465
# Time taken: 10866.50s
#
# Start of epoch 311
# Average training loss at epoch 311: 2.9264369
# Epoch val loss: 5.999586582183838
# Time taken: 10902.16s
#
# Start of epoch 312
# Average training loss at epoch 312: 2.9922104
# Epoch val loss: 4.837941646575928
# Time taken: 10936.81s
#
# Start of epoch 313
# Average training loss at epoch 313: 2.8572271
# Epoch val loss: 6.76833438873291
# Time taken: 10971.71s
#
# Start of epoch 314
# Average training loss at epoch 314: 2.7292056
# Epoch val loss: 6.8037567138671875
# Time taken: 11006.99s
#
# Start of epoch 315
# Average training loss at epoch 315: 2.7258711
# Epoch val loss: 6.537880897521973
# Time taken: 11042.14s
#
# Start of epoch 316
# Average training loss at epoch 316: 3.0038009
# Epoch val loss: 6.443881988525391
# Time taken: 11077.31s
#
# Start of epoch 317
# Average training loss at epoch 317: 3.0040298
# Epoch val loss: 5.947795391082764
# Time taken: 11112.25s
#
# Start of epoch 318
# Average training loss at epoch 318: 2.7928107
# Epoch val loss: 5.032068729400635
# Time taken: 11146.63s
#
# Start of epoch 319
# Average training loss at epoch 319: 2.6901326
# Epoch val loss: 4.797945022583008
# Time taken: 11181.62s
#
# Start of epoch 320
# Average training loss at epoch 320: 2.9161291
# Epoch val loss: 5.539440631866455
# Time taken: 11215.51s
#
# Start of epoch 321
# Average training loss at epoch 321: 2.7239377
# Epoch val loss: 6.395172119140625
# Time taken: 11250.22s
#
# Start of epoch 322
# Average training loss at epoch 322: 2.7722182
# Epoch val loss: 4.885314464569092
# Time taken: 11284.96s
#
# Start of epoch 323
# Average training loss at epoch 323: 2.6892486
# Epoch val loss: 4.70009183883667
# Time taken: 11320.44s
#
# Start of epoch 324
# Average training loss at epoch 324: 2.6188858
# Epoch val loss: 5.3562164306640625
# Time taken: 11354.94s
#
# Start of epoch 325
# Average training loss at epoch 325: 2.7328591
# Epoch val loss: 5.671960353851318
# Time taken: 11390.49s
#
# Start of epoch 326
# Average training loss at epoch 326: 2.8647134
# Epoch val loss: 6.045210361480713
# Time taken: 11425.53s
#
# Start of epoch 327
# Average training loss at epoch 327: 2.8441517
# Epoch val loss: 5.010756969451904
# Time taken: 11460.15s
#
# Start of epoch 328
# Average training loss at epoch 328: 2.6116390
# Epoch val loss: 6.4006524085998535
# Time taken: 11494.80s
#
# Start of epoch 329
# Average training loss at epoch 329: 2.7007079
# Epoch val loss: 4.788003921508789
# Time taken: 11530.34s
#
# Start of epoch 330
# Average training loss at epoch 330: 2.8419287
# Epoch val loss: 5.742693901062012
# Time taken: 11565.58s
#
# Start of epoch 331
# Average training loss at epoch 331: 2.6050920
# Epoch val loss: 5.611347198486328
# Time taken: 11600.20s
#
# Start of epoch 332
# Average training loss at epoch 332: 2.7735696
# Epoch val loss: 5.863349914550781
# Time taken: 11634.99s
#
# Start of epoch 333
# Average training loss at epoch 333: 2.4958329
# Epoch val loss: 6.031401634216309
# Time taken: 11670.18s
#
# Start of epoch 334
# Average training loss at epoch 334: 2.5896115
# Epoch val loss: 5.729137420654297
# Time taken: 11705.11s
#
# Start of epoch 335
# Average training loss at epoch 335: 2.8240390
# Epoch val loss: 5.862745761871338
# Time taken: 11739.84s
#
# Start of epoch 336
# Average training loss at epoch 336: 2.7594304
# Epoch val loss: 5.481410503387451
# Time taken: 11774.49s
#
# Start of epoch 337
# Average training loss at epoch 337: 2.6526017
# Epoch val loss: 4.866006374359131
# Time taken: 11808.99s
#
# Start of epoch 338
# Average training loss at epoch 338: 2.5162704
# Epoch val loss: 4.906638145446777
# Time taken: 11843.55s
#
# Start of epoch 339
# Average training loss at epoch 339: 2.4806075
# Epoch val loss: 4.424565315246582
# Time taken: 11877.80s
#
# Start of epoch 340
# Average training loss at epoch 340: 2.7777035
# Epoch val loss: 5.0641045570373535
# Time taken: 11911.77s
#
# Start of epoch 341
# Average training loss at epoch 341: 3.5134411
# Epoch val loss: 5.352162837982178
# Time taken: 11946.65s
#
# Start of epoch 342
# Average training loss at epoch 342: 2.7472982
# Epoch val loss: 5.8990888595581055
# Time taken: 11981.75s
#
# Start of epoch 343
# Average training loss at epoch 343: 2.6129689
# Epoch val loss: 4.91447114944458
# Time taken: 12016.12s
#
# Start of epoch 344
# Average training loss at epoch 344: 2.6633248
# Epoch val loss: 4.491527080535889
# Time taken: 12050.81s
#
# Start of epoch 345
# Average training loss at epoch 345: 2.6881604
# Epoch val loss: 5.052227020263672
# Time taken: 12085.54s
#
# Start of epoch 346
# Average training loss at epoch 346: 2.7947164
# Epoch val loss: 5.483104705810547
# Time taken: 12119.91s
#
# Start of epoch 347
# Average training loss at epoch 347: 2.6986055
# Epoch val loss: 6.101013660430908
# Time taken: 12154.44s
#
# Start of epoch 348
# Average training loss at epoch 348: 2.7545021
# Epoch val loss: 4.898517608642578
# Time taken: 12189.08s
#
# Start of epoch 349
# Average training loss at epoch 349: 2.5667071
# Epoch val loss: 6.383438587188721
# Time taken: 12224.61s
#
# Start of epoch 350
# Average training loss at epoch 350: 2.6045091
# Epoch val loss: 6.844482421875
# Time taken: 12258.81s
#
# Start of epoch 351
# Average training loss at epoch 351: 2.9607563
# Epoch val loss: 7.06644344329834
# Time taken: 12293.08s
#
# Start of epoch 352
# Average training loss at epoch 352: 2.6237788
# Epoch val loss: 6.590527534484863
# Time taken: 12328.11s
#
# Start of epoch 353
# Average training loss at epoch 353: 2.5505018
# Epoch val loss: 4.443068981170654
# Time taken: 12362.80s
#
# Start of epoch 354
# Average training loss at epoch 354: 2.5127008
# Epoch val loss: 6.249990463256836
# Time taken: 12396.97s
#
# Start of epoch 355
# Average training loss at epoch 355: 2.4727340
# Epoch val loss: 5.858038425445557
# Time taken: 12432.33s
#
# Start of epoch 356
# Average training loss at epoch 356: 2.7030010
# Epoch val loss: 6.204098224639893
# Time taken: 12466.32s
#
# Start of epoch 357
# Average training loss at epoch 357: 2.5734458
# Epoch val loss: 6.868756294250488
# Time taken: 12500.77s
#
# Start of epoch 358
# Average training loss at epoch 358: 2.4679976
# Epoch val loss: 5.684597969055176
# Time taken: 12534.96s
#
# Start of epoch 359
# Average training loss at epoch 359: 2.4392107
# Epoch val loss: 5.5185770988464355
# Time taken: 12569.30s
#
# Start of epoch 360
# Average training loss at epoch 360: 2.3016315
# Epoch val loss: 5.415457725524902
# Time taken: 12604.46s
#
# Start of epoch 361
# Average training loss at epoch 361: 2.7570879
# Epoch val loss: 5.996188640594482
# Time taken: 12639.22s
#
# Start of epoch 362
# Average training loss at epoch 362: 2.7132349
# Epoch val loss: 7.741347312927246
# Time taken: 12674.15s
#
# Start of epoch 363
# Average training loss at epoch 363: 2.8117390
# Epoch val loss: 6.8421125411987305
# Time taken: 12708.52s
#
# Start of epoch 364
# Average training loss at epoch 364: 3.2508266
# Epoch val loss: 8.152335166931152
# Time taken: 12743.24s
#
# Start of epoch 365
# Average training loss at epoch 365: 2.7784472
# Epoch val loss: 7.791323661804199
# Time taken: 12778.14s
#
# Start of epoch 366
# Average training loss at epoch 366: 2.8439727
# Epoch val loss: 6.718688011169434
# Time taken: 12813.00s
#
# Start of epoch 367
# Average training loss at epoch 367: 2.6620560
# Epoch val loss: 6.928993225097656
# Time taken: 12847.92s
#
# Start of epoch 368
# Average training loss at epoch 368: 2.6207385
# Epoch val loss: 7.168336391448975
# Time taken: 12883.26s
#
# Start of epoch 369
# Average training loss at epoch 369: 2.5178695
# Epoch val loss: 6.932247161865234
# Time taken: 12917.42s
#
# Start of epoch 370
# Average training loss at epoch 370: 2.4061561
# Epoch val loss: 6.743892192840576
# Time taken: 12952.18s
#
# Start of epoch 371
# Average training loss at epoch 371: 2.4107289
# Epoch val loss: 6.802903175354004
# Time taken: 12986.74s
#
# Start of epoch 372
# Average training loss at epoch 372: 2.5753546
# Epoch val loss: 7.589004039764404
# Time taken: 13022.62s
#
# Start of epoch 373
# Average training loss at epoch 373: 2.6276951
# Epoch val loss: 6.0254597663879395
# Time taken: 13058.00s
#
# Start of epoch 374
# Average training loss at epoch 374: 2.5071778
# Epoch val loss: 7.078619003295898
# Time taken: 13093.01s
#
# Start of epoch 375
# Average training loss at epoch 375: 2.4357252
# Epoch val loss: 7.839118003845215
# Time taken: 13128.18s
#
# Start of epoch 376
# Average training loss at epoch 376: 2.4334691
# Epoch val loss: 7.041451930999756
# Time taken: 13163.37s
#
# Start of epoch 377
# Average training loss at epoch 377: 2.4843922
# Epoch val loss: 8.970380783081055
# Time taken: 13198.46s
#
# Start of epoch 378
# Average training loss at epoch 378: 2.4135046
# Epoch val loss: 8.105976104736328
# Time taken: 13232.95s
#
# Start of epoch 379
# Average training loss at epoch 379: 2.7387354
# Epoch val loss: 6.020793914794922
# Time taken: 13267.51s
#
# Start of epoch 380
# Average training loss at epoch 380: 2.4817572
# Epoch val loss: 6.512491226196289
# Time taken: 13302.53s
#
# Start of epoch 381
# Average training loss at epoch 381: 2.4498525
# Epoch val loss: 7.433121681213379
# Time taken: 13337.42s
#
# Start of epoch 382
# Average training loss at epoch 382: 2.5556216
# Epoch val loss: 7.233902931213379
# Time taken: 13372.81s
#
# Start of epoch 383
# Average training loss at epoch 383: 2.5989852
# Epoch val loss: 6.414233684539795
# Time taken: 13407.20s
#
# Start of epoch 384
# Average training loss at epoch 384: 2.3744149
# Epoch val loss: 6.85364294052124
# Time taken: 13441.56s
#
# Start of epoch 385
# Average training loss at epoch 385: 2.3835282
# Epoch val loss: 6.247013568878174
# Time taken: 13476.20s
#
# Start of epoch 386
# Average training loss at epoch 386: 2.4801011
# Epoch val loss: 6.540491580963135
# Time taken: 13511.16s
#
# Start of epoch 387
# Average training loss at epoch 387: 2.2937281
# Epoch val loss: 6.877318382263184
# Time taken: 13545.60s
#
# Start of epoch 388
# Average training loss at epoch 388: 2.3970208
# Epoch val loss: 6.680136680603027
# Time taken: 13581.07s
#
# Start of epoch 389
# Average training loss at epoch 389: 2.4673867
# Epoch val loss: 6.400822162628174
# Time taken: 13615.37s
#
# Start of epoch 390
# Average training loss at epoch 390: 2.7057400
# Epoch val loss: 7.10390567779541
# Time taken: 13650.39s
#
# Start of epoch 391
# Average training loss at epoch 391: 2.3517847
# Epoch val loss: 6.787065029144287
# Time taken: 13684.99s
#
# Start of epoch 392
# Average training loss at epoch 392: 2.4201579
# Epoch val loss: 5.866830348968506
# Time taken: 13719.87s
#
# Start of epoch 393
# Average training loss at epoch 393: 2.4036958
# Epoch val loss: 7.527503967285156
# Time taken: 13754.88s
#
# Start of epoch 394
# Average training loss at epoch 394: 2.3278081
# Epoch val loss: 6.529775142669678
# Time taken: 13789.49s
#
# Start of epoch 395
# Average training loss at epoch 395: 2.3477311
# Epoch val loss: 5.948588848114014
# Time taken: 13824.57s
#
# Start of epoch 396
# Average training loss at epoch 396: 2.4475336
# Epoch val loss: 8.051405906677246
# Time taken: 13859.27s
#
# Start of epoch 397
# Average training loss at epoch 397: 2.4759133
# Epoch val loss: 7.334469318389893
# ...
# Time taken: 19905.02s
#
# Start of epoch 571
# Average training loss at epoch 571: 1.5920497
# Epoch val loss: 12.60393238067627
# Time taken: 19941.06s
#
# Start of epoch 572
# Average training loss at epoch 572: 1.6271698
# Epoch val loss: 12.541203498840332
# Time taken: 19976.45s
#
# Start of epoch 573
# Average training loss at epoch 573: 1.8021786
# Epoch val loss: 12.560254096984863
# Time taken: 20010.93s
#
# Start of epoch 574
# Average training loss at epoch 574: 1.7202135
# Epoch val loss: 13.594149589538574
# Time taken: 20045.76s
#
# Start of epoch 575
# Average training loss at epoch 575: 1.8332405
# Epoch val loss: 13.904914855957031
# Time taken: 20080.12s
#
# Start of epoch 576
# Average training loss at epoch 576: 1.5048025
# Epoch val loss: 13.759145736694336
# Time taken: 20115.06s
#
# Start of epoch 577
# Average training loss at epoch 577: 1.4614594
# Epoch val loss: 13.822781562805176
# Time taken: 20150.04s
#
# Start of epoch 578
# Average training loss at epoch 578: 1.5157480
# Epoch val loss: 12.97986888885498
# Time taken: 20185.87s
#
# Start of epoch 579
# Average training loss at epoch 579: 1.6742022
# Epoch val loss: 12.815364837646484
# Time taken: 20220.44s
#
# Start of epoch 580
# Average training loss at epoch 580: 1.6275291
# Epoch val loss: 11.870720863342285
# Time taken: 20254.96s
#
# Start of epoch 581
# Average training loss at epoch 581: 1.5137321
# Epoch val loss: 13.63772201538086
# Time taken: 20289.36s
#
# Start of epoch 582
# Average training loss at epoch 582: 1.4748682
# Epoch val loss: 12.804197311401367
# Time taken: 20324.16s
#
# Start of epoch 583
# Average training loss at epoch 583: 1.4588456
# Epoch val loss: 14.237761497497559
# Time taken: 20358.83s
#
# Start of epoch 584
# Average training loss at epoch 584: 1.3296185
# Epoch val loss: 13.02079963684082
# Time taken: 20393.80s
#
# Start of epoch 585
# Average training loss at epoch 585: 1.3434485
# Epoch val loss: 13.321958541870117
# Time taken: 20429.10s
#
# Start of epoch 586
# Average training loss at epoch 586: 1.3463278
# Epoch val loss: 12.996027946472168
# Time taken: 20463.94s
#
# Start of epoch 587
# Average training loss at epoch 587: 1.5517807
# Epoch val loss: 13.622540473937988
# Time taken: 20498.40s
#
# Start of epoch 588
# Average training loss at epoch 588: 1.4146470
# Epoch val loss: 12.553984642028809
# Time taken: 20532.58s
#
# Start of epoch 589
# Average training loss at epoch 589: 1.4401574
# Epoch val loss: 12.146651268005371
# Time taken: 20567.05s
#
# Start of epoch 590
# Average training loss at epoch 590: 1.6339080
# Epoch val loss: 12.276267051696777
# Time taken: 20601.72s
#
# Start of epoch 591
# Average training loss at epoch 591: 1.5725886
# Epoch val loss: 11.504091262817383
# Time taken: 20636.34s
#
# Start of epoch 592
# Average training loss at epoch 592: 1.7473302
# Epoch val loss: 12.211569786071777
# Time taken: 20670.26s
#
# Start of epoch 593
# Average training loss at epoch 593: 1.6178600
# Epoch val loss: 12.293827056884766
# Time taken: 20704.96s
#
# Start of epoch 594
# Average training loss at epoch 594: 1.3147478
# Epoch val loss: 12.264946937561035
# Time taken: 20739.89s
#
# Start of epoch 595
# Average training loss at epoch 595: 1.3122683
# Epoch val loss: 11.919163703918457
# Time taken: 20774.82s
#
# Start of epoch 596
# Average training loss at epoch 596: 1.5193563
# Epoch val loss: 11.404948234558105
# Time taken: 20809.68s
#
# Start of epoch 597
# Average training loss at epoch 597: 1.5010879
# Epoch val loss: 12.86812973022461
# Time taken: 20844.27s
#
# Start of epoch 598
# Average training loss at epoch 598: 1.3862786
# Epoch val loss: 11.857117652893066
# Time taken: 20879.36s
#
# Start of epoch 599
# Average training loss at epoch 599: 1.3181312
# Epoch val loss: 12.225682258605957
# Time taken: 20913.71s
#
# Start of epoch 600
# Average training loss at epoch 600: 1.2988876
# Epoch val loss: 12.26641845703125
# Time taken: 20948.84s
#
# Start of epoch 601
# Average training loss at epoch 601: 1.3501512
# Epoch val loss: 12.10934066772461
# Time taken: 20983.41s
#
# Start of epoch 602
# Average training loss at epoch 602: 1.3519505
# Epoch val loss: 11.252058029174805
# Time taken: 21018.30s
#
# Start of epoch 603
# Average training loss at epoch 603: 1.3879216
# Epoch val loss: 12.884492874145508
# Time taken: 21053.19s
#
# Start of epoch 604
# Average training loss at epoch 604: 1.4263959
# Epoch val loss: 11.976067543029785
# Time taken: 21087.46s
#
# Start of epoch 605
# Average training loss at epoch 605: 1.3395053
# Epoch val loss: 11.627199172973633
# Time taken: 21122.08s
#
# Start of epoch 606
# Average training loss at epoch 606: 1.2583909
# Epoch val loss: 12.034321784973145
# Time taken: 21157.22s
#
# Start of epoch 607
# Average training loss at epoch 607: 1.2940776
# Epoch val loss: 12.031599998474121
# Time taken: 21192.29s
#
# Start of epoch 608
# Average training loss at epoch 608: 1.3852521
# Epoch val loss: 11.541361808776855
# Time taken: 21226.86s
#
# Start of epoch 609
# Average training loss at epoch 609: 1.6242120
# Epoch val loss: 12.409125328063965
# Time taken: 21261.68s
#
# Start of epoch 610
# Average training loss at epoch 610: 1.6245558
# Epoch val loss: 12.331642150878906
# Time taken: 21296.78s
#
# Start of epoch 611
# Average training loss at epoch 611: 1.7236536
# Epoch val loss: 11.475213050842285
# Time taken: 21331.87s
#
# Start of epoch 612
# Average training loss at epoch 612: 1.7285905
# Epoch val loss: 12.46861457824707
# Time taken: 21366.35s
#
# Start of epoch 613
# Average training loss at epoch 613: 1.5806444
# Epoch val loss: 12.021997451782227
# Time taken: 21400.93s
#
# Start of epoch 614
# Average training loss at epoch 614: 1.5934509
# Epoch val loss: 11.515141487121582
# Time taken: 21435.78s
#
# Start of epoch 615
# Average training loss at epoch 615: 1.3140919
# Epoch val loss: 11.220726013183594
# Time taken: 21470.65s
#
# Start of epoch 616
# Average training loss at epoch 616: 1.2432821
# Epoch val loss: 12.41433048248291
# Time taken: 21505.28s
#
# Start of epoch 617
# Average training loss at epoch 617: 1.4651179
# Epoch val loss: 11.907269477844238
# Time taken: 21539.81s
#
# Start of epoch 618
# Average training loss at epoch 618: 1.4799435
# Epoch val loss: 12.291427612304688
# Time taken: 21574.89s
#
# Start of epoch 619
# Average training loss at epoch 619: 1.4309334
# Epoch val loss: 11.641317367553711
# Time taken: 21610.08s
#
# Start of epoch 620
# Average training loss at epoch 620: 1.4318005
# Epoch val loss: 12.31706428527832
# Time taken: 21644.72s
#
# Start of epoch 621
# Average training loss at epoch 621: 1.5969325
# Epoch val loss: 12.694718360900879
# Time taken: 21679.53s
#
# Start of epoch 622
# Average training loss at epoch 622: 1.3321506
# Epoch val loss: 13.354259490966797
# Time taken: 21714.75s
#
# Start of epoch 623
# Average training loss at epoch 623: 1.2822530
# Epoch val loss: 12.517372131347656
# Time taken: 21749.84s
#
# Start of epoch 624
# Average training loss at epoch 624: 1.3791223
# Epoch val loss: 12.533187866210938
# Time taken: 21784.97s
#
# Start of epoch 625
# Average training loss at epoch 625: 1.3304136
# Epoch val loss: 11.613289833068848
# Time taken: 21820.39s
#
# Start of epoch 626
# Average training loss at epoch 626: 1.4113698
# Epoch val loss: 11.960786819458008
# Time taken: 21855.09s
#
# Start of epoch 627
# Average training loss at epoch 627: 1.5297153
# Epoch val loss: 11.339057922363281
# Time taken: 21889.85s
#
# Start of epoch 628
# Average training loss at epoch 628: 1.7857549
# Epoch val loss: 12.538761138916016
# Time taken: 21924.31s
#
# Start of epoch 629
# Average training loss at epoch 629: 1.4339099
# Epoch val loss: 12.249267578125
# Time taken: 21958.62s
#
# Start of epoch 630
# Average training loss at epoch 630: 1.5252020
# Epoch val loss: 12.573073387145996
# Time taken: 21993.50s
#
# Start of epoch 631
# Average training loss at epoch 631: 1.5164852
# Epoch val loss: 12.592738151550293
# Time taken: 22028.05s
#
# Start of epoch 632
# Average training loss at epoch 632: 1.4795353
# Epoch val loss: 11.820928573608398
# Time taken: 22063.39s
#
# Start of epoch 633
# Average training loss at epoch 633: 1.2697691
# Epoch val loss: 13.481988906860352
# Time taken: 22098.38s
#
# Start of epoch 634
# Average training loss at epoch 634: 1.1885865
# Epoch val loss: 12.272079467773438
# Time taken: 22132.51s
#
# Start of epoch 635
# Average training loss at epoch 635: 1.3012017
# Epoch val loss: 12.363073348999023
# Time taken: 22167.29s
#
# Start of epoch 636
# Average training loss at epoch 636: 1.2849765
# Epoch val loss: 13.079998970031738
# Time taken: 22202.19s
#
# Start of epoch 637
# Average training loss at epoch 637: 1.2630864
# Epoch val loss: 13.78779411315918
# Time taken: 22237.08s
#
# Start of epoch 638
# Average training loss at epoch 638: 1.2356844
# Epoch val loss: 12.768213272094727
# Time taken: 22271.20s
#
# Start of epoch 639
# Average training loss at epoch 639: 1.2373593
# Epoch val loss: 12.679972648620605
# Time taken: 22306.05s
#
# Start of epoch 640
# Average training loss at epoch 640: 1.3650045
# Epoch val loss: 12.863524436950684
# Time taken: 22340.51s
#
# Start of epoch 641
# Average training loss at epoch 641: 1.3510963
# Epoch val loss: 12.481539726257324
# Time taken: 22375.46s
#
# Start of epoch 642
# Average training loss at epoch 642: 1.2530496
# Epoch val loss: 12.94075870513916
# Time taken: 22410.58s
#
# Start of epoch 643
# Average training loss at epoch 643: 1.1928689
# Epoch val loss: 12.812427520751953
# Time taken: 22445.61s
#
# Start of epoch 644
# Average training loss at epoch 644: 1.2260364
# Epoch val loss: 12.121556282043457
# Time taken: 22481.26s
#
# Start of epoch 645
# Average training loss at epoch 645: 1.2042933
# Epoch val loss: 12.254079818725586
# Time taken: 22516.06s
#
# Start of epoch 646
# Average training loss at epoch 646: 1.1062846
# Epoch val loss: 12.486355781555176
# Time taken: 22550.99s
#
# Start of epoch 647
# Average training loss at epoch 647: 1.1506114
# Epoch val loss: 13.52197265625
# Time taken: 22586.10s
#
# Start of epoch 648
# Average training loss at epoch 648: 1.2023326
# Epoch val loss: 13.15880298614502
# Time taken: 22620.40s
#
# Start of epoch 649
# Average training loss at epoch 649: 1.3749986
# Epoch val loss: 11.964750289916992
# Time taken: 22655.68s
#
# Start of epoch 650
# Average training loss at epoch 650: 1.7704537
# Epoch val loss: 10.911548614501953
# Time taken: 22690.94s
#
# Start of epoch 651
# Average training loss at epoch 651: 1.3674873
# Epoch val loss: 12.723590850830078
# Time taken: 22725.54s
#
# Start of epoch 652
# Average training loss at epoch 652: 1.2341218
# Epoch val loss: 12.7483549118042
# Time taken: 22760.02s
#
# Start of epoch 653
# Average training loss at epoch 653: 1.2566793
# Epoch val loss: 12.884539604187012
# Time taken: 22795.07s
#
# Start of epoch 654
# Average training loss at epoch 654: 1.3865162
# Epoch val loss: 12.966076850891113
# Time taken: 22829.53s
#
# Start of epoch 655
# Average training loss at epoch 655: 1.3226427
# Epoch val loss: 12.222455978393555
# Time taken: 22864.30s
#
# Start of epoch 656
# Average training loss at epoch 656: 1.2281549
# Epoch val loss: 11.709565162658691
# Time taken: 22899.01s
#
# Start of epoch 657
# Average training loss at epoch 657: 1.2736313
# Epoch val loss: 12.04765796661377
# Time taken: 22933.52s
#
# Start of epoch 658
# Average training loss at epoch 658: 1.1451085
# Epoch val loss: 12.276776313781738
# Time taken: 22968.14s
#
# Start of epoch 659
# Average training loss at epoch 659: 1.0890859
# Epoch val loss: 12.222537994384766
# Time taken: 23002.76s
#
# Start of epoch 660
# Average training loss at epoch 660: 1.1733112
# Epoch val loss: 12.674816131591797
# Time taken: 23037.25s
#
# Start of epoch 661
# Average training loss at epoch 661: 1.2607783
# Epoch val loss: 11.393880844116211
# Time taken: 23072.24s
#
# Start of epoch 662
# Average training loss at epoch 662: 1.2541480
# Epoch val loss: 13.0538969039917
# Time taken: 23107.02s
#
# Start of epoch 663
# Average training loss at epoch 663: 1.4736967
# Epoch val loss: 11.83884334564209
# Time taken: 23141.68s
#
# Start of epoch 664
# Average training loss at epoch 664: 1.3971982
# Epoch val loss: 11.975912094116211
# Time taken: 23177.56s
#
# Start of epoch 665
# Average training loss at epoch 665: 1.5308230
# Epoch val loss: 12.75993537902832
# Time taken: 23212.28s
#
# Start of epoch 666
# Average training loss at epoch 666: 1.3540306
# Epoch val loss: 12.400762557983398
# Time taken: 23247.24s
#
# Start of epoch 667
# Average training loss at epoch 667: 1.3731145
# Epoch val loss: 12.460448265075684
# Time taken: 23281.49s
#
# Start of epoch 668
# Average training loss at epoch 668: 1.2571225
# Epoch val loss: 11.550101280212402
# Time taken: 23316.71s
#
# Start of epoch 669
# Average training loss at epoch 669: 1.3853962
# Epoch val loss: 12.357409477233887
# Time taken: 23351.43s
#
# Start of epoch 670
# Average training loss at epoch 670: 1.2161573
# Epoch val loss: 12.240312576293945
# Time taken: 23386.59s
#
# Start of epoch 671
# Average training loss at epoch 671: 1.0945034
# Epoch val loss: 12.663069725036621
# Time taken: 23421.48s
#
# Start of epoch 672
# Average training loss at epoch 672: 1.2153450
# Epoch val loss: 11.563639640808105
# Time taken: 23456.35s
#
# Start of epoch 673
# Average training loss at epoch 673: 1.0595843
# Epoch val loss: 11.868267059326172
# Time taken: 23490.99s
#
# Start of epoch 674
# Average training loss at epoch 674: 1.2146412
# Epoch val loss: 11.203300476074219
# Time taken: 23525.94s
#
# Start of epoch 675
# Average training loss at epoch 675: 1.0460470
# Epoch val loss: 12.238933563232422
# Time taken: 23560.80s
#
# Start of epoch 676
# Average training loss at epoch 676: 1.0582287
# Epoch val loss: 13.252467155456543
# Time taken: 23595.88s
#
# Start of epoch 677
# Average training loss at epoch 677: 1.0326512
# Epoch val loss: 12.64538860321045
# Time taken: 23630.32s
#
# Start of epoch 678
# Average training loss at epoch 678: 0.9805564
# Epoch val loss: 12.691498756408691
# Time taken: 23665.07s
#
# Start of epoch 679
# Average training loss at epoch 679: 0.9685259
# Epoch val loss: 12.384444236755371
# Time taken: 23699.49s
#
# Start of epoch 680
# Average training loss at epoch 680: 1.0646620
# Epoch val loss: 12.254075050354004
# Time taken: 23734.29s
#
# Start of epoch 681
# Average training loss at epoch 681: 1.0888922
# Epoch val loss: 11.906965255737305
# Time taken: 23770.47s
#
# Start of epoch 682
# Average training loss at epoch 682: 1.0067183
# Epoch val loss: 11.274982452392578
# Time taken: 23804.79s
#
# Start of epoch 683
# Average training loss at epoch 683: 1.0291996
# Epoch val loss: 11.263683319091797
# Time taken: 23839.78s
#
# Start of epoch 684
# Average training loss at epoch 684: 1.1215628
# Epoch val loss: 13.107699394226074
# Time taken: 23874.71s
#
# Start of epoch 685
# Average training loss at epoch 685: 1.0841194
# Epoch val loss: 13.345011711120605
# Time taken: 23909.48s
#
# Start of epoch 686
# Average training loss at epoch 686: 1.0792160
# Epoch val loss: 12.823073387145996
# Time taken: 23944.21s
#
# Start of epoch 687
# Average training loss at epoch 687: 1.3475161
# Epoch val loss: 13.286314964294434
# Time taken: 23979.15s
#
# Start of epoch 688
# Average training loss at epoch 688: 1.1735370
# Epoch val loss: 13.035225868225098
# Time taken: 24013.96s
#
# Start of epoch 689
# Average training loss at epoch 689: 1.1368191
# Epoch val loss: 13.066902160644531
# Time taken: 24048.39s
#
# Start of epoch 690
# Average training loss at epoch 690: 1.1674116
# Epoch val loss: 12.136900901794434
# Time taken: 24082.81s
#
# Start of epoch 691
# Average training loss at epoch 691: 1.1213055
# Epoch val loss: 12.775100708007812
# Time taken: 24117.33s
#
# Start of epoch 692
# Average training loss at epoch 692: 1.0134988
# Epoch val loss: 12.043527603149414
# Time taken: 24151.82s
#
# Start of epoch 693
# Average training loss at epoch 693: 0.9068705
# Epoch val loss: 12.376368522644043
# Time taken: 24186.89s
#
# Start of epoch 694
# Average training loss at epoch 694: 0.9803016
# Epoch val loss: 11.98082160949707
# Time taken: 24221.86s
#
# Start of epoch 695
# Average training loss at epoch 695: 1.4177155
# Epoch val loss: 12.818047523498535
# Time taken: 24256.65s
#
# Start of epoch 696
# Average training loss at epoch 696: 1.6428590
# Epoch val loss: 13.731453895568848
# Time taken: 24291.83s
#
# Start of epoch 697
# Average training loss at epoch 697: 1.3723103
# Epoch val loss: 12.834441184997559
# Time taken: 24326.58s
#
# Start of epoch 698
# Average training loss at epoch 698: 1.2755616
# Epoch val loss: 11.075922012329102
# Time taken: 24361.06s
#
# Start of epoch 699
# Average training loss at epoch 699: 1.0286605
# Epoch val loss: 11.945311546325684
# Time taken: 24396.44s
# Tried making graph folder. Folder already exists...
# Tried making csv folder. Folder already exists...
# Total time taken: 24396.63s

# %% [markdown]
# # Plots on Train data

# %% [markdown]
# ### Reconstruction

# %%
#input = x_train[batch_size*10:batch_size*11]
input = x_train
print("Training shape: ", input.shape)
out1, out2, out3 = koopmanAEModel(input)
# Out:
# Training shape:  (16384, 6)

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %%
plt.rcParams['figure.figsize'] = [8, 4]
row,col = np.shape(input)

for i in range(col):
    plt.figure(i)
    plt.title("Batch Reconstruction")
    plt.plot(input[0:trajLength,i], label = "Ground Truth")
    plt.plot(out1[0:trajLength,i], '--', label="Reconstruction")
    plt.title("%dth State" % i)
    plt.legend()

# %%
plt.plot(out1[:,0], out1[:,1], label="Reconstruction")
plt.plot(input[:,0], input[:,1], '--', label="Ground Truth")
plt.legend()

# %% [markdown]
# ### Graphing Error Section

# %% [markdown]
# #### Average Error Function

# %%
def preProcessForAvg(input, numTraj_batch, trajLength, num_batches, desiredStates, model):
    '''
    Given input, the number of trajectory in each batch, and the trajectory length, outputs
    batch data concatenated vertically on top of one another by calling the Koopman AE class

    Parameters:
    -----------
    input: Tensor
        Input data to reshape into outputs
    numTraj_batch: int
        Number of trajectory per batch
    trajLength: int
        Number of snapshots in a trajectory
    desiredStates: list
        List of states
    model: Koopman AE keras model
        Koopman AE model to propagate data

    Return:
    ----------
    x1_all: tensor
        Copy of input (No need for change) (Ground Truth)
    x2_all: tensor
        Concatenated tensor of 1 time shifted data for all batches (Ground Truth)
    x3_all: tensor
        Concatenated tensor of 1 time step shifted data for all batches (x2_all=x3_all) (Ground Truth)
    out1_all: tensor
        Reconstruction of input (parameter) using the Koopman AE class
    out2_all: tensor
        Predicted output from Koopman model of concatenated tensors of 1 time shifted data for all batches
    out3_all: tensor
        Predicted n time step output from Koopman model of concatenated tensors data for all batches
    '''
    
    x2_all = []
    out1_all = []
    out2_all = []
    out3_all = []
    x = input


    # Loop through num of batches
    for i in range(num_batches):
        x2 = []
        # Within each batch, loop through trajectory number
        for j in range(numTraj_batch):
            x2.append(x[(i*numTraj_batch+j)*trajLength+1:(i*numTraj_batch+j+1)*trajLength])
        x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input for a batch
        x2_all.append(x2)
        
        x_input = x[i*numTraj_batch*trajLength:(i+1)*numTraj_batch*trajLength]
        out1, out2, out3 = model(x_input)
        out1_all.append(out1)
        out2_all.append(out2)
        out3_all.append(out3)
        
    x1_all = x
    x2_all = tf.reshape(x2_all,(-1,len(desiredStates)))
    x3_all = x2_all
    out1_all = tf.reshape(out1_all,(-1,len(desiredStates)))
    out2_all = tf.reshape(out2_all,(-1,len(desiredStates)))
    out3_all = tf.reshape(out3_all,(-1,len(desiredStates)))


    '''
    print(tf.shape(x2_all))
    print(tf.shape(out1_all))
    print(tf.shape(out2_all))
    print(tf.shape(out3_all))
    '''

    return x1_all, x2_all, x3_all, out1_all, out2_all, out3_all

# %%
def avgTrajError(gTruth, predicted, trajLength, numTraj):
    '''
    Get the average trajectory error

    Parameters:
    -----------
    gTruth: tensor or ndarray
        Ground Truth matrix
    predicted: tensor or ndarray
        Predicted matrix
    trajLength: int
        Length of trajectory
    numTraj: int
        Number of trajectory (total?)
    

    Return:
    ----------
    avgErrorList: list
        List of average errors of all trajectories (each index is the avg error of the states at a point of time along the trajectory)
    
    errorList: list
        List of error of all states and trajectory
    '''
    errorList = []
    avgErrorList = []
    numStates = len(gTruth[0,:])
    for i in range(numTraj):
        '''
        print("Gtruth")
        print(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:])
        print("Predicted")
        print(np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
        print("---Loop---")
        '''
        errorList.append(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:] - np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
    
    #print("Error List")
    #print(np.shape(errorList[0]))
    
    for j in range(trajLength):
        #print("Length of Traj %d"% j)
        for k in range(numTraj):
            #print("Traj: %d"% k)
            if k == 0:
                avgErrorList.append(errorList[k][j,:])
            else:
                #print(avgErrorList[j])
                avgErrorList[j] = (k*avgErrorList[j]+errorList[k][j,:])/(k+1) # Recursive average formula
    return avgErrorList, errorList

# %% [markdown]
# #### Preprocess Error Graph Data

# %%
saveErrorPath = 'errorGraph/'
try:
    os.mkdir(saveErrorPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
x1_all,x2_all,x3_all, out1_all,out2_all,out3_all = preProcessForAvg(x_train,numTraj_batch, trajLength, num_batches_train, desiredStates, koopmanAEModel)
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)

# %%
print(x2_all.shape)
# Out:
# (16128, 6)

# %% [markdown]
# #### Error Graphs

# %% [markdown]
# ##### Reconstruction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i],
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Reconstruction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'recon_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ##### Forward Time Shift Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i], 
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Forward Time Shift Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'ftimeShift_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ##### Linearity Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:1000,i])), avgTrajErrorArray[:1000,i]-errorStdDevArray[:1000,i], 
                    avgTrajErrorArray[:1000,i]+errorStdDevArray[:1000,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Linear Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((0,1))
    plt.savefig(saveErrorPath+'linPred_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ### Reconstruction/Forward Time Shift Prediction/Linear Prediction Graph

# %%
saveOutputPath = 'outputGraph/'
try:
    os.mkdir(saveOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x1_all[:1000,i])
    plt.plot(out1_all[:1000,i],'--',label="")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.savefig(saveOutputPath+'recon_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x2_all[:1000,i])
    plt.plot(out2_all[:1000,i],'--',label="")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.savefig(saveOutputPath+'ftimeShiftPred_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x3_all[:1000,i])
    plt.plot(out3_all[:1000,i],'--',label="")
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.38,0.44))
    plt.savefig(saveOutputPath+'linPred_'+title+'.png', dpi=300)
    plt.close()

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %% [markdown]
# # Animate Graphs

# %% [markdown]
# ## Animate Setup

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
def animateStatesError(middleLine, boundLine, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifBoundLine=True, xlim=[0,128], ylim=[0,1]):
    '''
    Given the average trajectory error, standard deviation error, and desired states,
    animate the trajectory with given legend into a mp4 under the mp4 folder

    Parameters:
    -----------
    middleLine: ndarray
        Trajectory of the middle line (nxlen(desiredStates))
    boundLine: ndarray
        Trajectory of the bound for upper and lower bound (+/- stdDev)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line
    xlim: list
        Limit of plot axis in x direction
    ylim: list
        Limit of axis in y direction


    Return:
    ---------
    None
    '''
    for j in range(np.shape(middleLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        line, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " "))
        plt.style.use('default')
        plt.legend()
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])

            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(middleLine[0:i,j]))
            data = middleLine[0:i,j] #select data range
            line.set_data(x,data)
            line.set_color('#1f77b4')
        
            if ifBoundLine:
                p = plt.fill_between(range(len(boundLine[0:i,j])), middleLine[0:i,j]-boundLine[0:i,j], 
                                middleLine[0:i,j]+boundLine[0:i,j], facecolor='lightsteelblue')
                return line, p,
            else:
                return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=128,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %%
def animateStates(predictedLine, gTruthLine, label1, label2, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifGTruthLine=True, xlim=[0,128], ylim=[0,1]):
    '''
    Given the predicted and ground truth trajectory, as well as desired states,
    animate the trajectory with given legend into a mp4 under the mp4FilePath folder

    Parameters:
    -----------
    predictedLine: ndarray
        Trajectory of the predicted line (nxlen(desiredStates))
    gTruthLine: ndarray
        Trajectory of the ground truth line (+/- stdDev)
    label1: str
        Label for predicted line (suffix)
    label2: str
        Label for ground truth line (suffix)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line
    xlim: list
        Limit of plot axis in x direction
    ylim: list
        Limit of axis in y direction
        
    Return:
    ---------
    None
    '''
    for j in range(np.shape(predictedLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        line, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " ") + " " + label1)
        line.set_color('C1')
        plt.setp(line, linestyle='--')
        if ifGTruthLine:
            line2, = ax.plot([],[], lw=2, label=desiredStates[j].replace("_", " ") + " " + label2)
            line2.set_color('C0')
            #plt.setp(line2, linestyle='--')
        
        plt.style.use('default')
        plt.legend(loc='upper left')
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])
            if ifGTruthLine:
                line2.set_data([],[])
            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(predictedLine[0:i,j]))
            data = predictedLine[0:i,j] #select data range
            line.set_data(x,data)
            if ifGTruthLine:
                line2.set_data(x, gTruthLine[0:i,j])
          
            return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=256,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %% [markdown]
# ## Animation Graphs

# %% [markdown]
# Trajectory

# %%
animateStates(x1_all, x1_all, 'State Trajectory', 'State Trajectory', desiredStates, 'trajectory', ifGTruthLine=False)

# %% [markdown]
# Error

# %%
# Reconstruction Error
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_recon_error')

# Forward Time Shift Prediction Error
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_fTimeShiftPred_error')

# Linear Prediction Error
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_linPred_error')

# %% [markdown]
# Trajectory

# %%
animateStates(out1_all,x1_all,'Reconstruction','Truth',  desiredStates, 'train_traj_recon')
animateStates(out2_all,x2_all,'Forward Time Shift','Truth', desiredStates, 'train_traj_FTimeShiftPred')
animateStates(out3_all,x3_all,'Lin Pred','Truth', desiredStates, 'train_traj_linPred')

# %% [markdown]
# # Save the Model

# %%
koopmanAEModel.save('checkpoints/champ_Trained_Model')
# Out:
# INFO:tensorflow:Assets written to: checkpoints/champ_Trained_Model\assets

# %% [markdown]
# # Load the Model

# %%
new_model = tf.keras.models.load_model('checkpoints/champ_Trained_Model', compile=False)
new_model.summary()
# Out:
# Model: "Koopman_AE_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_model_3 (EncoderMode multiple                  396544
# _________________________________________________________________
# koopman__model_3 (Koopman_Mo multiple                  65536
# _________________________________________________________________
# decoder_model_3 (DecoderMode multiple                  264710
# =================================================================
# Total params: 726,790
# Trainable params: 726,790
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = x_train
new_out1, new_out2, new_out3 = new_model(input)

# %% [markdown]
# # Plots on Test Data

# %% [markdown]
# ## Test Graphs

# %%
saveTestOutputPath = 'testOutputGraph/'
try:
    os.mkdir(saveTestOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
input = doggo_test
new_out1, new_out2, new_out3 = new_model(input)

# %%
nx1_all,nx2_all,nx3_all,nout1_all,nout2_all,nout3_all = preProcessForAvg(input,numTraj_batch,trajLength,num_batches_val,desiredStates, new_model)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx1_all[:,i], label="Ground Truth")
    plt.plot(nout1_all[:,i],'--',label="Reconstruction")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0,1))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_recon_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx2_all[:,i], label="Ground Truth")
    plt.plot(nout2_all[:,i],'--',label="Predicted")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.3, 0.6))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_fTimeShift_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx3_all[:,i], label="Ground Truth", linewidth=2)
    plt.plot(nout3_all[:,i],'--',label="Predicted", linewidth=2)
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    #plt.ylim((0.38,0.44))
    plt.legend()
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_linPred_'+title+'.png', dpi=300)
    plt.close()

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %% [markdown]
# ## Error Graphs on Test

# %%
avgTrajErrorList, errorList = avgTrajError(nx1_all, nout1_all, trajLength, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Reconstruction Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.25,0.25))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_recon_error_'+title+'.png', dpi=300)
    plt.close()

# %%
avgTrajErrorList, errorList = avgTrajError(nx2_all, nout2_all, trajLength-1, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Forward Time Shift Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.003,0.003))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_FTimeShift_error_'+title+'.png', dpi=300)
    plt.close()

# %%
avgTrajErrorList, errorList = avgTrajError(nx3_all, nout3_all, trajLength-1, numTraj_test)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Linear Prediction Error")
    plt.xlabel("Time Step")
    #plt.ylim((-0.003,0.003))
    plt.tight_layout()
    plt.savefig(saveTestOutputPath+'test_LinPred_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ## Phase Portrait

# %%
plt.plot(nx1_all[:,0], nx1_all[:,1], label="Ground Truth")
plt.plot(nout1_all[:,0], nout1_all[:,1], linestyle='--',label="Reconstruction")
title = 'Phase Reconstruction'
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_' +title+'.png', dpi=300)
plt.close()


plt.plot(nx2_all[:,0], nx2_all[:,1], label="Ground Truth")
plt.plot(nout1_all[:,0], nout1_all[:,1], linestyle='--',label="Forward Time Shift")
title = "Forward Time Shift"
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()


plt.plot(nx3_all[:,0], nx3_all[:,1], label="Ground Truth")
plt.plot(nout3_all[:,0], nout3_all[:,1], linestyle='--',label="Linear Prediction")
title = "Linear Prediction"
plt.title(title)
plt.xlabel("Hip Joint Position")
plt.ylabel("Hip Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()

# %%
plt.plot(nx1_all[:,2], nx1_all[:,3], label="Ground Truth")
plt.plot(nout1_all[:,2], nout1_all[:,3], linestyle='--',label="Reconstruction")
title = 'Phase Reconstruction Lower Leg'
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_' +title+'.png', dpi=300)
plt.close()


plt.plot(nx2_all[:,2], nx2_all[:,3], label="Ground Truth")
plt.plot(nout1_all[:,2], nout1_all[:,3], linestyle='--',label="Forward Time Shift")
title = "Forward Time Shift Lower Leg"
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()


plt.plot(nx3_all[:,2], nx3_all[:,3], label="Ground Truth")
plt.plot(nout3_all[:,2], nout3_all[:,3], linestyle='--',label="Linear Prediction")
title = "Linear Prediction Lower Leg"
plt.title(title)
plt.xlabel("Lower Leg Joint Angle")
plt.ylabel("Lower Leg Joint Velocity")
plt.tight_layout()
plt.legend(loc='upper left')
plt.savefig(saveTestOutputPath+'test_phase_'+title+'.png', dpi=300)
plt.close()

# %% [markdown]
# ## Animation on Test

# %%
avgTrajErrorList, errorList = avgTrajError(nx1_all, nout1_all, trajLength, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_recon_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx2_all, nout2_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_fTimeShiftPred_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx3_all, nout3_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_linPred_error', mp4FilePath, ifBoundLine=False)

# %% [markdown]
# Trajectory

# %%
animateStates(nout1_all,nx1_all,'Reconstruction','Truth',  desiredStates, 'test_traj_recon',xlim=[0,256])
animateStates(nout2_all,nx2_all,'Forward Time Shift','Truth', desiredStates, 'test_traj_FTimeShiftPred',xlim=[0,256])
animateStates(nout3_all,nx3_all,'Lin Pred','Truth', desiredStates, 'test_traj_linPred', xlim=[0,256])

# %% [markdown]
# # Koopman Eigenvalues

# %%
w,v = np.linalg.eig(new_model.koopman.get_weights())
fig = plt.figure(figsize=(5.5,5))
ax = fig.add_subplot(1,1,1)
circ = plt.Circle((0, 0), radius=1, edgecolor='black', facecolor='None')
ax.add_patch(circ)
plt.scatter(w.real.squeeze(), w.imag.squeeze())
title = "Koopman Eigenvalues - Empty Ground"
plt.title(title)
plt.savefig(saveTestOutputPath+'test_'+title+'.png', dpi=300)
plt.close()
