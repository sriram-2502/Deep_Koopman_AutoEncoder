# %% [markdown]
# # Implement a custom Autoencoder with Koopman layer

# %% [markdown]
# ## Version Control

# %% [markdown]
# To Do:
# 1) Account for trailing batch - Make robust (fixed issue by reshaping input data)
# 2) Preprocess Data
# 3) Make sure sim data is different for different ground parameters
# 4) Validation data has different batch size. Address when HP training
# 5) Address semi graident issue for K^m*z in linearity loss (Prob fine)

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras

import  numpy as np
import pandas as pd

import matplotlib.colors as mcol
import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.animation as animation

import seaborn as sns

import time 
import os

import glob
import csv

# %%
plt.rcParams['figure.figsize'] = [9, 6]
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.style.use('default')

# %%
#from google.colab import drive
#drive.mount('/gdrive')

# %% [markdown]
# Comment out if don't need

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data

# %% [markdown]
# ### Read Sim Data Functions

# %%
def preprocessSimData(df, desiredStates:list, initialIndex:int=300, finalIndex:int=812):
    '''
    Preprocess text file (fixing formatting issue in data as well) while returning a dataframe object with the desired states selected

    Parameters:
    -----------
    df: dataFrame
        Panda dataframe that is read from one of the recorded simulation .txt files
    desiredStates: list
        List of desired states to return as a panda dataframe object in sequential order

    Return:
    ----------
    stateMatrix: dataFrame
        State matrix with desired states
    '''



    # Fix formatting Variables
    falseList = ['time_lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort', 'nan']
    df.columns = falseList
    df['time_lf_hip_joint_position'] = df.time_lf_hip_joint_position.str[0:8] + ' ' + df.time_lf_hip_joint_position.str[8:]


    # Data and State Name List
    data = df.values # np array of data values
    namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

    dictStates = {}
    staticCounter = 0 # Variable to account for formatting issue
    for index in range(len(namesList)-1):
        if index == 0 and staticCounter == 0: # Condition for formatting issue of collected data
            for j in range(len(data[:,index])): # Looping through all elements in column 0 and converting to float
                if j == 0: # Initialize array
                    array1 = float(data[j,index][0:8])
                    #print(array1)
                    array2 = float(data[j,index][8:])
                    #print(array2)
                else:
                    array1 = np.vstack((array1,float(data[j,index][0:8])))
                    array2 = np.vstack((array2,float(data[j,index][8:])))
            dictStates[namesList[index]] = np.squeeze(array1[initialIndex:finalIndex])
            dictStates[namesList[index+1]] = np.squeeze(array2[initialIndex:finalIndex])        
        else:
            dictStates[namesList[index+1]] = data[initialIndex:finalIndex,index]
    for counter, names in enumerate(desiredStates):
        if counter == 0:
            stateMatrix = np.reshape(dictStates[names], (-1,1))
        else:
            stateMatrix = np.hstack((stateMatrix, np.reshape(dictStates[names], (-1,1))))
    return pd.DataFrame(stateMatrix, columns = desiredStates)



def preprocessFile(fileNames:list, initialIndex:int, finalIndex:int, desiredStates:list):
    '''
    Given fileNames to read, reads the file(s) and returns all data concatenated in a panda dataframe framework

    Paramaters:
    -----------
    fileNamess:list
        List of filenames to read and concatenate data together
    intialIndex: int
        Index to start reading each file's data from
    finalIndex: int
        Index to stop reading each file's data from
    desiredStates:list
        List of states to read
    
    Return:
    ----------
    totalData: dataFrame
        Returns data of all filenames with given states in one panda dataframe
    '''

    filePaths = []
    for i in fileNames:
        filePaths.append(glob.glob(i))
    #print(filePaths)


    dataFrameList = []
    for i in filePaths:
        for j in i:
            df = pd.read_csv(j, sep= " ", header=None)
            dataFrameList.append(preprocessSimData(df, desiredStates, initialIndex=initialIndex, finalIndex=finalIndex)) # 712-200 = 512 --> 512-1 is 512 indices (i.e. [0, 511])

    totalData = pd.concat(dataFrameList)
    return totalData

# %% [markdown]
# ### Read full data

# %%
# List of states
namesList = ['time', 'lf_hip_joint_position', 'lf_lower_leg_joint_position', 'lf_upper_leg_joint_position', 'lh_hip_joint_position', 'lh_lower_leg_joint_position', 'lh_upper_leg_joint_position',
                'rf_hip_joint_position', 'rf_lower_leg_joint_position', 'rf_upper_leg_joint_position', 'rh_hip_joint_position', 'rh_lower_leg_joint_position', 'rh_upper_leg_joint_position',
                'lf_hip_joint_vel', 'lf_lower_leg_joint_vel', 'lf_upper_leg_joint_vel', 'lh_hip_joint_vel', 'lh_lower_leg_joint_vel', 'lh_upper_leg_joint_vel',
                'rf_hip_joint_vel', 'rf_lower_leg_joint_vel', 'rf_upper_leg_joint_vel', 'rh_hip_joint_vel', 'rh_lower_leg_joint_vel', 'rh_upper_leg_joint_vel',
                'lf_hip_joint_effort', 'lf_lower_leg_joint_effort', 'lf_upper_leg_joint_effort', 'lh_hip_joint_effort', 'lh_lower_leg_joint_effort', 'lh_upper_leg_joint_effort',
                'rf_hip_joint_effort', 'rf_lower_leg_joint_effort', 'rf_upper_leg_joint_effort', 'rh_hip_joint_effort', 'rh_lower_leg_joint_effort', 'rh_upper_leg_joint_effort']

# %%
desiredStates = ['lf_hip_joint_position', 'lf_hip_joint_vel', 'lf_hip_joint_effort']

input_dim = len(desiredStates)
output_dim = input_dim

trajLength = 2**5 # Length of each trajectory in the dataset

filePath = "simData"
fileNames = [filePath + '/plane_kp_100e10_kd_0/joint_state_test_plane_kp_100e10_kd_0_forward_0.1*']


numTraj = 16 # Total number of trajectories in the dataset (train)
numTraj_val = 4
batch_size = int(2**7) # Number of snapshots in each batch
numTraj_batch = int(batch_size/trajLength)


initialIndex, finalIndex= 200, 200+trajLength*(numTraj+numTraj_val)

num_batches_train = int(trajLength*numTraj/batch_size) ## num_batches = trajLength*numTraj/batch_size 
num_batches_val = int(trajLength*numTraj_val/batch_size)

# %%
doggoFrame = preprocessFile(fileNames,initialIndex,finalIndex, desiredStates)
doggoFrame.head(5)
# Out:
#   lf_hip_joint_position lf_hip_joint_vel lf_hip_joint_effort
# 0               -0.0005           0.0852               0.107
# 1               -0.0004           0.0631              0.0889
# 2               -0.0004           0.0054               0.086
# 3               -0.0004           0.0151              0.0593
# 4               -0.0003           0.0099              0.0539

# %%
plt.plot(doggoFrame.values[0:512,0])
plt.title("Graph of data")
# Out:
# Text(0.5, 1.0, 'Graph of data')

# %%
plt.plot(doggoFrame.values[0:20,0], doggoFrame.values[0:20,1])
plt.title("Phase Portrait")
# Out:
# Text(0.5, 1.0, 'Phase Portrait')

# %%
print("Datapoints: ", len(doggoFrame.index))
# Out:
# Datapoints:  640

# %%
doggo_train = doggoFrame.values[:numTraj*trajLength,:]
doggo_validation = doggoFrame.values[numTraj*trajLength:(numTraj+numTraj_val)*trajLength,:]
doggo_test = doggoFrame.values[(numTraj+numTraj_val)*trajLength:,:]

doggo_train = np.asarray(doggo_train).astype('float32')
doggo_test = np.asarray(doggo_test).astype('float32')
doggo_validation = np.asarray(doggo_validation).astype('float32')

# %%
print("Size of doggo_train:", len(doggo_train))
print("Size of doggo_validation:", len(doggo_validation))
print("Size of doggo_test:", len(doggo_test))
# Out:
# Size of doggo_train: 512
# Size of doggo_validation: 128
# Size of doggo_test: 0

# %% [markdown]
# ### Make into dataset

# %%
# Normalize the data
min_val = tf.reduce_min(doggo_train)
max_val = tf.reduce_max(doggo_train)

doggo_train = (doggo_train - min_val) / (max_val - min_val)
doggo_validation = (doggo_validation - min_val) / (max_val - min_val)
doggo_test = (doggo_test - min_val) / (max_val - min_val)

train_data = tf.cast(doggo_train[0:batch_size*num_batches_train], tf.float32)
validation_data = tf.cast(doggo_validation[0:batch_size*num_batches_val], tf.float32)
validation_data = tf.data.Dataset.from_tensor_slices((validation_data, validation_data)).batch(batch_size)
test_data = tf.cast(doggo_test, tf.float32)

# %%
x_train = train_data
y_train = train_data

# %% [markdown]
# # Custom Model definition

# %% [markdown]
# ## Encoder

# %%
class EncoderLayer(keras.layers.Layer):
    """
    Custom class to create a encoder layer
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * x + b: tensor
        linear combination of weights times input + bias for the layer
    """
    
    def __init__(self, units=32, name=None):
        super(EncoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Encoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, inputs):
        #print("Encoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(inputs, self.w) + self.b

# %%
class EncoderModel(keras.Model):
    """
    Custom Model to create an encoder with one input
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    """
    
    def __init__(self, name=None):
        super(EncoderModel, self).__init__(name=name)
        self.enc1 = EncoderLayer(16)
        self.enc2 = EncoderLayer(32)
        self.enc3 = EncoderLayer(64)
        self.enc4 = EncoderLayer(64)
        self.enc5 = EncoderLayer(16)
        self.enc6 = EncoderLayer(16)
        self.enc7 = EncoderLayer(16)

    def call(self, input):
        x = input
        x = self.enc1(x)
        x = tf.nn.tanh(x)
        x = self.enc2(x)
        x = tf.nn.elu(x)

        # Encoder output layer
        x = self.enc3(x)
        x = tf.nn.tanh(x)
        x = self.enc4(x)
        x = tf.nn.elu(x)
        x = self.enc5(x)
        x = tf.nn.tanh(x)
        x = self.enc6(x)
        x = tf.nn.elu(x)
        x = self.enc7(x)
        z = tf.nn.tanh(x)
        return z

# %% [markdown]
# ## Koopman

# %%
class KoopmanLayer(keras.layers.Layer):
    """
    Custom class to calculate the Koopman operator K on latent variables
    Adds a linear loss as mse(Z2-Z2_tilde)
    
    Parameters
    ----------
    Z: tensor 
        inputs are the latent variabes (output from encoder)
        input dimension is (m, 128)
        m is the number of time snapshots for each input dimension of X
        128 is the number of latent varibales (observables)

    Return
    ----------
    Z: tensor
        return the original input Z 

    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    Z2_tilde: tensor
        return the prediction by linearity from K (z2_tilde = K^m * z(1,:))
    """

    def __init__(self, trajLength, numTraj_batch):
        super(KoopmanLayer, self).__init__()
        self.trajLength = trajLength
        self.numTraj_batch = numTraj_batch

    def build(self, Z):
        # Initialize K as a weight
            self.K =  self.add_weight(
                name = 'Koopman_weight',
                shape=(Z[-1], Z[-1]),
                initializer="random_normal",
                trainable=True,
            )

    def timeShift(self,Z,latent_dim):
        '''
        Shifts trajectories one time step
        Parameters:
        -----------
            Z: tensor
                Batch data of latent variables (in the lifted space)
                
            latent_dim: tensor shape
                Dimension of the lifted space (columns of Z)
        '''
        Z1 = []
        z1 = []
        Z2 = []

        for i in range(self.numTraj_batch):
            Z1.append(Z[i*self.trajLength:(i+1)*self.trajLength-1,:])
            Z2.append(Z[i*self.trajLength+1:(i+1)*self.trajLength,:])
            z1.append(Z[i*self.trajLength,:])
        return tf.reshape(Z1, [-1, latent_dim]), tf.reshape(Z2, [-1, latent_dim]), tf.reshape(z1, [-1, latent_dim])       

    def call(self, Z):
        latent_dim = tf.shape(Z)[1]
        shift_len = (self.trajLength-1)*self.numTraj_batch # length of rows for forward time shifted Z
        Z1, Z2, z1 = self.timeShift(Z,latent_dim)

        # Find Z2_tilde
        Z2_tilde = tf.zeros([shift_len, latent_dim], dtype=tf.float32)
        for traj in range(self.numTraj_batch): # loop over numnber of traj
            for m in range(self.trajLength-1): #loop over snapshots in each traj
                 #K = tf.zeros([latent_dim, latent_dim], dtype=tf.float32)
                 
                 indices = tf.constant([[traj*(self.trajLength-1)+m]])
                 if m == 0:
                    K = self.K 
                    # Matrix matvec works out to get Kz' and returns as row vector
                    updates = [tf.linalg.matvec(K, z1[traj,:])] #updates the row tensor at index = indices 
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                 else:
                    K = tf.matmul(K,self.K)
                    updates = [tf.linalg.matvec(K, z1[traj,:])]
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
           
        # Find linear loss
        Linear_loss = tf.reduce_mean(tf.square(tf.subtract(Z2,Z2_tilde)))
        self.add_loss(Linear_loss)
        
        # prints for debugging dimensions
        #print("Koopman layer, K",tf.shape(K))
        #print("Koopman layer, m",tf.shape(m))
        #print("Koopman layer, Z",tf.shape(Z))
        #print("Koopman layer, z1",tf.shape(z1))
        #print("Koopman layer, Z2 ",tf.shape(Z2))
        #print("Koopman layer, Z2_tilde",tf.shape(Z2_tilde))
        
        return Z, tf.matmul(Z1,self.K), Z2_tilde,

# %%
class Koopman_Model(keras.Model):
    """
    Custom Model to create an encoder with koopman layer
    
    Parameters
    ----------
    input: tensor 
        z - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    
    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    z2_tilde: tensor
        Latent variables of prediction obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    """
    
    def __init__(self, trajLength, numTraj_batch, name=None):
        super(Koopman_Model, self).__init__(name=name)
        self.koopman = KoopmanLayer(trajLength,numTraj_batch)


    def call(self, input):
        z = input
        z, Z2_hat, z2_tilde = self.koopman(z)
        return z, Z2_hat, z2_tilde

# %% [markdown]
# ## Decoder

# %%
class DecoderLayer(keras.layers.Layer):
    """
    Custom class to create a decoder layer with two inputs
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * input1 + b: tensor
        linear combination of weights times input1 + bias for the layer
        
    W.T * input2 + b: tensor
        linear combination of weights times input2 + bias for the layer

    W.T * input3 + b: tensor
        linear combination of weights times input3 + bias for the layer
    """

    def __init__(self, units=32, name=None):
        super(DecoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Decoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, input1, input2, input3):
        #print("Decoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(input1, self.w) + self.b, tf.matmul(input2, self.w) + self.b, tf.matmul(input3, self.w) + self.b

# %%
class DecoderModel(keras.Model):
    """
    Custom Model to create a decoder with two inputs
    
    Parameters
    ----------
    input 1: tensor 
        z - the lifted output of the koopman layer (encoder output)
    
    input 2: tensor 
        z2_tilde - obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Prediction of the original state inputs x (label values are forward time shifted x)

    x2_tilde: tensor
        Prediction obtained by linearity from K 
    
    """
    
    def __init__(self, outputDim, name=None):
        super(DecoderModel, self).__init__(name=name)
        self.dec1 = DecoderLayer(64)
        self.dec2 = DecoderLayer(64)
        self.dec3 = DecoderLayer(32)
        self.dec4 = DecoderLayer(64)
        self.outputLayer = DecoderLayer(outputDim)

    def call(self, input1, input2, input3):
        z = input1
        z2_hat = input2
        z2_tilde = input3

        z, z2_hat, z2_tilde = self.dec1(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec2(z, z2_hat, z2_tilde)
        z = tf.nn.elu(z)
        z2_hat = tf.nn.elu(z2_hat)
        z2_tilde = tf.nn.elu(z2_tilde)

        z, z2_hat, z2_tilde = self.dec3(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec4(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        # Decoder output layer
        x_hat, x2_hat, x2_tilde = self.outputLayer(z, z2_hat, z2_tilde)
        #x_hat = tf.nn.elu(x_hat)
        #x2_hat = tf.nn.elu(x2_hat)
        #x2_tilde = tf.nn.elu(x2_tilde)

        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# ## Koopman Autoencoder

# %%
class Koopman_AE_Model(keras.Model):
    """
    Custom Model to create a Koopman Autoencoder
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    
    x2_tilde: tensor
        Prediction obtained by linearity from K 
    """
    
    def __init__(self, inputDim, outputDim, trajLength, numTraj, name=None):
        super(Koopman_AE_Model, self).__init__(name=name)
        self.enc = EncoderModel()
        self.koopman = Koopman_Model(trajLength, numTraj)
        self.dec = DecoderModel(outputDim)

    def call(self, input):
        x = input
        z = self.enc(x)
        z, z2_hat, z2_tilde = self.koopman(z)
        x_hat, x2_hat, x2_tilde = self.dec(z, z2_hat, z2_tilde)
        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# # Custom Training Loop

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.batch(batch_size)

# %%
class MyStaticModel():
    def __init__(self, input_dim, batch_size, trajLength, num_batches_train, num_batches_val):
        # Initialize constants
        self.batch_size = batch_size
        self.trajLength = int(trajLength) #should be int
        self.numtraj_batch = int(self.batch_size/self.trajLength) # should be int
        self.num_batches_train = num_batches_train
        self.num_batches_val = num_batches_val

        self.inputs = tf.keras.layers.Input(shape=(input_dim,))
        self.graphCounter = 0 

    ######################################  LOSS FUNCTIONS  ###################################################
    def tot_loss(self, model, x, x_hat, x2_hat, x2_tilde):
        """Calculates total loss as sum of recon_loss + predict_loss + Koopman_loss"""
        #alpha1 = 0.1, alpha2 = 1e-7, alpha3 = 1e-15
        alpha1 = 0.1
        alpha2 = 1e-7
        alpha3 = 1e-15

        x2 = []
        x2_SP = []
        x2_tilde_SP = []
        for i in range(self.numtraj_batch):
            predict_length = self.trajLength-1
            x2.append(x[i*self.trajLength+1:(i+1)*self.trajLength]) # forward time shift x to get x2
            x2_SP.append(x[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # forward time shift x to get x2 for Sp timesteps
            #x2_tilde_SP.append(x2_tilde[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # get Sp timesteps from x2_tilde
            # Shape currently goes from 31 to 27.. but somehow indexing does not work
            x2_tilde_SP = x2_tilde

        #print("In loss function x2", tf.shape(x2))
        #print("In loss function x2_SP", tf.shape(x2_SP))
        #print("In loss function x2_tilde_SP", tf.shape(x2_tilde_SP))

        x2 = tf.reshape(x2, [-1, x.shape[-1]])
        x2_SP = tf.reshape(x2_SP, [-1, x.shape[-1]])
        x2_tilde_SP = tf.reshape(x2_tilde_SP, [-1, x.shape[-1]])

        recon_loss = tf.reduce_mean(tf.square(tf.subtract(x,x_hat)))
        predict_loss =tf.reduce_mean(tf.square(tf.subtract(x2_SP,x2_tilde_SP)))

        weights  = model.trainable_variables
        lossL2 = tf.add_n([tf.nn.l2_loss(w) for w in weights if 'bias' not in w.name])

        Linf_loss = tf.add(tf.norm(tf.subtract(x,x_hat), ord=np.inf), tf.norm(tf.subtract(x2,x2_hat), ord=np.inf))
        return alpha1*(recon_loss+predict_loss) + alpha2*Linf_loss + alpha3*lossL2 + sum(model.losses)

    ###############################################  GRAPH FUNCTIONS     #########################################################

    def graphPlot(self, error, error_min, error_max, error_val, error_min_val, error_max_val):
        '''
        Graph plots for loss over all epochs
        Parameters:
        error: list
            Training Loss Error for all epochs
        error_val: list
            Validation Loss Error for all epochs
        '''
        saveFiles = True
        imgPath = 'graphs/'
        csvPath = 'csvFiles/'

        csvFileName = 'epochLosses.csv'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making graph folder. Folder already exists...")

            try:
                os.mkdir(csvPath)
            except:
                print("Tried making csv folder. Folder already exists...")
        
        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Training Loss")
        plt.plot(error_val, label = "Validation Loss")
        textTitle = "All Epoch Loss %d" % self.graphCounter
        self.graphCounter += 1
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight') 
        plt.close()

        # Save data into csv file
        csvDict = {'Epoch Training Loss': error, 'Epoch Training Min Loss': error_min, 'Epoch Training Max Loss': error_max,
                    'Epoch Validation Loss': error_val, 'Epoch Validation Min Loss' : error_min_val, 
                    'Epoch Validation Max Loss': error_max_val}
        df = pd.DataFrame(csvDict)
        df.to_csv(csvPath+csvFileName)
            

    
    def graphBatchLossPlot(self, epochNum, error, error_val):
        saveFiles = True
        imgPath = 'graphs/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Batch Training Loss")
        plt.plot(error_val, label="Batch Validation Loss")
        textTitle = "BatchLoss_Epoch_%d" % (epochNum)
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
        plt.close() 

    
    def graphEigenfunctions(self, model, K):
        saveFiles = True
        imgPath = 'graphs/eigenfunctions/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        x1 = tf.linspace(-1,1,256)
        x2 = tf.linspace(-1,1,256)
        x1, x2 = tf.meshgrid(x1, x2)
        X = tf.reshape([[x1],[x2]], [-1, 2])

        Z = model.enc(X)
        complex_Z = tf.complex(Z, tf.zeros(tf.shape(Z))) # make Z complex with zero complex part

        eig_values, right_eig_vectors = tf.linalg.eig(tf.squeeze(K))
        W = tf.transpose(tf.linalg.inv(right_eig_vectors))
        Psi = tf.matmul(complex_Z,W)

        eig_dominant = tf.abs(eig_values)
        counter = 0
        for eig in eig_values:
            cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["b","w","r"])
            #normalize = mpl.colors.Normalize(vmin=np.min(Psi[:,counter]), vmax=np.max(Psi[:,counter]))
            plt.figure(counter)
            fig, axs = plt.subplots(2)
            
            p1 = axs[0].scatter(x1, x2, c=tf.abs(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p1, ax=axs[0])
            fig_title1 = "|Psi| %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig)) 
            axs[0].set_title(fig_title1)
            
            p2 = axs[1].scatter(x1, x2, c=tf.math.angle(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p2, ax=axs[1])
            fig_title2 = "angle(Psi) %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig))  
            axs[1].set_title(fig_title2)

            fig.tight_layout()
            textTitle = "Psi_%0.04f_epoch%d"%(eig, counter)
            counter += 1
            if saveFiles:
                plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
            plt.close('all') 

    ###############################################     FIT FUNCTION        #########################################################

    def fit(self, model, x, y, validation_data, batch_size):
        # Preprocess data
        train_ds = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)

        # Define the optimizer
        optimizer = tf.keras.optimizers.Adam(1e-4)

        epochs = 9000     
        
        # Initialize variables for csv file
        epoch_train_loss = [] # total loss for each epoch
        epoch_train_min_loss = []
        epoch_train_max_loss = []
        
        epoch_validation_loss = []
        epoch_validation_min_loss = []
        epoch_validation_max_loss = []



        start_time_total = time.time()
        for epoch in range(epochs):

            print("\nStart of epoch %d" % (epoch))
            start_time = time.time()

            batch_train_loss_list = [] # total loss for each batch 
            batch_validation_loss_list = []


            ###############################################     Training loop     ###################################################
            # Iterate over the train batches of the dataset.
            for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
                with tf.GradientTape() as tape:
                    reconstruction, prediction, linearity = model(x_batch_train)

                    # total avg loss for each batch
                    batch_train_loss = self.tot_loss(model, y_batch_train, reconstruction, prediction, linearity)
                    batch_train_loss_list.append(batch_train_loss)

                grads = tape.gradient(batch_train_loss, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
                              
            # outside batch loop
            avg_train_loss = np.sum(batch_train_loss_list)/self.num_batches_train
            min_train_loss = np.amin(batch_train_loss_list)
            max_train_loss = np.amax(batch_train_loss_list)
            epoch_train_loss.append(avg_train_loss)
            epoch_train_min_loss.append(min_train_loss)
            epoch_train_max_loss.append(max_train_loss)


            print("Average training loss at epoch %d: %.7f"% (epoch, float(avg_train_loss)))


            ###############################################   Validaiton  loop     ###################################################
            for step, (x_batch_val, y_batch_val) in enumerate(validation_data):
                print("x_batch_val")
                print(tf.shape(x_batch_val))
                reconstruction_val, pred_val, linearity_val = model(x_batch_val)

                batch_validation_loss = self.tot_loss(model, y_batch_val, reconstruction_val, pred_val, linearity_val)
                batch_validation_loss_list.append(batch_validation_loss)

            # outside batch loop
            epoch_validation_loss.append(np.sum(batch_validation_loss_list)/self.num_batches_val)
            epoch_validation_min_loss.append(np.amin(batch_validation_loss_list))
            epoch_validation_max_loss.append(np.amax(batch_validation_loss_list))

            print(f"Epoch val loss: {np.sum(batch_validation_loss_list)/num_batches_val}")
            print("Time taken: %.2fs" % (time.time()- start_time_total))
            #self.graphBatchLossPlot(epoch, batch_train_loss_list, batch_validation_loss_list)
            #K = model.koopman.get_weights()
            #self.graphEigenfunctions(model, K)

        self.graphPlot(epoch_train_loss, epoch_train_min_loss, epoch_train_max_loss, epoch_validation_loss, 
                        epoch_validation_min_loss, epoch_validation_max_loss)
        print("Total time taken: %.2fs" % (time.time() - start_time_total))

# %%
Training_class = MyStaticModel(input_dim, batch_size, trajLength, num_batches_train, num_batches_val)
koopmanAEModel = Koopman_AE_Model(input_dim, output_dim, trajLength, numTraj_batch, name="Koopman_AE_Model")
Training_class.fit(koopmanAEModel,x=train_data, y=train_data, validation_data=validation_data, batch_size=batch_size)
# Out:
# Start of epoch 0
# Average training loss at epoch 0: 0.0460851
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.04122811183333397
# Time taken: 1.52s
#
# Start of epoch 1
# Average training loss at epoch 1: 0.0406106
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.037299610674381256
# Time taken: 2.76s
#
# Start of epoch 2
# Average training loss at epoch 2: 0.0370415
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.03445899859070778
# Time taken: 3.99s
#
# Start of epoch 3
# Average training loss at epoch 3: 0.0342373
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.03184542804956436
# Time taken: 5.22s
#
# Start of epoch 4
# Average training loss at epoch 4: 0.0315812
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.02938029170036316
# Time taken: 6.43s
#
# Start of epoch 5
# Average training loss at epoch 5: 0.0291225
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.027207180857658386
# Time taken: 7.69s
#
# Start of epoch 6
# Average training loss at epoch 6: 0.0269497
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.025279000401496887
# Time taken: 8.97s
#
# Start of epoch 7
# Average training loss at epoch 7: 0.0249704
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.02345656231045723
# Time taken: 10.22s
#
# Start of epoch 8
# Average training loss at epoch 8: 0.0230823
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.021706152707338333
# Time taken: 11.45s
#
# Start of epoch 9
# Average training loss at epoch 9: 0.0212886
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.02006126567721367
# Time taken: 12.75s
#
# Start of epoch 10
# Average training loss at epoch 10: 0.0196050
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.018515920266509056
# Time taken: 14.01s
#
# Start of epoch 11
# Average training loss at epoch 11: 0.0180116
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.017060771584510803
# Time taken: 15.24s
#
# Start of epoch 12
# Average training loss at epoch 12: 0.0165070
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.01569979637861252
# Time taken: 16.48s
#
# Start of epoch 13
# Average training loss at epoch 13: 0.0150913
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.014413664117455482
# Time taken: 17.71s
#
# Start of epoch 14
# Average training loss at epoch 14: 0.0137510
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.013198720291256905
# Time taken: 18.93s
#
# Start of epoch 15
# Average training loss at epoch 15: 0.0124897
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.012061918154358864
# Time taken: 20.15s
#
# Start of epoch 16
# Average training loss at epoch 16: 0.0113051
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.010995464399456978
# Time taken: 21.38s
#
# Start of epoch 17
# Average training loss at epoch 17: 0.0101906
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.009998146444559097
# Time taken: 22.59s
#
# Start of epoch 18
# Average training loss at epoch 18: 0.0091469
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.009067302569746971
# Time taken: 23.84s
#
# Start of epoch 19
# Average training loss at epoch 19: 0.0081727
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.008204502984881401
# Time taken: 25.08s
#
# Start of epoch 20
# Average training loss at epoch 20: 0.0072688
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0074118636548519135
# Time taken: 26.31s
#
# Start of epoch 21
# Average training loss at epoch 21: 0.0064351
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.006688994355499744
# Time taken: 27.54s
#
# Start of epoch 22
# Average training loss at epoch 22: 0.0056720
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.006034638732671738
# Time taken: 28.83s
#
# Start of epoch 23
# Average training loss at epoch 23: 0.0049799
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.005449298303574324
# Time taken: 30.12s
#
# Start of epoch 24
# Average training loss at epoch 24: 0.0043587
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.00493314303457737
# Time taken: 31.38s
#
# Start of epoch 25
# Average training loss at epoch 25: 0.0038074
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.004484168253839016
# Time taken: 32.64s
#
# Start of epoch 26
# Average training loss at epoch 26: 0.0033245
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.004099326673895121
# Time taken: 34.05s
#
# Start of epoch 27
# Average training loss at epoch 27: 0.0029075
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0037760320119559765
# Time taken: 35.33s
#
# Start of epoch 28
# Average training loss at epoch 28: 0.0025532
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0035101529210805893
# Time taken: 36.73s
#
# Start of epoch 29
# Average training loss at epoch 29: 0.0022571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.003296049078926444
# Time taken: 38.00s
#
# Start of epoch 30
# Average training loss at epoch 30: 0.0020141
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.003128137905150652
# Time taken: 39.25s
#
# Start of epoch 31
# Average training loss at epoch 31: 0.0018185
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.003000213298946619
# Time taken: 40.58s
#
# Start of epoch 32
# Average training loss at epoch 32: 0.0016640
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002905487082898617
# Time taken: 41.87s
#
# Start of epoch 33
# Average training loss at epoch 33: 0.0015444
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0028377906419336796
# Time taken: 43.08s
#
# Start of epoch 34
# Average training loss at epoch 34: 0.0014536
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0027911695651710033
# Time taken: 44.32s
#
# Start of epoch 35
# Average training loss at epoch 35: 0.0013858
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0027600647881627083
# Time taken: 45.53s
#
# Start of epoch 36
# Average training loss at epoch 36: 0.0013360
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0027400159742683172
# Time taken: 46.76s
#
# Start of epoch 37
# Average training loss at epoch 37: 0.0012996
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002727244049310684
# Time taken: 47.97s
#
# Start of epoch 38
# Average training loss at epoch 38: 0.0012731
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.00271878601051867
# Time taken: 49.20s
#
# Start of epoch 39
# Average training loss at epoch 39: 0.0012536
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0027125636115670204
# Time taken: 50.41s
#
# Start of epoch 40
# Average training loss at epoch 40: 0.0012389
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002707053441554308
# Time taken: 51.82s
#
# Start of epoch 41
# Average training loss at epoch 41: 0.0012274
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0027013428043574095
# Time taken: 53.11s
#
# Start of epoch 42
# Average training loss at epoch 42: 0.0012180
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0026949229650199413
# Time taken: 54.66s
#
# Start of epoch 43
# Average training loss at epoch 43: 0.0012100
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.00268754456192255
# Time taken: 55.98s
#
# Start of epoch 44
# Average training loss at epoch 44: 0.0012027
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0026791910640895367
# Time taken: 57.47s
#
# Start of epoch 45
# Average training loss at epoch 45: 0.0011960
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0026699404697865248
# Time taken: 58.99s
#
# Start of epoch 46
# Average training loss at epoch 46: 0.0011897
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002659935737028718
# Time taken: 60.43s
#
# Start of epoch 47
# Average training loss at epoch 47: 0.
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018082407768815756
# Time taken: 371.15s
#
# Start of epoch 239
# Average training loss at epoch 239: 0.0007896
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018072574166581035
# Time taken: 373.09s
#
# Start of epoch 240
# Average training loss at epoch 240: 0.0007892
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018062782473862171
# Time taken: 375.06s
#
# Start of epoch 241
# Average training loss at epoch 241: 0.0007887
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018053047824651003
# Time taken: 378.31s
#
# Start of epoch 242
# Average training loss at epoch 242: 0.0007882
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018043359741568565
# Time taken: 380.74s
#
# Start of epoch 243
# Average training loss at epoch 243: 0.0007877
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018033726373687387
# Time taken: 383.76s
#
# Start of epoch 244
# Average training loss at epoch 244: 0.0007873
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018024123273789883
# Time taken: 389.29s
#
# Start of epoch 245
# Average training loss at epoch 245: 0.0007868
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018014567904174328
# Time taken: 392.18s
#
# Start of epoch 246
# Average training loss at epoch 246: 0.0007863
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018005046295002103
# Time taken: 394.49s
#
# Start of epoch 247
# Average training loss at epoch 247: 0.0007859
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017995573580265045
# Time taken: 396.35s
#
# Start of epoch 248
# Average training loss at epoch 248: 0.0007854
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017986125312745571
# Time taken: 398.16s
#
# Start of epoch 249
# Average training loss at epoch 249: 0.0007849
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017976700328290462
# Time taken: 399.78s
#
# Start of epoch 250
# Average training loss at epoch 250: 0.0007845
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017967307940125465
# Time taken: 401.77s
#
# Start of epoch 251
# Average training loss at epoch 251: 0.0007840
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001795794116333127
# Time taken: 403.74s
#
# Start of epoch 252
# Average training loss at epoch 252: 0.0007836
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017948594177141786
# Time taken: 405.31s
#
# Start of epoch 253
# Average training loss at epoch 253: 0.0007831
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001793926814571023
# Time taken: 406.74s
#
# Start of epoch 254
# Average training loss at epoch 254: 0.0007826
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017929974710568786
# Time taken: 408.50s
#
# Start of epoch 255
# Average training loss at epoch 255: 0.0007822
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017920692916959524
# Time taken: 410.38s
#
# Start of epoch 256
# Average training loss at epoch 256: 0.0007817
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017911434406414628
# Time taken: 411.94s
#
# Start of epoch 257
# Average training loss at epoch 257: 0.0007813
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017902195686474442
# Time taken: 413.50s
#
# Start of epoch 258
# Average training loss at epoch 258: 0.0007808
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017892966279760003
# Time taken: 415.09s
#
# Start of epoch 259
# Average training loss at epoch 259: 0.0007803
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017883761320263147
# Time taken: 416.64s
#
# Start of epoch 260
# Average training loss at epoch 260: 0.0007799
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001787458430044353
# Time taken: 418.21s
#
# Start of epoch 261
# Average training loss at epoch 261: 0.0007794
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017865427071228623
# Time taken: 419.81s
#
# Start of epoch 262
# Average training loss at epoch 262: 0.0007790
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017856286140158772
# Time taken: 421.78s
#
# Start of epoch 263
# Average training loss at epoch 263: 0.0007785
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017847169656306505
# Time taken: 423.42s
#
# Start of epoch 264
# Average training loss at epoch 264: 0.0007781
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017838062485679984
# Time taken: 425.06s
#
# Start of epoch 265
# Average training loss at epoch 265: 0.0007776
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017828999552875757
# Time taken: 426.68s
#
# ...
# Epoch val loss: 0.0020918059162795544
# Time taken: 11586.71s
#
# Start of epoch 8915
# Average training loss at epoch 8915: 0.0004748
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002071357099339366
# Time taken: 11587.94s
#
# Start of epoch 8916
# Average training loss at epoch 8916: 0.0004721
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.002008336829021573
# Time taken: 11589.24s
#
# Start of epoch 8917
# Average training loss at epoch 8917: 0.0004668
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019213124178349972
# Time taken: 11590.59s
#
# Start of epoch 8918
# Average training loss at epoch 8918: 0.0004625
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001841841614805162
# Time taken: 11591.94s
#
# Start of epoch 8919
# Average training loss at epoch 8919: 0.0004614
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017930427566170692
# Time taken: 11593.44s
#
# Start of epoch 8920
# Average training loss at epoch 8920: 0.0004631
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017783466028049588
# Time taken: 11594.87s
#
# Start of epoch 8921
# Average training loss at epoch 8921: 0.0004652
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0017910200404003263
# Time taken: 11596.30s
#
# Start of epoch 8922
# Average training loss at epoch 8922: 0.0004658
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018258291529491544
# Time taken: 11597.51s
#
# Start of epoch 8923
# Average training loss at epoch 8923: 0.0004648
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018796311924234033
# Time taken: 11598.80s
#
# Start of epoch 8924
# Average training loss at epoch 8924: 0.0004638
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001938839559443295
# Time taken: 11600.03s
#
# Start of epoch 8925
# Average training loss at epoch 8925: 0.0004639
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001979743130505085
# Time taken: 11601.22s
#
# Start of epoch 8926
# Average training loss at epoch 8926: 0.0004641
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019863098859786987
# Time taken: 11602.54s
#
# Start of epoch 8927
# Average training loss at epoch 8927: 0.0004626
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001961824717000127
# Time taken: 11603.72s
#
# Start of epoch 8928
# Average training loss at epoch 8928: 0.0004598
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019240740220993757
# Time taken: 11605.01s
#
# Start of epoch 8929
# Average training loss at epoch 8929: 0.0004575
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018913676030933857
# Time taken: 11606.22s
#
# Start of epoch 8930
# Average training loss at epoch 8930: 0.0004565
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001872893888503313
# Time taken: 11607.54s
#
# Start of epoch 8931
# Average training loss at epoch 8931: 0.0004564
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018691325094550848
# Time taken: 11608.73s
#
# Start of epoch 8932
# Average training loss at epoch 8932: 0.0004566
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001876389840617776
# Time taken: 11609.93s
#
# Start of epoch 8933
# Average training loss at epoch 8933: 0.0004568
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0018893313826993108
# Time taken: 11611.24s
#
# Start of epoch 8934
# Average training loss at epoch 8934: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019020603504031897
# Time taken: 11612.57s
#
# Start of epoch 8935
# Average training loss at epoch 8935: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001910728751681745
# Time taken: 11613.75s
#
# Start of epoch 8936
# Average training loss at epoch 8936: 0.0004574
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019141961820423603
# Time taken: 11615.02s
#
# Start of epoch 8937
# Average training loss at epoch 8937: 0.0004574
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001913529820740223
# Time taken: 11616.22s
#
# Start of epoch 8938
# Average training loss at epoch 8938: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019105009268969297
# Time taken: 11617.52s
#
# Start of epoch 8939
# Average training loss at epoch 8939: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019067809917032719
# Time taken: 11618.71s
#
# Start of epoch 8940
# Average training loss at epoch 8940: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019036793382838368
# Time taken: 11619.89s
#
# Start of epoch 8941
# Average training loss at epoch 8941: 0.0004569
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019017738522961736
# Time taken: 11621.23s
#
# Start of epoch 8942
# Average training loss at epoch 8942: 0.0004569
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001901142532005906
# Time taken: 11622.59s
#
# Start of epoch 8943
# Average training loss at epoch 8943: 0.0004569
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001901707611978054
# Time taken: 11624.53s
#
# Start of epoch 8944
# Average training loss at epoch 8944: 0.0004569
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001902972930110991
# Time taken: 11625.72s
#
# Start of epoch 8945
# Average training loss at epoch 8945: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001904451521113515
# Time taken: 11626.89s
#
# Start of epoch 8946
# Average training loss at epoch 8946: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019059412879869342
# Time taken: 11628.19s
#
# Start of epoch 8947
# Average training loss at epoch 8947: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019070907728746533
# Time taken: 11629.46s
#
# Start of epoch 8948
# Average training loss at epoch 8948: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019078190671280026
# Time taken: 11630.67s
#
# Start of epoch 8949
# Average training loss at epoch 8949: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019080385100096464
# Time taken: 11631.86s
#
# Start of epoch 8950
# Average training loss at epoch 8950: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019078691257163882
# Time taken: 11633.13s
#
# Start of epoch 8951
# Average training loss at epoch 8951: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019073400180786848
# Time taken: 11634.44s
#
# Start of epoch 8952
# Average training loss at epoch 8952: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001906671328470111
# Time taken: 11635.64s
#
# Start of epoch 8953
# Average training loss at epoch 8953: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019059614278376102
# Time taken: 11636.84s
#
# Start of epoch 8954
# Average training loss at epoch 8954: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019054949516430497
# Time taken: 11638.10s
#
# Start of epoch 8955
# Average training loss at epoch 8955: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019052644493058324
# Time taken: 11639.28s
#
# Start of epoch 8956
# Average training loss at epoch 8956: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019054240547120571
# Time taken: 11640.57s
#
# Start of epoch 8957
# Average training loss at epoch 8957: 0.0004570
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019058480393141508
# Time taken: 11641.74s
#
# Start of epoch 8958
# Average training loss at epoch 8958: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019065688829869032
# Time taken: 11642.94s
#
# Start of epoch 8959
# Average training loss at epoch 8959: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019074073061347008
# Time taken: 11644.23s
#
# Start of epoch 8960
# Average training loss at epoch 8960: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019082772778347135
# Time taken: 11645.55s
#
# Start of epoch 8961
# Average training loss at epoch 8961: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001909030950628221
# Time taken: 11646.74s
#
# Start of epoch 8962
# Average training loss at epoch 8962: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019096613395959139
# Time taken: 11647.94s
#
# Start of epoch 8963
# Average training loss at epoch 8963: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001909906743094325
# Time taken: 11649.40s
#
# Start of epoch 8964
# Average training loss at epoch 8964: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019099164055660367
# Time taken: 11650.77s
#
# Start of epoch 8965
# Average training loss at epoch 8965: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019095895113423467
# Time taken: 11652.05s
#
# Start of epoch 8966
# Average training loss at epoch 8966: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019090804271399975
# Time taken: 11653.46s
#
# Start of epoch 8967
# Average training loss at epoch 8967: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019084136001765728
# Time taken: 11654.68s
#
# Start of epoch 8968
# Average training loss at epoch 8968: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019078124314546585
# Time taken: 11655.90s
#
# Start of epoch 8969
# Average training loss at epoch 8969: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019073460716754198
# Time taken: 11657.21s
#
# Start of epoch 8970
# Average training loss at epoch 8970: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001907066092826426
# Time taken: 11658.57s
#
# Start of epoch 8971
# Average training loss at epoch 8971: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019071120768785477
# Time taken: 11659.76s
#
# Start of epoch 8972
# Average training loss at epoch 8972: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019074671436101198
# Time taken: 11661.05s
#
# Start of epoch 8973
# Average training loss at epoch 8973: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019082152284681797
# Time taken: 11662.23s
#
# Start of epoch 8974
# Average training loss at epoch 8974: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019091746071353555
# Time taken: 11663.55s
#
# Start of epoch 8975
# Average training loss at epoch 8975: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019103647209703922
# Time taken: 11664.76s
#
# Start of epoch 8976
# Average training loss at epoch 8976: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019113867310807109
# Time taken: 11666.05s
#
# Start of epoch 8977
# Average training loss at epoch 8977: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019124174723401666
# Time taken: 11667.30s
#
# Start of epoch 8978
# Average training loss at epoch 8978: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019130292348563671
# Time taken: 11668.60s
#
# Start of epoch 8979
# Average training loss at epoch 8979: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001913409330882132
# Time taken: 11669.80s
#
# Start of epoch 8980
# Average training loss at epoch 8980: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019131515873596072
# Time taken: 11671.10s
#
# Start of epoch 8981
# Average training loss at epoch 8981: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001912680920213461
# Time taken: 11672.27s
#
# Start of epoch 8982
# Average training loss at epoch 8982: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019114766037091613
# Time taken: 11673.58s
#
# Start of epoch 8983
# Average training loss at epoch 8983: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001910282764583826
# Time taken: 11674.77s
#
# Start of epoch 8984
# Average training loss at epoch 8984: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019086733227595687
# Time taken: 11676.07s
#
# Start of epoch 8985
# Average training loss at epoch 8985: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019075304735451937
# Time taken: 11677.27s
#
# Start of epoch 8986
# Average training loss at epoch 8986: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001906273071654141
# Time taken: 11678.48s
#
# Start of epoch 8987
# Average training loss at epoch 8987: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019060258055105805
# Time taken: 11679.76s
#
# Start of epoch 8988
# Average training loss at epoch 8988: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019058154430240393
# Time taken: 11681.00s
#
# Start of epoch 8989
# Average training loss at epoch 8989: 0.0004571
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001906846184283495
# Time taken: 11682.31s
#
# Start of epoch 8990
# Average training loss at epoch 8990: 0.0004572
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019079826306551695
# Time taken: 11683.63s
#
# Start of epoch 8991
# Average training loss at epoch 8991: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019105786923319101
# Time taken: 11684.83s
#
# Start of epoch 8992
# Average training loss at epoch 8992: 0.0004573
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019127004779875278
# Time taken: 11686.12s
#
# Start of epoch 8993
# Average training loss at epoch 8993: 0.0004574
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019161275122314692
# Time taken: 11687.43s
#
# Start of epoch 8994
# Average training loss at epoch 8994: 0.0004575
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019182147225365043
# Time taken: 11688.60s
#
# Start of epoch 8995
# Average training loss at epoch 8995: 0.0004576
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019213551422581077
# Time taken: 11689.86s
#
# Start of epoch 8996
# Average training loss at epoch 8996: 0.0004576
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001921890303492546
# Time taken: 11691.05s
#
# Start of epoch 8997
# Average training loss at epoch 8997: 0.0004577
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019235139479860663
# Time taken: 11692.39s
#
# Start of epoch 8998
# Average training loss at epoch 8998: 0.0004576
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.0019211997278034687
# Time taken: 11693.65s
#
# Start of epoch 8999
# Average training loss at epoch 8999: 0.0004576
# x_batch_val
# tf.Tensor([128   3], shape=(2,), dtype=int32)
# Epoch val loss: 0.001920643844641745
# Time taken: 11694.84s
# Tried making graph folder. Folder already exists...
# Tried making csv folder. Folder already exists...
# Total time taken: 11695.34s

# %% [markdown]
# # Plots on Train data

# %% [markdown]
# ### Reconstruction

# %%
#input = x_train[batch_size*10:batch_size*11]
input = x_train
out1, out2, out3 = koopmanAEModel(input)

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %%
plt.rcParams['figure.figsize'] = [8, 4]
row,col = np.shape(input)

for i in range(col):
    plt.figure(i)
    plt.title("Batch Reconstruction")
    plt.plot(input[0:trajLength,i], label = "Ground Truth")
    plt.plot(out1[0:trajLength,i], '--', label="Reconstruction")
    plt.title("%dth State" % i)
    plt.legend()

# %%
plt.plot(out1[:,0], out1[:,1], label="Ground Truth")
plt.plot(input[:,0], input[:,1], '--', label="Reconstruction")
plt.legend()

# %% [markdown]
# ### Linear Prediction

# %% [markdown]
# ### Graphing Error Section

# %% [markdown]
# #### Average Error Function

# %%
def preProcessForAvg(input, numTraj_batch, trajLength, num_batches, desiredStates, model):
    '''
    Given input, the number of trajectory in each batch, and the trajector length, outputs
    batch data concatenated vertically on top of one another by calling the Koopman AE class

    Parameters:
    -----------
    input: Tensor
        Input data to reshape into outputs
    numTraj_batch: int
        Number of trajectory per batch
    trajLength: int
        Number of snapshots in a trajectory
    desiredStates: list
        List of states
    model: Koopman AE keras model
        Koopman AE model to propagate data

    Return:
    ----------
    x1_all: tensor
        Copy of input (No need for change) (Ground Truth)
    x2_all: tensor
        Concatenated tensor of 1 time shifted data for all batches (Ground Truth)
    x3_all: tensor
        Concatenated tensor of 1 time step shifted data for all batches (x2_all=x3_all) (Ground Truth)
    out1_all: tensor
        Reconstruction of input (parameter) using the Koopman AE class
    out2_all: tensor
        Predicted output from Koopman model of concatenated tensors of 1 time shifted data for all batches
    out3_all: tensor
        Predicted n time step output from Koopman model of concatenated tensors data for all batches
    '''
    
    x2_all = []
    out1_all = []
    out2_all = []
    out3_all = []
    x = input

    for i in range(num_batches):
        x2 = []
        for j in range(numTraj_batch):
            x2.append(x[(i*numTraj_batch+j)*trajLength+1:(i*numTraj_batch+j+1)*trajLength])
        x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input for a batch
        x2_all.append(x2)
        
        x_input = x[i*numTraj_batch*trajLength:(i+1)*numTraj_batch*trajLength]
        out1, out2, out3 = model(x_input)
        out1_all.append(out1)
        out2_all.append(out2)
        out3_all.append(out3)
        
    x1_all = x
    x2_all = tf.reshape(x2_all,(-1,len(desiredStates)))
    x3_all = x2_all
    out1_all = tf.reshape(out1_all,(-1,len(desiredStates)))
    out2_all = tf.reshape(out2_all,(-1,len(desiredStates)))
    out3_all = tf.reshape(out3_all,(-1,len(desiredStates)))


    '''
    print(tf.shape(x2_all))
    print(tf.shape(out1_all))
    print(tf.shape(out2_all))
    print(tf.shape(out3_all))
    '''

    return x1_all, x2_all, x3_all, out1_all, out2_all, out3_all

# %%
def avgTrajError(gTruth, predicted, trajLength, numTraj):
    '''
    Get the average trajectory error with min and max values (Maybe std dev better)

    Parameters:
    -----------
    gTruth: tensor or ndarray
        Ground Truth matrix
    predicted: tensor or ndarray
        Predicted matrix
    trajLength: int
        Length of trajectory
    numTraj: int
        Number of trajectory (total?)
    

    Return:
    ----------
    avgErrorList: list
        List of average errors of all trajectories (each index is the avg error of the states at a point of time along the trajectory)
    
    errorList: list
        List of error of all states and trajectory
    '''
    errorList = []
    avgErrorList = []
    numStates = len(gTruth[0,:])
    for i in range(numTraj):
        '''
        print("Gtruth")
        print(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:])
        print("Predicted")
        print(np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
        print("---Loop---")
        '''
        errorList.append(np.array(gTruth)[i*trajLength:(i+1)*trajLength,:] - np.array(predicted[i*trajLength:(i+1)*trajLength,:]))
    
    #print("Error List")
    #print(np.shape(errorList[0]))
    
    for j in range(trajLength):
        #print("Length of Traj %d"% j)
        for k in range(numTraj):
            #print("Traj: %d"% k)
            if k == 0:
                avgErrorList.append(errorList[k][j,:])
            else:
                #print(avgErrorList[j])
                avgErrorList[j] = (k*avgErrorList[j]+errorList[k][j,:])/(k+1) # Recursive average formula
    return avgErrorList, errorList

# %% [markdown]
# #### Preprocess Error Graph Data

# %%
saveErrorPath = 'errorGraph/'
try:
    os.mkdir(saveErrorPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
x1_all,x2_all,x3_all, out1_all,out2_all,out3_all = preProcessForAvg(x_train,numTraj_batch, trajLength, num_batches_train, desiredStates, koopmanAEModel)
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)

# %%
print(x2_all.shape)
# Out:
# (496, 3)

# %% [markdown]
# #### Error Graphs

# %% [markdown]
# ##### Reconstruction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i],
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i], facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Reconstruction Error")
    plt.xlabel("Time Step")
    plt.ylim((0,1))
    plt.savefig(saveErrorPath+'recon_error_'+title+'.png', dpi=300)
    #plt.close()

# %% [markdown]
# ##### Forward Time Shift Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i], 
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Forward Time Shift Prediction Error")
    plt.xlabel("Time Step")
    plt.ylim((0,1))
    plt.savefig(saveErrorPath+'ftimeShift_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ##### Linearity Prediction Error

# %%
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

# %%
for i in range(len(desiredStates)):
    plt.figure()
    plt.style.use('default')
    plt.plot(avgTrajErrorArray[:,i])
    plt.fill_between(range(len(errorStdDevArray[:,i])), avgTrajErrorArray[:,i]-errorStdDevArray[:,i], 
                    avgTrajErrorArray[:,i]+errorStdDevArray[:,i],facecolor='lightsteelblue')
    title=desiredStates[i]
    plt.title(title)
    plt.ylabel("Linear Prediction Error")
    plt.xlabel("Time Step")
    plt.ylim((0,1))
    plt.savefig(saveErrorPath+'linPred_error_'+title+'.png', dpi=300)
    plt.close()

# %% [markdown]
# ### Reconstruction/Forward Time Shift Prediction/Linear Prediction Graph

# %%
saveOutputPath = 'outputGraph/'
try:
    os.mkdir(saveOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x1_all[:,i])
    plt.plot(out1_all[:,i],'--',label="")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0,1))
    plt.savefig(saveOutputPath+'recon_'+title+'.png', dpi=300, transparent=True)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x2_all[:,i])
    plt.plot(out2_all[:,i],'--',label="")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0,1))
    plt.savefig(saveOutputPath+'ftimeShiftPred_'+title+'.png', dpi=300, transparent=True)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(x3_all[:,i])
    plt.plot(out3_all[:,i],'--',label="")
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0,1))
    plt.savefig(saveOutputPath+'linPred_'+title+'.png', dpi=300, transparent=True)
    plt.close()

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %% [markdown]
# # Animate Graphs

# %% [markdown]
# ## Animate Setup

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
def animateStatesError(middleLine, boundLine, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifBoundLine=True):
    '''
    Given the average trajectory error, standard deviation error, and desired states,
    animate the trajectory with given legend into a mp4 under the mp4 folder

    Parameters:
    -----------
    middleLine: ndarray
        Trajectory of the middle line (nxlen(desiredStates))
    boundLine: ndarray
        Trajectory of the bound for upper and lower bound (+/- stdDev)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line

    Return:
    ---------
    None
    '''
    for j in range(np.shape(middleLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim([0, 128])
        ax.set_ylim([0, 1])
        line, = ax.plot([],[], lw=1, label=desiredStates[j].replace("_", " "))
        plt.style.use('default')
        plt.legend()
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])

            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(middleLine[0:i,j]))
            data = middleLine[0:i,j] #select data range
            line.set_data(x,data)
            line.set_color('#1f77b4')
        
            if ifBoundLine:
                p = plt.fill_between(range(len(boundLine[0:i,j])), middleLine[0:i,j]-boundLine[0:i,j], 
                                middleLine[0:i,j]+boundLine[0:i,j], facecolor='lightsteelblue')
                return line, p,
            else:
                return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=128,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %%
def animateStates(predictedLine, gTruthLine, label1, label2, desiredStates:list, titlePrefix, mp4FilePath = 'mp4/', ifGTruthLine=True):
    '''
    Given the predicted and ground truth trajectory, as well as desired states,
    animate the trajectory with given legend into a mp4 under the mp4FilePath folder

    Parameters:
    -----------
    predictedLine: ndarray
        Trajectory of the predicted line (nxlen(desiredStates))
    gTruthLine: ndarray
        Trajectory of the ground truth line (+/- stdDev)
    label1: str
        Label for predicted line (suffix)
    label2: str
        Label for ground truth line (suffix)
    desiredStates: list
        List of the desired states
    titlePrefix: str
        Prefix title to save into mp4FilePath
    mp4FilePath: str
        Directory path to save mp4
    ifBoundLine: Boolean
        ifBoundLine is true, graphs with bounded fill between lines, else just graphs middle line

    Return:
    ---------
    None
    '''
    for j in range(np.shape(predictedLine)[1]):
        # Set up figure, axis, and plot element want to animate
        fig, ax = plt.subplots(figsize=(10,6))
        ax.set_xlim([0, 128])
        ax.set_ylim([0, 1])
        line, = ax.plot([],[], lw=1, label=desiredStates[j].replace("_", " ") + " " + label1)
        line.set_color('#1f77b4')
        if ifGTruthLine:
            line2, = ax.plot([],[], lw=1, label=desiredStates[j].replace("_", " ") + " " + label2)
            line2.set_color('black')
            plt.setp(line2, linestyle='--')
        
        plt.style.use('default')
        plt.legend()
        plt.tight_layout()

        # Initialize function: plot the background of each frame
        def init():
            line.set_data([], [])
            if ifGTruthLine:
                line2.set_data([],[])
            return line,


        # animation function called sequentially
        def animate(i, j):
            x = range(len(predictedLine[0:i,j]))
            data = predictedLine[0:i,j] #select data range
            line.set_data(x,data)
            if ifGTruthLine:
                line2.set_data(x, gTruthLine[0:i,j])
          
            return line,

        anim = animation.FuncAnimation(fig, animate, init_func=init, frames=128,
                                    interval=10, repeat=True, blit=True, fargs=(j,))

        anim.save(mp4FilePath+titlePrefix+'_'+ desiredStates[j]+'.mp4', writer=writer, dpi=300)
        plt.close()

# %% [markdown]
# ## Animation Graphs

# %% [markdown]
# Trajectory

# %%
animateStates(x1_all, x1_all, 'State Trajectory', 'State Trajectory', desiredStates, 'trajectory', ifGTruthLine=False)

# %% [markdown]
# Error

# %%
# Reconstruction Error
avgTrajErrorList, errorList = avgTrajError(x1_all, out1_all, trajLength, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_recon_error')

# Forward Time Shift Prediction Error
avgTrajErrorList, errorList = avgTrajError(x2_all, out2_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_fTimeShiftPred_error')

# Linear Prediction Error
avgTrajErrorList, errorList = avgTrajError(x3_all, out3_all, trajLength-1, numTraj)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'train_linPred_error')

# %% [markdown]
# Trajectory

# %%
animateStates(out1_all,x1_all,'Reconstruction','Truth',  desiredStates, 'train_traj_recon')
animateStates(out2_all,x2_all,'Forward Time Shift','Truth', desiredStates, 'train_traj_FTimeShiftPred')
animateStates(out3_all,x3_all,'Lin Pred','Truth', desiredStates, 'train_traj_linPred')

# %% [markdown]
# # Save the Model

# %%
koopmanAEModel.save('checkpoints/champ_Trained_Model')
# Out:
# INFO:tensorflow:Assets written to: checkpoints/champ_Trained_Model\assets

# %% [markdown]
# # Load the Model

# %%
new_model = tf.keras.models.load_model('checkpoints/champ_Trained_Model', compile=False)
new_model.summary()
# Out:
# Model: "Koopman_AE_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_model_33 (EncoderMod multiple                  8464
# _________________________________________________________________
# koopman__model_33 (Koopman_M multiple                  256
# _________________________________________________________________
# decoder_model_33 (DecoderMod multiple                  9635
# =================================================================
# Total params: 18,355
# Trainable params: 18,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = x_train
new_out1, new_out2, new_out3 = new_model(input)

# %% [markdown]
# # Plots on Test Data

# %% [markdown]
# ## Test Graphs

# %%
saveTestOutputPath = 'testOutputGraph/'
try:
    os.mkdir(saveTestOutputPath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %%
input = doggo_validation
new_out1, new_out2, new_out3 = new_model(input)

# %%
print(numTraj_batch)
# Out:
# 4

# %%
nx1_all,nx2_all,nx3_all,nout1_all,nout2_all,nout3_all = preProcessForAvg(input,numTraj_batch,trajLength,num_batches_val,desiredStates, new_model)

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx1_all[:,i], label="Ground Truth")
    plt.plot(nout1_all[:,i],'--',label="Predicted")
    plt.ylabel("Reconstruction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0,1))
    plt.legend()
    plt.savefig(saveTestOutputPath+'test_recon_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx2_all[:,i], label="Ground Truth")
    plt.plot(nout2_all[:,i],'--',label="Predicted")
    plt.ylabel("Forward Time Shift Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0,1))
    plt.legend()
    plt.savefig(saveTestOutputPath+'test_fTimeShift_'+title+'.png', dpi=300)
    plt.close()

# %%
for i in range(len(desiredStates)):
    plt.figure(figsize=(8,4))
    plt.style.use('default')
    plt.plot(nx3_all[:,i], label="Ground Truth")
    plt.plot(nout3_all[:,i],'--',label="Predicted")
    plt.ylabel("Linear Prediction")
    plt.xlabel("Time Step")
    title = desiredStates[i]
    plt.title(title)
    plt.ylim((0.3,0.6))
    plt.legend()
    plt.savefig(saveTestOutputPath+'test_linPred_'+title+'.png', dpi=300)
    plt.close()

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

# %%
mp4FilePath = 'mp4/'
try:
    os.mkdir(mp4FilePath)
except OSError as exc:
    print(exc.errno)
# Out:
# 17

# %% [markdown]
# ## Animation on Test

# %%
avgTrajErrorList, errorList = avgTrajError(nx1_all, nout1_all, trajLength, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_recon_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx2_all, nout2_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_fTimeShiftPred_error', mp4FilePath, ifBoundLine=False)

avgTrajErrorList, errorList = avgTrajError(nx3_all, nout3_all, trajLength-1, numTraj_val)
avgTrajErrorArray = np.array(avgTrajErrorList)
errorArray = np.array(errorList)
errorStdDevArray = np.std(errorArray,axis=0)

animateStatesError(avgTrajErrorArray, errorStdDevArray, desiredStates, 'test_linPred_error', mp4FilePath, ifBoundLine=False)

# %% [markdown]
# Trajectory

# %%
animateStates(nout1_all,nx1_all,'Reconstruction','Truth',  desiredStates, 'test_traj_recon')
animateStates(nout2_all,nx2_all,'Forward Time Shift','Truth', desiredStates, 'test_traj_FTimeShiftPred')
animateStates(nout3_all,nx3_all,'Lin Pred','Truth', desiredStates, 'test_traj_linPred')
