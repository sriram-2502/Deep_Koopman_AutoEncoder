# %% [markdown]
# # Implement a custom Autoencoder with Koopman layer

# %% [markdown]
# ## Version Control

# %% [markdown]
# To Do:
# 1) Account for trailing batch - Make robust (fixed issue by reshaping input data)
# 2) Preprocess Data
# 3) Make sure sim data is different for different ground parameters
# 4) Validation data has different batch size. Address when HP training
# 5) Address semi graident issue for K^m*z in linearity loss

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import matplotlib as mpl
from matplotlib import pyplot as plt
from tensorflow import keras

import  numpy as np
import pandas as pd

import matplotlib.colors as mcol

import time 
import os

# %%
plt.rcParams['figure.figsize'] = [9, 6]
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
#from google.colab import drive
#drive.mount('/gdrive')

# %% [markdown]
# Comment out if don't need

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Data

# %% [markdown]
# ### Read full data

# %%
doggo_train = pd.read_csv('Rigid Ground Data/train_data.csv', sep=',').values
doggo_test =pd.read_csv('Rigid Ground Data/test_data.csv', sep=',').values
doggo_validation = pd.read_csv('Rigid Ground Data/validation_data.csv', sep=',').values

# %% [markdown]
# ### Extract theta, theta_dot, gamma and gamma_dot columns

# %%
input_dim = 4
output_dim = 4

doggo_train = doggo_train[:,0:input_dim]
doggo_test = doggo_test[:,0:input_dim]
doggo_validation = doggo_validation[:,0:input_dim]

# %% [markdown]
# ### Define trajectory lengths in each batch

# %%
trajLength = 64 #length of each trajectory in the dataset
numTraj = 16 #total number of trajectories in the dataset
numTraj_val = 4
batch_size = int(256) # Number of snapshots in each batch
numTraj_batch = int(batch_size/trajLength)
input_dim = 4

num_batches_train = int(trajLength*numTraj/batch_size) ## num_batches = trajLength*numTraj/batch_size 
num_batches_val = int(trajLength*numTraj_val/batch_size)

# %% [markdown]
# ### Normalize the data from 0 to 1

# %%
# Normalize the data
min_val = tf.reduce_min(doggo_train)
max_val = tf.reduce_max(doggo_train)

doggo_train = (doggo_train - min_val) / (max_val - min_val)
doggo_validation = (doggo_validation - min_val) / (max_val - min_val)
doggo_test = (doggo_test - min_val) / (max_val - min_val)

train_data = tf.cast(doggo_train, tf.float32)
validation_data = tf.cast(doggo_validation, tf.float32)
validation_data = tf.data.Dataset.from_tensor_slices((validation_data, validation_data)).batch(batch_size)
test_data = tf.cast(doggo_test, tf.float32)

# %%
x_train = train_data
y_train = train_data
tf.shape(x_train)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([1024,    4])>

# %% [markdown]
# ### Plot data

# %%
plt.grid()
plt.plot(train_data[:,0:2]) #51 samples for each trajectory
plt.title(r"$\theta$ $\dot \theta$ vs time")
plt.show()

# %%
plt.grid()
plt.plot(train_data[:,2:4]) #51 samples for each trajectory
plt.title(r"$I_1$ $I_2$ vs time")
plt.show()

# %%
plt.grid()
plt.plot(train_data[:,0], train_data[:,1]) #51 samples for each trajectory
plt.title(r"$\theta$ vs $\dot \theta$")
plt.show()

# %%
plt.grid()
plt.plot(train_data[:,2], train_data[:,3]) #51 samples for each trajectory
plt.title(r"$\gamma$ vs $\dot \gamma$")
plt.show()

# %% [markdown]
# # Custom Model definition

# %% [markdown]
# ## Encoder

# %%
class EncoderLayer(keras.layers.Layer):
    """
    Custom class to create a encoder layer
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * x + b: tensor
        linear combination of weights times input + bias for the layer
    """
    
    def __init__(self, units=32, name=None):
        super(EncoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Encoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, inputs):
        #print("Encoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(inputs, self.w) + self.b

# %%
class EncoderModel(keras.Model):
    """
    Custom Model to create an encoder with one input
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    """
    
    def __init__(self, name=None):
        super(EncoderModel, self).__init__(name=name)
        self.enc0 = EncoderLayer(16)
        self.enc1 = EncoderLayer(32)
        self.enc2 = EncoderLayer(64)
        self.enc3 = EncoderLayer(64)
        self.enc4 = EncoderLayer(16)
        self.enc5 = EncoderLayer(16)
        self.outputLayer = EncoderLayer(16)

    def call(self, input):
        x = input
        x = self.enc0(x)
        x = tf.nn.tanh(x)
        x = self.enc1(x)
        x = tf.nn.tanh(x)
        x = self.enc2(x)
        x = tf.nn.tanh(x)
        x = self.enc3(x)
        x = tf.nn.tanh(x)
        x = self.enc4(x)
        x = tf.nn.tanh(x)
        x = self.enc5(x)
        x = tf.nn.tanh(x)

        # Encoder output layer
        z = self.outputLayer(x)
        z = tf.nn.tanh(z)
        return z

# %% [markdown]
# ## Koopman

# %%
class KoopmanLayer(keras.layers.Layer):
    """
    Custom class to calculate the Koopman operator K on latent variables
    Adds a linear loss as mse(Z2-Z2_tilde)
    
    Parameters
    ----------
    Z: tensor 
        inputs are the latent variabes (output from encoder)
        input dimension is (m, 128)
        m is the number of time snapshots for each input dimension of X
        128 is the number of latent varibales (observables)

    Return
    ----------
    Z: tensor
        return the original input Z 

    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    Z2_tilde: tensor
        return the prediction by linearity from K (z2_tilde = K^m * z(1,:))
    """

    def __init__(self, trajLength, numTraj_batch):
        super(KoopmanLayer, self).__init__()
        self.trajLength = trajLength
        self.numTraj_batch = numTraj_batch

    def build(self, Z):
        # Initialize K as a weight
            self.K =  self.add_weight(
                name = 'Koopman_weight',
                shape=(Z[-1], Z[-1]),
                initializer="random_normal",
                trainable=True,
            )

    def timeShift(self,Z,latent_dim):
        '''
        Shifts trajectories one time step
        Parameters:
        -----------
            Z: tensor
                Batch data of latent variables (in the lifted space)
                
            latent_dim: tensor shape
                Dimension of the lifted space (columns of Z)
        '''
        Z1 = []
        z1 = []
        Z2 = []

        for i in range(self.numTraj_batch):
            Z1.append(Z[i*self.trajLength:(i+1)*self.trajLength-1,:])
            Z2.append(Z[i*self.trajLength+1:(i+1)*self.trajLength,:])
            z1.append(Z[i*self.trajLength,:])
        return tf.reshape(Z1, [-1, latent_dim]), tf.reshape(Z2, [-1, latent_dim]), tf.reshape(z1, [-1, latent_dim])       

    def call(self, Z):
        latent_dim = tf.shape(Z)[1]
        shift_len = (self.trajLength-1)*self.numTraj_batch # length of rows for forward time shifted Z
        Z1, Z2, z1 = self.timeShift(Z,latent_dim)

        # Find Z2_tilde
        Z2_tilde = tf.zeros([shift_len, latent_dim], dtype=tf.float32)
        for traj in range(self.numTraj_batch): # loop over numnber of traj
            for m in range(self.trajLength-1): #loop over snapshots in each traj               
                 indices = tf.constant([[traj*(self.trajLength-1)+m]])
                 if m == 0:
                    K = self.K 
                    # Matrix matvec works out to get Kz' and returns as row vector
                    updates = [tf.linalg.matvec(K, z1[traj,:])] #updates the row tensor at index = indices 
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
                 else:
                    K = tf.matmul(K,self.K)
                    updates = [tf.linalg.matvec(K, z1[traj,:])]
                    Z2_tilde = tf.tensor_scatter_nd_update(Z2_tilde, indices, updates)
           
        # Find linear loss
        Linear_loss = tf.reduce_mean(tf.square(tf.subtract(Z2,Z2_tilde)))
        self.add_loss(Linear_loss)
        
        # prints for debugging dimensions
        #print("Koopman layer, K",tf.shape(K))
        #print("Koopman layer, m",tf.shape(m))
        #print("Koopman layer, Z",tf.shape(Z))
        #print("Koopman layer, z1",tf.shape(z1))
        #print("Koopman layer, Z2 ",tf.shape(Z2))
        #print("Koopman layer, Z2_tilde",tf.shape(Z2_tilde))
        
        return Z, tf.matmul(Z1,self.K), Z2_tilde,

# %%
class Koopman_Model(keras.Model):
    """
    Custom Model to create an encoder with koopman layer
    
    Parameters
    ----------
    input: tensor 
        z - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    z: tensor
        Latent variables of x in the lifted space
    
    Z2_hat: tensor
        return the prediction from K (z2_hat = K*z1)

    z2_tilde: tensor
        Latent variables of prediction obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    """
    
    def __init__(self, trajLength, numTraj_batch, name=None):
        super(Koopman_Model, self).__init__(name=name)
        self.koopman = KoopmanLayer(trajLength,numTraj_batch)


    def call(self, input):
        z = input
        z, Z2_hat, z2_tilde = self.koopman(z)
        return z, Z2_hat, z2_tilde

# %% [markdown]
# ## Decoder

# %%
class DecoderLayer(keras.layers.Layer):
    """
    Custom class to create a decoder layer with two inputs
    
    Parameters
    ----------
    units: number of units in the layer 
        units are assigned to the layer at the time of initialization
    
    input_shape: shape of the input (output from previous layer)
        input_shape is used to build the weight matrix at the time of call
        
    Return
    ----------
    W.T * input1 + b: tensor
        linear combination of weights times input1 + bias for the layer
        
    W.T * input2 + b: tensor
        linear combination of weights times input2 + bias for the layer

    W.T * input3 + b: tensor
        linear combination of weights times input3 + bias for the layer
    """

    def __init__(self, units=32, name=None):
        super(DecoderLayer, self).__init__(name=name)
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(
            name = 'weight',
            shape=(input_shape[-1], self.units),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.b = self.add_weight(
            name = 'bias',
            shape=(self.units,), initializer="zeros", trainable=True
        )
        #print("Decoder Layer, weight dimension:",tf.shape(self.w))

    def call(self, input1, input2, input3):
        #print("Decoder Layer, output dimension:",tf.shape(tf.matmul(inputs, self.w) + self.b))
        return tf.matmul(input1, self.w) + self.b, tf.matmul(input2, self.w) + self.b, tf.matmul(input3, self.w) + self.b

# %%
class DecoderModel(keras.Model):
    """
    Custom Model to create a decoder with two inputs
    
    Parameters
    ----------
    input 1: tensor 
        z - the lifted output of the koopman layer (encoder output)
    
    input 2: tensor 
        z2_tilde - obtained by linearity from K (z2_tilde = K^m * z(1,:))
        
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Prediction of the original state inputs x (label values are forward time shifted x)

    x2_tilde: tensor
        Prediction obtained by linearity from K 
    
    """
    
    def __init__(self, output_dim=4, name=None):
        super(DecoderModel, self).__init__(name=name)
        self.dec0 = DecoderLayer(64)
        self.dec1 = DecoderLayer(64)
        self.dec2 = DecoderLayer(32)
        self.dec3 = DecoderLayer(64)
        self.outputLayer = DecoderLayer(output_dim)

    def call(self, input1, input2, input3):
        z = input1
        z2_hat = input2
        z2_tilde = input3

        z, z2_hat, z2_tilde = self.dec0(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec1(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec2(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)

        z, z2_hat, z2_tilde = self.dec3(z, z2_hat, z2_tilde)
        z = tf.nn.tanh(z)
        z2_hat = tf.nn.tanh(z2_hat)
        z2_tilde = tf.nn.tanh(z2_tilde)


        # Decoder output layer
        x_hat, x2_hat, x2_tilde = self.outputLayer(z, z2_hat, z2_tilde)
        #x_hat = tf.nn.elu(x_hat)
        #x2_hat = tf.nn.elu(x2_hat)
        #x2_tilde = tf.nn.elu(x2_tilde)

        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# ## Koopman Autoencoder

# %%
class Koopman_AE_Model(keras.Model):
    """
    Custom Model to create a Koopman Autoencoder
    
    Parameters
    ----------
    input: tensor 
        x - the the orignal state inputs x given as snapshots taken from random trajectory
    
    Return
    ----------
    x_hat: tensor
        Reconstuction of the orignal state inputs x (label values are x)
    
    x2_hat: tensor
        Predcition of the original state inputs x (label values are forward time shifted x)
    
    x2_tilde: tensor
        Prediction obtained by linearity from K 
    """
    
    def __init__(self, trajLength, numTraj, name=None):
        super(Koopman_AE_Model, self).__init__(name=name)
        self.enc = EncoderModel()
        self.koopman = Koopman_Model(trajLength, numTraj)
        self.dec = DecoderModel(output_dim)

    def call(self, input):
        x = input
        z = self.enc(x)
        z, z2_hat, z2_tilde = self.koopman(z)
        x_hat, x2_hat, x2_tilde = self.dec(z, z2_hat, z2_tilde)
        return x_hat, x2_hat, x2_tilde

# %% [markdown]
# # Custom Training Loop

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.batch(batch_size)

# %%
class MyStaticModel():
    def __init__(self, input_dim, batch_size, trajLength, num_batches_train, num_batches_val):
        # Initialize constants
        self.batch_size = batch_size
        self.trajLength = int(trajLength) #should be int
        self.numtraj_batch = int(self.batch_size/self.trajLength) # should be int
        self.num_batches_train = num_batches_train
        self.num_batches_val = num_batches_val

        self.inputs = tf.keras.layers.Input(shape=(input_dim,))
        self.graphCounter = 0 

    ######################################  LOSS FUNCTIONS  ###################################################
    def tot_loss(self, model, x, x_hat, x2_hat, x2_tilde):
        """Calculates total loss as sum of recon_loss + predict_loss + Koopman_loss"""
        #alpha1 = 0.1, alpha2 = 1e-7, alpha3 = 1e-15
        alpha1 = 0.1
        alpha2 = 1e-7
        alpha3 = 1e-15

        #print("In loss function x", tf.shape(x))
        #print("In loss function x_hat", tf.shape(x_hat))
        #print("In loss function x2_hat", tf.shape(x2_hat))
        #print("In loss function x2_tilde", tf.shape(x2_tilde))

        x2 = []
        x2_SP = []
        x2_tilde_SP = []
        for i in range(self.numtraj_batch):
            predict_length = self.trajLength-1
            x2.append(x[i*self.trajLength+1:(i+1)*self.trajLength]) # forward time shift x to get x2
            x2_SP.append(x[i*self.trajLength+1:i*self.trajLength+predict_length+1]) # forward time shift x to get x2 for Sp timesteps
            #x2_tilde_SP.append(x2_tilde[i*self.trajLength:i*self.trajLength+predict_length]) # get Sp timesteps from x2_tilde
            x2_tilde_SP = x2_tilde

        #print("In loss function x2", tf.shape(x2))
        #print("In loss function x2_SP", tf.shape(x2_SP))
        #print("In loss function x2_tilde_SP", tf.shape(x2_tilde_SP))
        
        x2 = tf.reshape(x2, [-1, x.shape[-1]])
        x2_SP = tf.reshape(x2_SP, [-1, x.shape[-1]])
        x2_tilde_SP = tf.reshape(x2_tilde_SP, [-1, x.shape[-1]])

        recon_loss = tf.reduce_mean(tf.square(tf.subtract(x,x_hat)))
        predict_loss =tf.reduce_mean(tf.square(tf.subtract(x2_SP,x2_tilde_SP)))

        weights  = model.trainable_variables
        lossL2 = tf.add_n([tf.nn.l2_loss(w) for w in weights if 'bias' not in w.name])

        Linf_loss = tf.add(tf.norm(tf.subtract(x,x_hat), ord=np.inf), tf.norm(tf.subtract(x2,x2_hat), ord=np.inf))
        return alpha1*(recon_loss+predict_loss) + alpha2*Linf_loss + alpha3*lossL2 + sum(model.losses)

    ###############################################  GRAPH FUNCTIONS #########################################################

    def graphPlot(self, error, error_min, error_max, error_val, error_min_val, error_max_val):
        '''
        Graph plots for loss over all epochs
        Parameters:
        error: list
            Training Loss Error for all epochs
        error_val: list
            Validation Loss Error for all epochs
        '''
        saveFiles = True
        imgPath = 'graphs/'
        csvPath = 'csvFiles/'

        csvFileName = 'epochLosses.csv'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making graph folder. Folder already exists...")

            try:
                os.mkdir(csvPath)
            except:
                print("Tried making csv folder. Folder already exists...")
        
        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Training Loss")
        plt.plot(error_val, label = "Validation Loss")
        textTitle = "All Epoch Loss %d" % self.graphCounter
        self.graphCounter += 1
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight') 
        plt.close()

        # Save data into csv file
        csvDict = {'Epoch Training Loss': error, 'Epoch Training Min Loss': error_min, 'Epoch Training Max Loss': error_max,
                    'Epoch Validation Loss': error_val, 'Epoch Validation Min Loss' : error_min_val, 
                    'Epoch Validation Max Loss': error_max_val}
        df = pd.DataFrame(csvDict)
        df.to_csv(csvPath+csvFileName)

    
    def graphBatchLossPlot(self, epochNum, error, error_val):
        saveFiles = True
        imgPath = 'graphs/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        plt.figure(figsize=(10,10))
        plt.xlabel('time', fontsize=16)
        plt.ylabel('x', fontsize=16)
        plt.plot(error, label="Batch Training Loss")
        plt.plot(error_val, label="Batch Validation Loss")
        textTitle = "BatchLoss_Epoch_%d" % (epochNum)
        plt.title(textTitle)
        plt.legend()
        if saveFiles:
            plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
        plt.close() 

    
    def graphEigenfunctions(self, model, K):
        saveFiles = True
        imgPath = 'graphs/eigenfunctions/'
        if saveFiles:
            try:
                os.mkdir(imgPath)
            except:
                print("Tried making folder. Folder already exists...")

        x1 = tf.linspace(-1,1,256)
        x2 = tf.linspace(-1,1,256)
        x1, x2 = tf.meshgrid(x1, x2)
        X = tf.reshape([[x1],[x2]], [-1, 2])

        Z = model.enc(X)
        complex_Z = tf.complex(Z, tf.zeros(tf.shape(Z))) # make Z complex with zero complex part

        eig_values, right_eig_vectors = tf.linalg.eig(tf.squeeze(K))
        W = tf.transpose(tf.linalg.inv(right_eig_vectors))
        Psi = tf.matmul(complex_Z,W)

        eig_dominant = tf.abs(eig_values)
        counter = 0
        for eig in eig_values:
            cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["b","w","r"])
            #normalize = mpl.colors.Normalize(vmin=np.min(Psi[:,counter]), vmax=np.max(Psi[:,counter]))
            plt.figure(counter)
            fig, axs = plt.subplots(2)
            
            p1 = axs[0].scatter(x1, x2, c=tf.abs(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p1, ax=axs[0])
            fig_title1 = "|Psi| %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig)) 
            axs[0].set_title(fig_title1)
            
            p2 = axs[1].scatter(x1, x2, c=tf.math.angle(Psi[:,counter]).numpy(), cmap=cm1)
            fig.colorbar(p2, ax=axs[1])
            fig_title2 = "angle(Psi) %0.04f + %0.04f i"%(tf.math.real(eig),tf.math.imag(eig))  
            axs[1].set_title(fig_title2)

            fig.tight_layout()
            textTitle = "Psi_%0.04f_epoch%d"%(eig, counter)
            counter += 1
            if saveFiles:
                plt.savefig(imgPath+textTitle+'.png', bbox_inches='tight')
            plt.close('all') 

    ###############################################     FIT FUNCTION        #########################################################

    def fit(self, model, x, y, validation_data, batch_size):
        # Preprocess data
        train_ds = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)

        # Define the optimizer
        optimizer = tf.keras.optimizers.Adam(0.0001)

        epochs = 10000     
        
        epoch_train_loss = [] 
        epoch_train_min_loss = []
        epoch_train_max_loss = []

        epoch_validation_loss = []
        epoch_validation_min_loss = []
        epoch_validation_max_loss = []


        start_time_total = time.time()
        for epoch in range(epochs):

            print("\nStart of epoch %d" % (epoch))
            start_time = time.time()

            batch_train_loss_list = [] # total loss for each batch 
            batch_validation_loss_list = []

            
            ###############################################     Training loop     ###################################################
            # Iterate over the train batches of the dataset.
            for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
                with tf.GradientTape() as tape:
                    reconstruction, prediction, linearity = model(x_batch_train)

                    # total avg loss for each batch
                    batch_train_loss = self.tot_loss(model, y_batch_train, reconstruction, prediction, linearity)
                    batch_train_loss_list.append(batch_train_loss)

                grads = tape.gradient(batch_train_loss, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
                              
            # outside batch loop
            avg_train_loss = np.sum(batch_train_loss_list)/self.num_batches_train
            min_train_loss = np.amin(batch_train_loss_list)
            max_train_loss = np.amax(batch_train_loss_list)

            epoch_train_loss.append(avg_train_loss)
            epoch_train_min_loss.append(min_train_loss)
            epoch_train_max_loss.append(max_train_loss)
            print("Average training loss at epoch %d: %.7f"% (epoch, float(avg_train_loss)))


            ###############################################   Validaiton  loop     ###################################################
            for step, (x_batch_val, y_batch_val) in enumerate(validation_data):
                reconstruction_val, pred_val, linearity_val = model(x_batch_val)
                batch_validation_loss = self.tot_loss(model, y_batch_val, reconstruction_val, pred_val, linearity_val)
                batch_validation_loss_list.append(batch_validation_loss)

            # outside batch loop
            epoch_validation_loss.append(np.sum(batch_validation_loss_list)/self.num_batches_val)
            epoch_validation_min_loss.append(np.amin(batch_validation_loss_list))
            epoch_validation_max_loss.append(np.amax(batch_validation_loss_list))

            print(f"Epoch val loss: {np.sum(batch_validation_loss_list)/num_batches_val}")
            print("Time taken: %.2fs" % (time.time()- start_time_total))
            #self.graphBatchLossPlot(epoch, batch_train_loss_list, batch_validation_loss_list)
            #K = model.koopman.get_weights()
            #self.graphEigenfunctions(model, K)

        self.graphPlot(epoch_train_loss, epoch_train_min_loss, epoch_train_max_loss, epoch_validation_loss, 
                        epoch_validation_min_loss, epoch_validation_max_loss)
        print("Total time taken: %.2fs" % (time.time() - start_time_total))

# %%
Training_class = MyStaticModel(input_dim, batch_size, trajLength, num_batches_train, num_batches_val)
koopmanAEModel = Koopman_AE_Model(trajLength, numTraj_batch, name="Koopman_AE_Model")
Training_class.fit(koopmanAEModel,x=train_data, y=train_data, validation_data=validation_data, batch_size=batch_size)
# Out:
# Start of epoch 0
# Average training loss at epoch 0: 0.0757561
# Epoch val loss: 0.06507906317710876
# Time taken: 2.47s
#
# Start of epoch 1
# Average training loss at epoch 1: 0.0626045
# Epoch val loss: 0.05448856204748154
# Time taken: 4.08s
#
# Start of epoch 2
# Average training loss at epoch 2: 0.0529944
# Epoch val loss: 0.04681289941072464
# Time taken: 5.76s
#
# Start of epoch 3
# Average training loss at epoch 3: 0.0459880
# Epoch val loss: 0.04114796966314316
# Time taken: 7.30s
#
# Start of epoch 4
# Average training loss at epoch 4: 0.
#
# Start of epoch 36
# Average training loss at epoch 36: 0.0021501
# Epoch val loss: 0.0017337778117507696
# Time taken: 62.54s
#
# Start of epoch 37
# Average training loss at epoch 37: 0.0018491
# Epoch val loss: 0.0014714142307639122
# Time taken: 64.17s
#
# Start of epoch 38
# Average training loss at epoch 38: 0.0015837
# Epoch val loss: 0.0012435015523806214
# Time taken: 65.85s
#
# Start of epoch 39
# Average training loss at epoch 39: 0.0013521
# Epoch val loss: 0.001046256278641522
# Time taken: 67.48s
#
# Start of epoch 40
# Average training loss at epoch 40: 0.0011519
# Epoch val loss: 0.0008794183377176523
# Time taken: 69.10s
#
# Start of epoch 41
# Average training loss at epoch 41: 0.0009807
# Epoch val loss: 0.0007388122612610459
# Time taken: 70.74s
#
# Start of epoch 42
# Average training loss at epoch 42: 0.0008356
# Epoch val loss: 0.0006190257845446467
# Time taken: 72.41s
#
# Start of epoch 43
# Average training loss at epoch 43: 0.0007136
# Epoch val loss: 0.0005224271444603801
# Time taken: 74.03s
#
# Start of epoch 44
# Average training loss at epoch 44: 0.0006124
# Epoch val loss: 0.00044451517169363797
# Time taken: 75.65s
#
# Start of epoch 45
# Average training loss at epoch 45: 0.0005296
# Epoch val loss: 0.0003806411405093968
# Time taken: 77.32s
#
# Start of epoch 46
# Average training loss at epoch 46: 0.0004622
# Epoch val loss: 0.0003298340307082981
# Time taken: 78.90s
#
# Start of epoch 47
# Average training loss at epoch 47: 0.0004074
# Epoch val loss: 0.0002908787573687732
# Time taken: 80.54s
#
# Start of epoch 48
# Average training loss at epoch 48: 0.0003640
# Epoch val loss: 0.0002587345661595464
# Time taken: 82.16s
#
# Start of epoch 49
# Average training loss at epoch 49: 0.0003289
# Epoch val loss: 0.00023578251420985907
# Time taken: 83.79s
#
# Start of epoch 50
# Average training loss at epoch 50: 0.0003015
# Epoch val loss: 0.00021688810375053436
# Time taken: 85.41s
#
# Start of epoch 51
# Average training loss at epoch 51: 0.0002793
# Epoch val loss: 0.00020331607083790004
# Time taken: 87.05s
#
# Start of epoch 52
# Average training loss at epoch 52: 0.0002624
# Epoch val loss: 0.0001921313814818859
# Time taken: 88.68s
#
# Start of epoch 53
# Average training loss at epoch 53: 0.0002484
# Epoch val loss: 0.0001837718446040526
# Time taken: 90.34s
#
# Start of epoch 54
# Average training loss at epoch 54: 0.0002374
# Epoch val loss: 0.00017720265896059573
# Time taken: 92.09s
#
# Start of epoch 55
# Average training loss at epoch 55: 0.0002283
# Epoch val loss: 0.00017190338985528797
# Time taken: 93.75s
#
# Start of epoch 56
# Average training loss at epoch 56: 0.0002210
# Epoch val loss: 0.00016725892783142626
# Time taken: 95.40s
#
# Start of epoch 57
# Average training loss at epoch 57: 0.0002147
# Epoch val loss: 0.0001636934030102566
# Time taken: 97.07s
#
# Start of epoch 58
# Average training loss at epoch 58: 0.0002094
# Epoch val loss: 0.0001603406126378104
# Time taken: 98.70s
#
# Start of epoch 59
# Average training loss at epoch 59: 0.0002049
# Epoch val loss: 0.00015727461141068488
# Time taken: 100.34s
#
# Start of epoch 60
# Average training loss at epoch 60: 0.0002007
# Epoch val loss: 0.0001547520369058475
# Time taken: 102.01s
#
# Start of epoch 61
# Average training loss at epoch 61: 0.0001973
# Epoch val loss: 0.00015210051788017154
# Time taken: 103.67s
#
# Start of epoch 62
# Average training loss at epoch 62: 0.0001940
# Epoch val loss: 0.00014994163939263672
# Time taken: 105.32s
#
# Start of epoch 63
# Average training loss at epoch 63: 0.0001910
# Epoch val loss: 0.0001477650075685233
# Time taken: 106.96s
#
# Start of epoch 64
# Average training loss at epoch 64: 0.0001883
# Epoch val loss: 0.00014553173969034106
# Time taken: 108.70s
#
# Start of epoch 65
# Average training loss at epoch 65: 0.0001858
# Epoch val loss: 0.00014389550779014826
# Time taken: 110.42s
#
# Start of epoch 66
# Average training loss at epoch 66: 0.0001835
# Epoch val loss: 0.0001420723565388471
# Time taken: 112.07s
#
# Start of epoch 67
# Average training loss at epoch 67: 0.0001816
# Epoch val loss: 0.0001402136986143887
# Time taken: 113.70s
#
# Start of epoch 68
# Average training loss at epoch 68: 0.0001795
# Epoch val loss: 0.00013885967200621963
# Time taken: 115.38s
#
# Start of epoch 69
# Average training loss at epoch 69: 0.0001777
# Epoch val loss: 0.00013714346277993172
# Time taken: 116.97s
#
# Start of epoch 70
# Average training loss at epoch 70: 0.0001760
# Epoch val loss: 0.0001358259323751554
# Time taken: 118.67s
#
# Start of epoch 71
# Average training loss at epoch 71: 0.0001743
# Epoch val loss: 0.00013492946163751185
# Time taken: 120.32s
#
# Start of epoch 72
# Average training loss at epoch 72: 0.0001731
# Epoch val loss: 0.00013301806757226586
# Time taken: 121.85s
#
# Start of epoch 73
# Average training loss at epoch 73: 0.0001715
# Epoch val loss: 0.00013236835366114974
# Time taken: 123.42s
#
# Start of epoch 74
# Average training loss at epoch 74: 0.0001702
# Epoch val loss: 0.00013120498624630272
# Time taken: 124.99s
#
# Start of epoch 75
# Average training loss at epoch 75: 0.0001691
# Epoch val loss: 0.00012972096737939864
# Time taken: 126.68s
#
# Start of epoch 76
# Average training loss at epoch 76: 0.0001677
# Epoch val loss: 0.00012940101441927254
# Time taken: 128.21s
#
# Start of epoch 77
# Average training loss at epoch 77: 0.0001668
# Epoch val loss: 0.00012829492334276438
# Time taken: 129.82s
#
# Start of epoch 78
# Average training loss at epoch 78: 0.0001658
# Epoch val loss: 0.00012765901919919997
# Time taken: 131.51s
#
# Start of epoch 79
# Average training loss at epoch 79: 0.0001647
# Epoch val loss: 0.00012675215839408338
# Time taken: 133.09s
#
# Start of epoch 80
# Average training loss at epoch 80: 0.0001639
# Epoch val loss: 0.00012598723697010428
# Time taken: 134.78s
#
# Start of epoch 81
# Average training loss at epoch 81: 0.0001629
# Epoch val loss: 0.00012526950740721077
# Time taken: 136.40s
#
# Start of epoch 82
# Average training loss at epoch 82: 0.0001621
# Epoch val loss: 0.00012489045911934227
# Time taken: 138.06s
#
# Start of epoch 83
# Average training loss at epoch 83: 0.0001615
# Epoch val loss: 0.00012403633445501328
# Time taken: 139.71s
#
# Start of epoch 84
# Average training loss at epoch 84: 0.0001605
# Epoch val loss: 0.0001238387485500425
# Time taken: 141.34s
#
# Start of epoch 85
# Average training loss at epoch 85: 0.0001600
# Epoch val loss: 0.00012300480739213526
# Time taken: 142.94s
#
# Start of epoch 86
# Average training loss at epoch 86: 0.0001593
# Epoch val loss: 0.0001225770974997431
# Time taken: 144.70s
#
# Start of epoch 87
# Average training loss at epoch 87: 0.0001585
# Epoch val loss: 0.0001222360151587054
# Time taken: 147.51s
#
# Start of epoch 88
# Average training loss at epoch 88: 0.0001582
# Epoch val loss: 0.00012133485870435834
# Time taken: 149.69s
#
# Start of epoch 89
# Average training loss at epoch 89: 0.0001574
# Epoch val loss: 0.0001214354851981625
# Time taken: 151.40s
#
# Start of epoch 90
# Average training loss at epoch 90: 0.0001569
# Epoch val loss: 0.00012083924957551062
# Time taken: 153.04s
#
# Start of epoch 91
# Average training loss at epoch 91: 0.0001564
# Epoch val loss: 0.00012056485866196454
# Time taken: 154.68s
#
# Start of epoch 92
# Average training loss at epoch 92: 0.0001558
# Epoch val loss: 0.00012018890993203968
# Time taken: 156.58s
#
# Start of epoch 93
# Average training loss at epoch 93: 0.0001555
# Epoch val loss: 0.00011948443716391921
# Time taken: 158.23s
#
# Start of epoch 94
# Average training loss at epoch 94: 0.0001548
# Epoch val loss: 0.000119478689157404
# Time taken: 159.84s
#
# Start of epoch 95
# Average training loss at epoch 95: 0.0001546
# Epoch val loss: 0.00011912680929526687
# Time taken: 161.43s
#
# Start of epoch 96
# Average training loss at epoch 96: 0.0001542
# Epoch val loss: 0.00011876343342009932
# Time taken: 162.98s
#
# Start of epoch 97
# Average training loss at epoch 97: 0.0001537
# Epoch val loss: 0.00011838327918667346
# Time taken: 164.52s
#
# Start of epoch 98
# Average training loss at epoch 98: 0.0001533
# Epoch val loss: 0.00011847654968732968
# Time taken: 166.06s
#
# Start of epoch 99
# Average training loss at epoch 99: 0.0001530
# Epoch val loss: 0.00011791547149186954
# Time taken: 167.61s
#
# Start of epoch 100
# Average training loss at epoch 100: 0.0001527
# Epoch val loss: 0.0001176421792479232
# Time taken: 169.22s
#
# Start of epoch 101
# Average training loss at epoch 101: 0.0001521
# Epoch val loss: 0.00011774177255574614
# Time taken: 170.76s
#
# Start of epoch 102
# Average training loss at epoch 102: 0.0001520
# Epoch val loss: 0.000117260824481491
# Time taken: 172.33s
#
# Start of epoch 103
# Average training loss at epoch 103: 0.0001516
# Epoch val loss: 0.00011729764810297638
# Time taken: 173.86s
#
# Start of epoch 104
# Average training loss at epoch 104: 0.0001513
# Epoch val loss: 0.00011705913493642583
# Time taken: 175.47s
#
# Start of epoch 105
# Average training loss at epoch 105: 0.0001513
# Epoch val loss: 0.00011655647540464997
# Time taken: 177.35s
#
# Start of epoch 106
# Average training loss at epoch 106: 0.0001507
# Epoch val loss: 0.00011691637337207794
# Time taken: 178.88s
#
# Start of epoch 107
# Average training loss at epoch 107: 0.0001507
# Epoch val loss: 0.0001165073990705423
# Time taken: 180.46s
#
# Start of epoch 108
# Average training loss at epoch 108: 0.0001503
# Epoch val loss: 0.00011655304842861369
# Time taken: 182.02s
#
# Start of epoch 109
# Average training loss at epoch 109: 0.0001500
# Epoch val loss: 0.00011618740973062813
# Time taken: 183.61s
#
# Start of epoch 110
# Average training loss at epoch 110: 0.0001497
# Epoch val loss: 0.00011621134035522118
# Time taken: 185.14s
#
# Start of epoch 111
# Average training loss at epoch 111: 0.0001496
# Epoch val loss: 0.00011565300519578159
# Time taken: 186.68s
#
# Start of epoch 112
# Average training loss at epoch 112: 0.0001493
# Epoch val loss: 0.00011564225860638544
# Time taken: 188.47s
#
# Start of epoch 113
# Average training loss at epoch 113: 0.0001491
# Epoch val loss: 0.00011548266047611833
# Time taken: 190.11s
#
# Start of epoch 114
# Average training loss at epoch 114: 0.0001488
# Epoch val loss: 0.00011535089288372546
# Time taken: 191.67s
#
# Start of epoch 115
# Average training loss at epoch 115: 0.0001485
# Epoch val loss: 0.00011513225763337687
# Time taken: 193.41s
#
# Start of epoch 116
# Average training loss at epoch 116: 0.0001483
# Epoch val loss: 0.00011513416393427178
# Time taken: 195.12s
#
# Start of epoch 117
# Average training loss at epoch 117: 0.0001481
# Epoch val loss: 0.00011518191604409367
# Time taken: 196.71s
#
# Start of epoch 118
# Average training loss at epoch 118: 0.0001481
# Epoch val loss: 0.0001147761577158235
# Time taken: 198.59s
#
# Start of epoch 119
# Average training loss at epoch 119: 0.0001478
# Epoch val loss: 0.00011483809794299304
# Time taken: 200.58s
#
# Start of epoch 120
# Average training loss at epoch 120: 0.0001476
# Epoch val loss: 0.0001142579858424142
# Time taken: 202.24s
#
# Start of epoch 121
# Average training loss at epoch 121: 0.0001472
# Epoch val loss: 0.00011428191646700725
# Time taken: 203.88s
#
# Start of epoch 122
# Average training loss at epoch 122: 0.0001471
# Epoch val loss: 0.00011402956442907453
# Time taken: 205.64s
#
# Start of epoch 123
# Average training loss at epoch 123: 0.0001469
# Epoch val loss: 0.00011398087372072041
# Time taken: 207.30s
#
# Start of epoch 124
# Average training loss at epoch 124: 0.0001467
# Epoch val loss: 0.00011384542449377477
# Time taken: 209.00s
#
# Start of epoch 125
# Average training loss at epoch 125: 0.0001466
# Epoch val loss: 0.00011384367098798975
# Time taken: 210.60s
#
# Start of epoch 126
# Average training loss at epoch 126: 0.0001464
# Epoch val loss: 0.00011364839156158268
# Time taken: 212.26s
#
# Start of epoch 127
# Average training loss at epoch 127: 0.0001462
# Epoch val loss: 0.00011354255548212677
# Time taken: 213.92s
#
# Start of epoch 128
# Average training loss at epoch 128: 0.0001460
# Epoch val loss: 0.00011342825018800795
# Time taken: 215.60s
#
# Start of epoch 129
# Average training loss at epoch 129: 0.0001458
# Epoch val loss: 0.00011321248894091696
# Time taken: 217.15s
#
# Start of epoch 130
# Average training loss at epoch 130: 0.0001456
# Epoch val loss: 0.00011301310587441549
# Time taken: 218.88s
#
# Start of epoch 131
# Average training loss at epoch 131: 0.0001454
# Epoch val loss: 0.00011312679998809472
# Time taken: 220.53s
#
# Start of epoch 132
# Average training loss at epoch 132: 0.0001452
# Epoch val loss: 0.00011302483471808955
# Time taken: 222.19s
#
# Start of epoch 133
# Average training loss at epoch 133: 0.0001452
# Epoch val loss: 0.0001128312069340609
# Time taken: 223.97s
#
# Start of epoch 134
# Average training loss at epoch 134: 0.0001448
# Epoch val loss: 0.00011276992154307663
# Time taken: 225.65s
#
# Start of epoch 135
# Average training loss at epoch 135: 0.0001448
# Epoch val loss: 0.0001127625655499287
# Time taken: 227.37s
#
# Start of epoch 136
# Average training loss at epoch 136: 0.0001446
# Epoch val loss: 0.00011236296268180013
# Time taken: 229.05s
#
# Start of epoch 137
# Average training loss at epoch 137: 0.0001444
# Epoch val loss: 0.00011240304593229666
# Time taken: 230.76s
#
# Start of epoch 138
# Average training loss at epoch 138: 0.0001443
# Epoch val loss: 0.00011236884165555239
# Time taken: 232.45s
#
# Start of epoch 139
# Average training loss at epoch 139: 0.0001441
# Epoch val loss: 0.00011214850383112207
# Time taken: 234.18s
#
# Start of epoch 140
# Average training loss at epoch 140: 0.0001439
# Epoch val loss: 0.00011202767200302333
# Time taken: 235.93s
#
# Start of epoch 141
# Average training loss at epoch 141: 0.0001437
# Epoch val loss: 0.00011196524428669363
# Time taken: 237.69s
#
# Start of epoch 142
# Average training loss at epoch 142: 0.0001436
# Epoch val loss: 0.00011163148155901581
# Time taken: 239.40s
#
# Start of epoch 143
# Average training loss at epoch 143: 0.0001433
# Epoch val loss: 0.000111728222691454
# Time taken: 241.07s
#
# Start of epoch 144
# Average training loss at epoch 144: 0.0001432
# Epoch val loss: 0.00011152625665999949
# Time taken: 242.80s
#
# Start of epoch 145
# Average training loss at epoch 145: 0.0001430
# Epoch val loss: 0.00011158594134030864
# Time taken: 244.59s
#
# Start of epoch 146
# Average training loss at epoch 146: 0.0001430
# Epoch val loss: 0.00011133513908134773
# Time taken: 246.23s
#
# Start of epoch 147
# Average training loss at epoch 147: 0.0001428
# Epoch val loss: 0.00011122829164378345
# Time taken: 247.91s
#
# Start of epoch 148
# Average training loss at epoch 148: 0.0001426
# Epoch val loss: 0.00011111799540231004
# Time taken: 249.56s
#
# Start of epoch 149
# Average training loss at epoch 149: 0.0001426
# Epoch val loss: 0.00011109867773484439
# Time taken: 251.22s
#
# Start of epoch 150
# Average training loss at epoch 150: 0.0001424
# Epoch val loss: 0.0001109629956772551
# Time taken: 252.92s
#
# Start of epoch 151
# Average training loss at epoch 151: 0.0001422
# Epoch val loss: 0.00011093476496171206
# Time taken: 254.63s
#
# Start of epoch 152
# Average training loss at epoch 152: 0.0001421
# Epoch val loss: 0.0001106779818655923
# Time taken: 256.32s
#
# Start of epoch 153
# Average training loss at epoch 153: 0.0001418
# Epoch val loss: 0.0001105553237721324
# Time taken: 257.99s
#
# Start of epoch 154
# Average training loss at epoch 154: 0.0001418
# Epoch val loss: 0.00011051625915570185
# Time taken: 259.69s
#
# Start of epoch 155
# Average training loss at epoch 155: 0.0001417
# Epoch val loss: 0.00011032717884518206
# Time taken: 261.33s
#
# Start of epoch 156
# Average training loss at epoch 156: 0.0001415
# Epoch val loss: 0.00011022305261576548
# Time taken: 263.04s
#
# Start of epoch 157
# Time taken: 348.60s
#
# Start of epoch 206
# Average training loss at epoch 206: 0.0001346
# Epoch val loss: 0.00010479112097527832
# Time taken: 350.62s
#
# Start of epoch 207
# Average training loss at epoch 207: 0.0001344
# Epoch val loss: 0.00010464546357979998
# Time taken: 352.22s
#
# Start of epoch 208
# Average training loss at epoch 208: 0.0001343
# Epoch val loss: 0.00010451933485455811
# Time taken: 353.79s
#
# Start of epoch 209
# Average training loss at epoch 209: 0.0001341
# Epoch val loss: 0.00010455391020514071
# Time taken: 355.42s
#
# Start of epoch 210
# Average training loss at epoch 210: 0.0001341
# Epoch val loss: 0.00010445355292176828
# Time taken: 357.05s
#
# Start of epoch 211
# Average training loss at epoch 211: 0.0001340
# Epoch val loss: 0.0001044346354319714
# Time taken: 358.73s
#
# Start of epoch 212
# Average training loss at epoch 212: 0.0001339
# Epoch val loss: 0.0001043881056830287
# Time taken: 360.39s
#
# Start of epoch 213
# Average training loss at epoch 213: 0.0001337
# Epoch val loss: 0.00010422521881991997
# Time taken: 362.04s
#
# Start of epoch 214
# Average training loss at epoch 214: 0.0001337
# Epoch val loss: 0.00010404497879790142
# Time taken: 363.68s
#
# Start of epoch 215
# Average training loss at epoch 215: 0.0001334
# Epoch val loss: 0.0001038034024531953
# Time taken: 365.42s
#
# Start of epoch 216
# Average training loss at epoch 216: 0.0001333
# Epoch val loss: 0.00010388457303633913
# Time taken: 367.06s
#
# Start of epoch 217
# Average training loss at epoch 217: 0.0001331
# Epoch val loss: 0.00010375247802585363
# Time taken: 368.74s
#
# Start of epoch 218
# Average training loss at epoch 218: 0.0001331
# Epoch val loss: 0.00010388261580374092
# Time taken: 370.43s
#
# Start of epoch 219
# Average training loss at epoch 219: 0.0001331
# Epoch val loss: 0.00010362541797803715
# Time taken: 372.08s
#
# Start of epoch 220
# Average training loss at epoch 220: 0.0001329
# Epoch val loss: 0.00010345864575356245
# Time taken: 373.73s
#
# Start of epoch 221
# Average training loss at epoch 221: 0.0001327
# Epoch val loss: 0.0001032772270264104
# Time taken: 375.38s
#
# Start of epoch 222
# Average training loss at epoch 222: 0.0001325
# Epoch val loss: 0.00010325259790988639
# Time taken: 377.06s
#
# Start of epoch 223
# Average training loss at epoch 223: 0.0001324
# Epoch val loss: 0.00010317168198525906
# Time taken: 378.74s
#
# Start of epoch 224
# Average training loss at epoch 224: 0.0001324
# Epoch val loss: 0.00010303196177119389
# Time taken: 380.42s
#
# Start of epoch 225
# Average training loss at epoch 225: 0.0001322
# Epoch val loss: 0.0001030250423355028
# Time taken: 382.08s
#
# Start of epoch 226
# Average training loss at epoch 226: 0.0001322
# Epoch val loss: 0.0001028648839564994
# Time taken: 383.72s
#
# Start of epoch 227
# Average training loss at epoch 227: 0.0001320
# Epoch val loss: 0.00010278678382746875
# Time taken: 385.41s
#
# Start of epoch 228
# Average training loss at epoch 228: 0.0001319
# Epoch val loss: 0.00010270587517879903
# Time taken: 387.07s
#
# Start of epoch 229
# Average training loss at epoch 229: 0.0001317
# Epoch val loss: 0.00010264106094837189
# Time taken: 388.73s
#
#
# Start of epoch 350
# Average training loss at epoch 350: 0.0001208
# Epoch val loss: 9.354228677693754e-05
# Time taken: 581.87s
#
# Start of epoch 351
# Average training loss at epoch 351: 0.0001208
# Epoch val loss: 9.347443119622767e-05
# Time taken: 583.49s
#
# Start of epoch 352
# Average training loss at epoch 352: 0.0001207
# Epoch val loss: 9.341244003735483e-05
# Time taken: 585.17s
#
# Start of epoch 353
# Average training loss at epoch 353: 0.0001207
# Epoch val loss: 9.329769818577915e-05
# Time taken: 586.80s
#
# Start of epoch 354
# Average training loss at epoch 354: 0.0001206
# Epoch val loss: 9.331628825748339e-05
# Time taken: 588.44s
#
# Start of epoch 355
# Average training loss at epoch 355: 0.0001206
# Epoch val loss: 9.323399717686698e-05
# Time taken: 589.99s
#
# Start of epoch 356
# Average training loss at epoch 356: 0.0001205
# Epoch val loss: 9.326785948360339e-05
# Time taken: 591.54s
#
# Start of epoch 357
# Average training loss at epoch 357: 0.0001205
# Epoch val loss: 9.321032121079043e-05
# Time taken: 593.06s
#
# Start of epoch 358
# Average training loss at epoch 358: 0.0001203
# Epoch val loss: 9.315364877693355e-05
# Time taken: 594.62s
#
# Start of epoch 359
# Average training loss at epoch 359: 0.0001203
# Epoch val loss: 9.309155575465411e-05
# Time taken: 596.20s
#
# Start of epoch 360
# Average training loss at epoch 360: 0.0001203
# Epoch val loss: 9.296264761360362e-05
# Time taken: 597.72s
#
# Start of epoch 361
# Average training loss at epoch 361: 0.0001201
# Epoch val loss: 9.288822911912575e-05
# Time taken: 599.32s
#
# Start of epoch 362
# Average training loss at epoch 362: 0.0001201
# Epoch val loss: 9.296250937040895e-05
# Time taken: 601.01s
#
# Start of epoch 363
# Average training loss at epoch 363: 0.0001201
# Epoch val loss: 9.290291927754879e-05
# Time taken: 602.55s
#
# Start of epoch 364
# Average training loss at epoch 364: 0.0001200
# Epoch val loss: 9.281637903768569e-05
# Time taken: 604.15s
#
# Start of epoch 365
# Average training loss at epoch 365: 0.0001199
# Epoch val loss: 9.290480375057086e-05
# Time taken: 605.73s
#
# Start of epoch 366
# Average training loss at epoch 366: 0.0001199
# Epoch val loss: 9.280539961764589e-05
# Time taken: 607.34s
#
# Start of epoch 367
# Average training loss at epoch 367: 0.0001199
# Epoch val loss: 9.282001701649278e-05
# Time taken: 608.94s
#
# Start of epoch 368
# Average training loss at epoch 368: 0.0001198
# Epoch val loss: 9.269708971260116e-05
# Time taken: 610.54s
#
# Start of epoch 369
# Average training loss at epoch 369: 0.0001197
# Epoch val loss: 9.259349462809041e-05
# Time taken: 612.14s
#
# Start of epoch 370
# Average training loss at epoch 370: 0.0001197
# Epoch val loss: 9.252165182260796e-05
# Time taken: 613.78s
#
# Start of epoch 371
# Average training loss at epoch 371: 0.0001196
# Epoch val loss: 9.240036160917953e-05
# Time taken: 615.40s
#
# Start of epoch 372
# Average training loss at epoch 372: 0.0001195
# Epoch val loss: 9.250258153770119e-05
# Time taken: 617.08s
#
# Start of epoch 373
# Average training loss at epoch 373: 0.0001195
# Epoch val loss: 9.230792056769133e-05
# Time taken: 618.64s
#
# Start of epoch 374
# Average training loss at epoch 374: 0.0001194
# Epoch val loss: 9.247377602150664e-05
# Time taken: 620.22s
#
# Start of epoch 375
# Average training loss at epoch 375: 0.0001194
# Epoch val loss: 9.25276690395549e-05
# Time taken: 621.81s
#
# Start of epoch 376
# Average training loss at epoch 376: 0.0001195
# Epoch val loss: 9.255517943529412e-05
# Time taken: 623.53s
#
# Start of epoch 377
# Average training loss at epoch 377: 0.0001194
# Epoch val loss: 9.234681783709675e-05
# Time taken: 625.14s
#
# Start of epoch 378
# Average training loss at epoch 378: 0.0001192
# Epoch val loss: 9.231712465407327e-05
# Time taken: 626.73s
#
# Start of epoch 379
# Average training loss at epoch 379: 0.0001191
# Epoch val loss: 9.220020729117095e-05
# Time taken: 628.41s
#
# Start of epoch 380
# Average training loss at epoch 380: 0.0001191
# Epoch val loss: 9.21498067327775e-05
# Time taken: 629.93s
#
# Start of epoch 381
# Average training loss at epoch 381: 0.0001191
# Epoch val loss: 9.213241719407961e-05
# Time taken: 631.44s
#
# Start of epoch 382
# Average training loss at epoch 382: 0.0001191
# Epoch val loss: 9.216700709657744e-05
# Time taken: 632.97s
#
# Start of epoch 383
# Average training loss at epoch 383: 0.0001190
# Epoch val loss: 9.197898907586932e-05
# Time taken: 634.53s
#
# Start of epoch 384
# Average training loss at epoch 384: 0.0001189
# Epoch val loss: 9.182941721519455e-05
# Time taken: 636.11s
#
# Start of epoch 385
# Average training loss at epoch 385: 0.0001188
# Epoch val loss: 9.190278797177598e-05
# Time taken: 637.77s
#
# Start of epoch 386
# Average training loss at epoch 386: 0.0001188
# Epoch val loss: 9.185022645397112e-05
# Time taken: 639.45s
#
# Start of epoch 387
# Average training loss at epoch 387: 0.0001188
# Epoch val loss: 9.164817311102524e-05
# Time taken: 641.05s
#
# Start of epoch 388
# Average training loss at epoch 388: 0.0001186
# ...
# Epoch val loss: 6.1024104070384055e-05
# Time taken: 15725.71s
#
# Start of epoch 9876
# Average training loss at epoch 9876: 0.0000627
# Epoch val loss: 6.62174861645326e-05
# Time taken: 15727.25s
#
# Start of epoch 9877
# Average training loss at epoch 9877: 0.0000631
# Epoch val loss: 6.583089998457581e-05
# Time taken: 15728.77s
#
# Start of epoch 9878
# Average training loss at epoch 9878: 0.0000654
# Epoch val loss: 6.772920460207388e-05
# Time taken: 15730.31s
#
# Start of epoch 9879
# Average training loss at epoch 9879: 0.0000682
# Epoch val loss: 7.28082814021036e-05
# Time taken: 15731.89s
#
# Start of epoch 9880
# Average training loss at epoch 9880: 0.0000703
# Epoch val loss: 7.660634582862258e-05
# Time taken: 15733.42s
#
# Start of epoch 9881
# Average training loss at epoch 9881: 0.0000724
# Epoch val loss: 7.747548806946725e-05
# Time taken: 15734.96s
#
# Start of epoch 9882
# Average training loss at epoch 9882: 0.0000754
# Epoch val loss: 6.75042174407281e-05
# Time taken: 15736.50s
#
# Start of epoch 9883
# Average training loss at epoch 9883: 0.0000755
# Epoch val loss: 5.941923154750839e-05
# Time taken: 15738.07s
#
# Start of epoch 9884
# Average training loss at epoch 9998: 0.0000701
# Epoch val loss: 5.9889738622587174e-05
# Time taken: 15918.78s
#
# Start of epoch 9999
# Average training loss at epoch 9999: 0.0000673
# Epoch val loss: 5.9807440266013145e-05
# Time taken: 15920.36s
# Total time taken: 15920.58s

# %% [markdown]
# # Plots on Train data

# %% [markdown]
# ### Reconstruction

# %%
input = x_train
out1, out2, out3 = koopmanAEModel(input)

# %%
plt.title("Batch Reconstruction")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot(input[:,0], label = "Ground Truth")
plt.plot(out1[:,0], '--', label="Reconstruction")
plt.legend()

# %% [markdown]
# ### Linear Prediction

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %%
plt.title("Batch Linear Prediciton")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot(x2[:,3], label = "Ground Truth")
plt.plot(out3[:,3], '--', label="Linear Prediction")
plt.legend()

# %%
plt.title("Batch Linear Prediciton")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot(x2[:,0], label = "Ground Truth")
plt.plot(out3[:,0], '--', label="Linear Prediction")
plt.legend()

# %% [markdown]
# ### Error graphs

# %%
plt.title("Batch Linearirty error")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot((tf.square(tf.subtract(x2,out3))), label = "Linearity Error")
plt.legend()

# %% [markdown]
# ### Koopman Matrix

# %%
K = koopmanAEModel.koopman.get_weights()
print(K)
tf.shape(K)
# Out:
# [array([[ 0.11301562,  0.14301282, -0.11957522,  0.0886809 , -0.16085123,
#         -0.042891  ,  0.13397986,  0.0376987 ,  0.1422346 , -0.01677757,
#          0.14658684,  0.14309783,  0.01566768, -0.17395402,  0.02023688,
#         -0.0706524 ],
#        [ 0.03531253,  0.05242883, -0.13357924, -0.02134078, -0.17529021,
#         -0.06029287,  0.1175748 , -0.00391487,  0.09333421,  0.02030695,
#         -0.06117055,  0.03310443, -0.02330135, -0.04895033,  0.03652994,
#         -0.19065134],
#        [-0.09776503,  0.0043634 ,  0.17860837,  0.05710474,  0.2329648 ,
#         -0.14838581, -0.05811596,  0.10750556, -0.08918111, -0.03697861,
#         -0.03433938, -0.22729981, -0.15310492, -0.05169488,  0.06483246,
#          0.06252325],
#        [ 0.08285004, -0.02983296,  0.04875486,  0.07919229, -0.0126685 ,
#         -0.029635  ,  0.01810056, -0.06840207,  0.05180397,  0.00598922,
#          0.01064566,  0.03218675, -0.01914988, -0.03639998,  0.02771082,
#         -0.04717423],
#        [-0.05254279, -0.00689377,  0.103063  , -0.01264311,  0.18198471,
#         -0.21266754, -0.05362784,  0.14785832, -0.05823277, -0.02696339,
#          0.15937838, -0.2224008 , -0.07155617,  0.06073251, -0.03379411,
#          0.09281649],
#        [-0.02711306,  0.07679407, -0.01008288, -0.05891753, -0.07865789,
#          0.19632319,  0.04278663, -0.1312656 , -0.0975304 ,  0.12258668,
#         -0.0995044 ,  0.12073429,  0.07074656,  0.09585052, -0.13239601,
#         -0.04762563],
#        [ 0.04416342,  0.05290236,  0.05669422,  0.02334419, -0.16087781,
#          0.06632282,  0.11447896, -0.01428014,  0.05821595, -0.00383599,
#         -0.00906851,  0.12948832, -0.02374293, -0.04214938,  0.0588302 ,
#         -0.13147172],
#        [ 0.00419459,  0.08052246, -0.00115526,  0.0676866 ,  0.00303504,
#         -0.1076085 ,  0.06451627,  0.02712962, -0.01036254, -0.1566264 ,
#          0.01996638, -0.14009753, -0.08893079, -0.14388347,  0.07104743,
#         -0.04189903],
#        [ 0.1589513 ,  0.01241068, -0.19737314, -0.01054914, -0.2462596 ,
#          0.12971996,  0.09254409, -0.08564375,  0.20436844, -0.0783454 ,
#          0.00593738,  0.14480321,  0.06212166, -0.05242045,  0.0613413 ,
#         -0.21839076],
#        [-0.14603043, -0.04845358,  0.05984794, -0.10432319,  0.08201656,
#          0.03531481, -0.10789338, -0.17011315, -0.15168193,  0.10435706,
#         -0.12447834,  0.0742135 ,  0.0197059 ,  0.04925721, -0.13612932,
#          0.17740244],
#        [-0.01632881,  0.08863934,  0.02337116,  0.08841006, -0.16625877,
#         -0.00724939,  0.0155816 ,  0.01450161,  0.08359694, -0.03438087,
#          0.00423584, -0.06301256, -0.00117582, -0.13143082,  0.11972294,
#          0.08996303],
#        [-0.03476391,  0.00414862, -0.07784742, -0.0873085 , -0.03707922,
#          0.13855378,  0.02418508, -0.18962984,  0.00470767,  0.06769369,
#         -0.08164421,  0.27441752,  0.12618765,  0.05771288, -0.14053442,
#         -0.10054468],
#        [-0.05083782,  0.0457035 , -0.04492595, -0.10229225, -0.07792117,
#          0.06594558, -0.04439127, -0.14821456,  0.08311821,  0.14433688,
#         -0.01509672,  0.11885484,  0.18362126,  0.08621232, -0.15591231,
#         -0.05920482],
#        [-0.14193408, -0.04023215,  0.05554912, -0.1927402 ,  0.13359788,
#         -0.02791119, -0.06158749, -0.02899935, -0.11108728,  0.06261733,
#         -0.02432057, -0.05068471,  0.00980539,  0.04811938, -0.1703004 ,
#          0.1789739 ],
#        [ 0.048537  ,  0.06600095, -0.03486899,  0.16988744, -0.19625738,
#          0.00532128,  0.06555386,  0.09350311,  0.27798364, -0.1421283 ,
#          0.02064542, -0.04810464, -0.07865103, -0.10160995,  0.20820239,
#         -0.18463677],
#        [-0.04906628, -0.03369319,  0.1390415 , -0.09858859,  0.18256488,
#         -0.1561    , -0.06001412,  0.04838166, -0.04618696, -0.02147459,
#          0.06278944, -0.15812378, -0.09975588,  0.01955696, -0.05477243,
#          0.14757925]], dtype=float32)]
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 1, 16, 16])>

# %% [markdown]
# # Save the Model

# %%
koopmanAEModel.save('checkpoints/doggo_Trained_Model')
# Out:
# INFO:tensorflow:Assets written to: checkpoints/doggo_Trained_Model\assets

# %% [markdown]
# # Load the Model

# %%
new_model = tf.keras.models.load_model('checkpoints/doggo_Trained_Model', compile=False)
new_model.summary()
# Out:
# Model: "Koopman_AE_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_model (EncoderModel) multiple                  8480
# _________________________________________________________________
# koopman__model (Koopman_Mode multiple                  256
# _________________________________________________________________
# decoder_model (DecoderModel) multiple                  9700
# =================================================================
# Total params: 18,436
# Trainable params: 18,436
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Plots on Test Data

# %%
input = test_data
new_out1, new_out2, new_out3 = new_model(input)

# %%
plt.title("Batch Reconstruction")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot(input[:,3], label = "Ground Truth")
plt.plot(new_out1[:,3], '--', label="Reconstruction")
plt.legend()

# %%
x = input
x2 = []
for i in range(numTraj_batch):
    x2.append(x[i*trajLength+1:(i+1)*trajLength])
x2 = tf.reshape(x2, [-1, x.shape[-1]]) # Shifted input

# %%
plt.title("Batch Linear Prediciton")
plt.rcParams['figure.figsize'] = [9, 6]
plt.plot(x2[:,0], label = "Ground Truth")
plt.plot(new_out3[:,0], '--', label="Linear Prediction")
plt.legend()
